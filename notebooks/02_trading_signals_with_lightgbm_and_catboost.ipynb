# %% [markdown]
# # Long-Short Strategy, Part 2: Trading signals with LightGBM and CatBoost

# %% [markdown]
# In this section, we'll start designing, implementing, and evaluating a trading strategy for US equities driven by daily return forecasts produced by gradient boosting models.
#
# As in the previous examples, we'll lay out a framework and build a specific example that you can adapt to run your own experiments. There are numerous aspects that you can vary, from the asset class and investment universe to more granular aspects like the features, holding period, or trading rules. See, for example, the **Alpha Factor Library** in the [Appendix](../24_alpha_factor_library) for numerous additional features.
#
# We'll keep the trading strategy simple and only use a single ML signal; a real-life application will likely use multiple signals from different sources, such as complementary ML models trained on different datasets or with different lookahead or lookback periods. It would also use sophisticated risk management, from simple stop-loss to value-at-risk analysis.
#
# **Six notebooks** cover our workflow sequence:
#
# 1. [preparing_the_model_data](04_preparing_the_model_data.ipyny): we engineer a few simple features from the Quandl Wiki data
# 2. `trading_signals_with_lightgbm_and_catboost`  (this noteboook): we tune hyperparameters for LightGBM and CatBoost to select a model, using 2015/16 as our validation period.
# 3. [evaluate_trading_signals](06_evaluate_trading_signals.ipynb): we compare the cross-validation performance using various metrics to select the best model.
# 4. [model_interpretation](07_model_interpretation.ipynb): we take a closer look at the drivers behind the best model's predictions.
# 5. [making_out_of_sample_predictions](08_making_out_of_sample_predictions.ipynb): we generate predictions for our out-of-sample test period 2017.
# 6. [backtesting_with_zipline](09_backtesting_with_zipline.ipynb): evaluate the historical performance of a long-short strategy based on our predictive signals using Zipline.

# %% [markdown]
# We'll subset the dataset created in the preceding notebook through the end of 2016 to cross-validate several model configurations for various lookback and lookahead windows, as well as different roll-forward periods and hyperparameters.
#
# Our approach to model selection will be similar to the one we used in the previous chapter and uses the custom `MultipleTimeSeriesCV` introduced in [Chapter 7, Linear Models – From Risk Factors to Return Forecasts](../07_linear_models).

# %% [markdown]
# ## Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

from pathlib import Path
import sys, os
from time import time
from tqdm import tqdm

from collections import defaultdict
from itertools import product

import numpy as np
import pandas as pd

import lightgbm as lgb
from catboost import Pool, CatBoostRegressor

from sklearn.linear_model import LinearRegression
from scipy.stats import spearmanr

from alphalens.tears import (create_summary_tear_sheet,
                             create_full_tear_sheet)

from alphalens.utils import get_clean_factor_and_forward_returns

import matplotlib.pyplot as plt
import seaborn as sns

# %%
sys.path.insert(1, os.path.join(sys.path[0], '..'))
from utils import MultipleTimeSeriesCV, format_time

# %%
sns.set_style('whitegrid')

# %%
YEAR = 252
idx = pd.IndexSlice

# %% [markdown]
# ## Get Data

# %% [markdown]
# We select the train and validation sets, and identify labels and features:

# %%
data = (pd.read_hdf('data.h5', 'model_data')
            .sort_index()
            .loc[idx[:, :'2022'], :]) # train & validation period
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 111185 entries, ('ALUA.BA', Timestamp('2010-01-04 00:00:00')) to ('YPFD.BA', Timestamp('2020-12-30 00:00:00'))
# Data columns (total 22 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   dollar_vol       111185 non-null  float64
#  1   dollar_vol_rank  111185 non-null  float64
#  2   rsi              110583 non-null  float64
#  3   bb_high          110368 non-null  float64
#  4   bb_low           110366 non-null  float64
#  5   NATR             110583 non-null  float64
#  6   ATR              110583 non-null  float64
#  7   ppo              110110 non-null  float64
#  8   MACD             109766 non-null  float64
#  9   sector           111185 non-null  int64
#  10  r01              111142 non-null  float64
#  11  r05              110970 non-null  float64
#  12  r10              110755 non-null  float64
#  13  r21              110282 non-null  float64
#  14  r42              109379 non-null  float64
#  15  r63              108476 non-null  float64
#  16  r01_fwd          111185 non-null  float64
#  17  r05_fwd          111185 non-null  float64
#  18  r21_fwd          111185 non-null  float64
#  19  year             111185 non-null  int32
#  20  month            111185 non-null  int32
#  21  weekday          111185 non-null  int32
# dtypes: float64(18), int32(3), int64(1)
# memory usage: 17.9+ MB

# %%
labels = sorted(data.filter(like='_fwd').columns)
features = data.columns.difference(labels).tolist() # features are columns not containing '_fwd'

# %% [markdown]
# ## Model Selection: Lookback, lookahead and roll-forward periods

# %%
tickers = data.index.get_level_values('symbol').unique()

# %% [markdown]
# We may want to predict 1, 5 or 21-day returns:

# %%
lookaheads = [1, 5, 21]
# lookaheads = [21]

# %%
categoricals = ['year', 'month', 'sector', 'weekday']

# %% [markdown]
# We select 4.5 and one years as the length of our training periods; test periods are one and three months long. Since we are using two years (2015/16) for validation, a one-month test period implies 24 folds.

# %%
train_lengths = [int(4.5 * 252), 252]
test_lengths = [63, 21]

# %%
test_params = list(product(lookaheads, train_lengths, test_lengths))

# %%
results_path = Path('results', 'us_stocks')
if not results_path.exists():
    results_path.mkdir(parents=True)

# %% [markdown]
# ## Baseline: Linear Regression

# %% [markdown]
# We always want to know how much our (gradient boosting) is improving over a simpler baseline (if at all..).

# %%
lr = LinearRegression()

# %%
lr_metrics = []

# iterate over our three CV configuration parameters
for lookahead, train_length, test_length in tqdm(test_params):
    label = f'r{lookahead:02}_fwd'
    df = pd.get_dummies(data.loc[:, features + [label]].dropna(), 
                        columns=categoricals, 
                        drop_first=True)
    X, y = df.drop(label, axis=1), df[label]

    n_splits = int(2 * YEAR / test_length)
    cv = MultipleTimeSeriesCV(n_splits=n_splits,
                              test_period_length=test_length,
                              lookahead=lookahead,
                              train_period_length=train_length)

    ic, preds = [], []
    for i, (train_idx, test_idx) in enumerate(cv.split(X=X)):
        X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
        X_test, y_test = X.iloc[test_idx], y.iloc[test_idx]
        lr.fit(X_train, y_train)
        y_pred = lr.predict(X_test)
        preds.append(y_test.to_frame('y_true').assign(y_pred=y_pred))
        ic.append(spearmanr(y_test, y_pred)[0])
    preds = pd.concat(preds)
    lr_metrics.append([lookahead, 
                       train_length, 
                       test_length,
                       np.mean(ic),
                       spearmanr(preds.y_true, preds.y_pred)[0]
                      ])

columns = ['lookahead', 'train_length', 'test_length', 'ic_by_day', 'ic']
lr_metrics = pd.DataFrame(lr_metrics, columns=columns)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   8%|▊         | 1/12 [00:01<00:11,  1.04s/it]
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#  25%|██▌       | 3/12 [00:02<00:07,  1.17it/s]
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#  33%|███▎      | 4/12 [00:03<00:06,  1.32it/s]
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#  42%|████▏     | 5/12 [00:04<00:04,  1.50it/s]
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#  58%|█████▊    | 7/12 [00:05<00:03,  1.32it/s]
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}

# %% [markdown]
# ### Information Coefficient - Distribution by Lookahead

# %%
fig, axes = plt.subplots(ncols=2, figsize=(14,5), sharey=True)

# plot average of daily IC values
sns.boxplot(x='lookahead', y='ic_by_day',data=lr_metrics, ax=axes[0])
axes[0].set_title('IC by Day')

# plot IC across all predictions
sns.boxplot(x='lookahead', y='ic',data=lr_metrics, ax=axes[1])
axes[1].set_title('IC Overall')
axes[0].set_ylabel('Information Coefficient')
axes[1].set_ylabel('')
fig.tight_layout()

# %% [markdown]
# ### Best Train/Test Period Lengths

# %% [markdown]
# For one- and five-day return forecasts, shorter train- and test-length yield better results in terms of daily avg IC:

# %%
(lr_metrics.groupby('lookahead', group_keys=False)
 .apply(lambda x: x.nlargest(3, 'ic_by_day')))
# Out:
#     lookahead  train_length  test_length  ic_by_day        ic
# 1           1          1134           21   0.072978  0.045205
# 0           1          1134           63   0.066265  0.046076
# 2           1           252           63   0.059931 -0.011535
# 7           5           252           21   0.092171  0.055000
# 6           5           252           63   0.087214 -0.015598
# 5           5          1134           21   0.076497  0.036405
# 11         21           252           21   0.102942  0.000084
# 8          21          1134           63   0.089641  0.140778
# 10         21           252           63   0.074136  0.125806

# %%
lr_metrics.to_csv(results_path / 'lin_reg_metrics.csv', index=False)

# %% [markdown]
# ## LightGBM Model Tuning

# %% [markdown]
# The notebook example iterates over many configurations, optionally using random samples to speed up model selection using a diverse subset. The goal is to identify the most impactful parameters without trying every possible combination.

# %%
def get_fi(model):
    """Return normalized feature importance as pd.Series"""
    fi = model.feature_importance(importance_type='gain')
    return (pd.Series(fi / fi.sum(),
                      index=model.feature_name()))

# %% [markdown]
# ### Hyperparameter Options

# %% [markdown]
# The `base_params` are not affected by cross-validation:

# %%
base_params = dict(boosting='gbdt',
                   objective='regression',
                   verbose=-1)

# %% [markdown]
# We choose the following parameters and values to select our best model (see book chapter for detail):

# %%
# constraints on structure (depth) of each tree
max_depths = [2, 3, 5, 7]
num_leaves_opts = [2 ** i for i in max_depths]
min_data_in_leaf_opts = [250, 500, 1000]

# weight of each new tree in the ensemble
learning_rate_ops = [.01, .1, .3]

# random feature selection
feature_fraction_opts = [.3, .6, .95]

# %%
param_names = ['learning_rate', 'num_leaves',
               'feature_fraction', 'min_data_in_leaf']

# %%
cv_params = list(product(learning_rate_ops,
                         num_leaves_opts,
                         feature_fraction_opts,
                         min_data_in_leaf_opts))
n_params = len(cv_params)
print(f'# Parameters: {n_params}')
# Out:
# # Parameters: 108

# %% [markdown]
# ### Train/Test Period Lengths

# %%
lookaheads = [1, 5, 21]
# lookaheads = [21]
label_dict = dict(zip(lookaheads, labels))

# %% [markdown]
# We only use test periods of 63 days length to save some model training and evaluation time.

# %%
train_lengths = [int(4.5 * 252), 252]
# train_lengths = [int(4.5 * 252)]
test_lengths = [63]

# %%
test_params = list(product(lookaheads, train_lengths, test_lengths))
n = len(test_params)
test_param_sample = np.random.choice(list(range(n)), size=int(n), replace=False)
test_params = [test_params[i] for i in test_param_sample]
print('Train configs:', len(test_params))
# Out:
# Train configs: 6

# %% [markdown]
# ### Categorical Variables

# %% [markdown]
# We integer-encode categorical variables with values starting at zero, as expected by LightGBM (not necessary
# as long as the category codes have values less than $2^{32}$, but avoids a warning)

# %%
categoricals = ['year', 'weekday', 'month']
for feature in categoricals:
    data[feature] = pd.factorize(data[feature], sort=True)[0]

# %% [markdown]
# ### Custom Loss Function: Information Coefficient

# %%
def ic_lgbm(preds, train_data):
    """Custom IC eval metric for lightgbm"""
    is_higher_better = True
    return 'ic', spearmanr(preds, train_data.get_label())[0], is_higher_better

# %% [markdown]
# ### Run Cross-Validation

# %% [markdown]
# To explore the hyperparameter space, we specify values for key parameters that we would like to test in combination. The sklearn library supports `RandomizedSearchCV` to cross-validate a subset of parameter combinations that are sampled randomly from specified distributions. We will implement a custom version that allows us to monitor performance so we can abort the search process once we're satisfied with the result, rather than specifying a set number of iterations beforehand.

# %%
lgb_store = Path(results_path / 'tuning_lgb.h5')

# %%
labels = sorted(data.filter(like='fwd').columns)
features = data.columns.difference(labels).tolist()

# %%
label_dict = dict(zip(lookaheads, labels))

# %%
num_iterations = [10, 25, 50, 75] + list(range(100, 501, 50))
num_boost_round = num_iterations[-1]

# %%
metric_cols = (param_names + ['t', 'daily_ic_mean', 'daily_ic_mean_n',
                              'daily_ic_median', 'daily_ic_median_n'] +
               [str(n) for n in num_iterations])

# %% [markdown]
# We iterate over our six CV configurations and collect the resulting metrics:

# %%
for lookahead, train_length, test_length in test_params:
    # randomized grid search
    cvp = np.random.choice(list(range(n_params)),
                           size=int(n_params / 2),
                           replace=False)
    cv_params_ = [cv_params[i] for i in cvp]

    # set up cross-validation
    n_splits = int(2 * YEAR / test_length)
    print(f'Lookahead: {lookahead:2.0f} | '
          f'Train: {train_length:3.0f} | '
          f'Test: {test_length:2.0f} | '
          f'Params: {len(cv_params_):3.0f} | '
          f'Train configs: {len(test_params)}')

    # time-series cross-validation
    cv = MultipleTimeSeriesCV(n_splits=n_splits,
                              lookahead=lookahead,
                              test_period_length=test_length,
                              train_period_length=train_length)

    label = label_dict[lookahead]
    outcome_data = data.loc[:, features + [label]].dropna()
    
    # binary dataset
    lgb_data = lgb.Dataset(data=outcome_data.drop(label, axis=1),
                           label=outcome_data[label],
                           categorical_feature=categoricals,
                           free_raw_data=False)
    T = 0
    predictions, metrics, feature_importance, daily_ic = [], [], [], []
    
    # iterate over (shuffled) hyperparameter combinations
    for p, param_vals in enumerate(cv_params_):
        key = f'{lookahead}/{train_length}/{test_length}/' + '/'.join([str(p) for p in param_vals])
        params = dict(zip(param_names, param_vals))
        params.update(base_params)

        start = time()
        cv_preds, nrounds = [], []
        ic_cv = defaultdict(list)
        
        # iterate over folds
        for i, (train_idx, test_idx) in enumerate(cv.split(X=outcome_data)):
            
            # select train subset
            lgb_train = lgb_data.subset(used_indices=train_idx.tolist(),
                                       params=params).construct()
            
            # train model for num_boost_round
            model = lgb.train(params=params,
                              train_set=lgb_train,
                              num_boost_round=num_boost_round)
            # log feature importance
            if i == 0:
                fi = get_fi(model).to_frame()
            else:
                fi[i] = get_fi(model)

            # capture predictions
            test_set = outcome_data.iloc[test_idx, :]
            X_test = test_set.loc[:, model.feature_name()]
            y_test = test_set.loc[:, label]
            y_pred = {str(n): model.predict(X_test, num_iteration=n) for n in num_iterations}
            
            # record predictions for each fold
            cv_preds.append(y_test.to_frame('y_test').assign(**y_pred).assign(i=i))
        
        # combine fold results
        cv_preds = pd.concat(cv_preds).assign(**params)
        predictions.append(cv_preds)
        
        # compute IC per day
        by_day = cv_preds.groupby(level='date')
        ic_by_day = pd.concat([by_day.apply(lambda x: spearmanr(x.y_test, x[str(n)])[0]).to_frame(n)
                               for n in num_iterations], axis=1)
        daily_ic_mean = ic_by_day.mean()
        daily_ic_mean_n = daily_ic_mean.idxmax()
        daily_ic_median = ic_by_day.median()
        daily_ic_median_n = daily_ic_median.idxmax()
        
        # compute IC across all predictions
        ic = [spearmanr(cv_preds.y_test, cv_preds[str(n)])[0] for n in num_iterations]
        t = time() - start
        T += t
        
        # collect metrics
        metrics = pd.Series(list(param_vals) +
                            [t, daily_ic_mean.max(), daily_ic_mean_n, daily_ic_median.max(), daily_ic_median_n] + ic,
                            index=metric_cols)
        msg = f'\t{p:3.0f} | {format_time(T)} ({t:3.0f}) | {params["learning_rate"]:5.2f} | '
        msg += f'{params["num_leaves"]:3.0f} | {params["feature_fraction"]:3.0%} | {params["min_data_in_leaf"]:4.0f} | '
        msg += f' {max(ic):6.2%} | {ic_by_day.mean().max(): 6.2%} | {daily_ic_mean_n: 4.0f} | {ic_by_day.median().max(): 6.2%} | {daily_ic_median_n: 4.0f}'
        print(msg)

        # persist results for given CV run and hyperparameter combination
        metrics.to_hdf(lgb_store, 'metrics/' + key)
        ic_by_day.assign(**params).to_hdf(lgb_store, 'daily_ic/' + key)
        fi.T.describe().T.assign(**params).to_hdf(lgb_store, 'fi/' + key)
        cv_preds.to_hdf(lgb_store, 'predictions/' + key)
# Out:
# Lookahead:  1 | Train: 252 | Test: 63 | Params:  54 | Train configs: 6
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  0 | 00:00:06 (  6) |  0.30 | 128 | 60% | 1000 |   4.34% |  5.66% |   10 |  5.86% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  1 | 00:00:10 (  4) |  0.10 |   4 | 30% | 1000 |   5.13% |  6.50% |  100 |  7.21% |  350
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  2 | 00:00:21 ( 11) |  0.10 | 128 | 95% |  500 |   5.00% |  6.13% |   50 |  6.26% |  250
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  3 | 00:00:26 (  5) |  0.30 |   8 | 30% |  500 |   4.51% |  5.58% |   25 |  6.59% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  4 | 00:00:30 (  4) |  0.01 |   4 | 95% |  250 |   3.16% |  4.98% |   75 |  6.51% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  5 | 00:00:35 (  5) |  0.30 |   8 | 60% |  500 |   4.41% |  5.71% |  100 |  6.41% |   75
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  6 | 00:00:48 ( 13) |  0.10 |  32 | 30% |  250 |   4.84% |  6.08% |   25 |  6.89% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  7 | 00:00:53 (  5) |  0.30 |   8 | 30% | 1000 |   5.12% |  6.62% |   25 |  6.47% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  8 | 00:00:57 (  4) |  0.30 |   4 | 60% |  500 |   3.79% |  5.69% |  150 |  7.19% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  9 | 00:01:06 (  9) |  0.10 |  32 | 60% |  500 |   4.34% |  5.71% |   50 |  6.24% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 10 | 00:01:15 (  9) |  0.30 |  32 | 60% |  500 |   4.61% |  5.26% |   25 |  5.75% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 11 | 00:01:19 (  4) |  0.01 |   4 | 60% |  250 |   3.35% |  5.03% |   50 |  6.04% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 12 | 00:01:23 (  4) |  0.10 |   4 | 60% |  250 |   4.43% |  5.93% |  100 |  7.05% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 13 | 00:01:27 (  4) |  0.30 |   4 | 60% | 1000 |   4.49% |  5.60% |   25 |  6.09% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 14 | 00:01:32 (  6) |  0.30 |   8 | 95% |  250 |   3.47% |  5.49% |  150 |  7.04% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 15 | 00:01:36 (  4) |  0.01 |   4 | 95% | 1000 |   4.06% |  6.11% |  350 |  7.14% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 16 | 00:01:42 (  6) |  0.30 |  32 | 60% | 1000 |   4.34% |  5.66% |   10 |  5.86% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 17 | 00:01:56 ( 14) |  0.30 |  32 | 60% |  250 |   4.56% |  5.23% |   10 |  5.75% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 18 | 00:02:02 (  6) |  0.30 | 128 | 30% | 1000 |   5.15% |  5.84% |   25 |  7.19% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 19 | 00:02:05 (  4) |  0.10 |   4 | 60% | 1000 |   4.46% |  6.21% |  150 |  6.49% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 20 | 00:02:14 (  8) |  0.30 |  32 | 30% |  500 |   4.91% |  5.76% |  100 |  6.99% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 21 | 00:02:18 (  4) |  0.30 |   4 | 95% | 1000 |   3.97% |  6.32% |  100 |  6.59% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 22 | 00:02:22 (  4) |  0.10 |   4 | 95% |  250 |   4.02% |  5.80% |  250 |  7.08% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 23 | 00:02:27 (  6) |  0.10 | 128 | 30% | 1000 |   5.36% |  6.48% |   50 |  7.86% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 24 | 00:02:36 (  9) |  0.01 |  32 | 60% |  500 |   4.78% |  6.53% |  400 |  6.56% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 25 | 00:02:40 (  3) |  0.10 |   4 | 30% |  250 |   4.82% |  6.00% |  100 |  6.95% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 26 | 00:02:53 ( 13) |  0.30 |  32 | 30% |  250 |   4.83% |  5.56% |   10 |  5.82% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 27 | 00:02:56 (  4) |  0.10 |   4 | 30% |  500 |   4.58% |  6.29% |  300 |  6.98% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 28 | 00:03:02 (  6) |  0.10 |   8 | 95% |  500 |   4.82% |  6.34% |   75 |  7.34% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 29 | 00:03:08 (  6) |  0.10 |   8 | 95% |  250 |   4.35% |  6.22% |   75 |  6.93% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 30 | 00:03:17 (  9) |  0.10 | 128 | 60% |  500 |   4.34% |  5.71% |   50 |  6.24% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 31 | 00:03:21 (  4) |  0.30 |   4 | 30% |  250 |   4.23% |  5.62% |   50 |  6.61% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 32 | 00:03:31 ( 10) |  0.10 |  32 | 95% |  500 |   5.00% |  6.13% |   50 |  6.26% |  250
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 33 | 00:03:35 (  4) |  0.10 |   4 | 95% |  500 |   4.14% |  6.07% |  150 |  7.33% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 34 | 00:03:40 (  5) |  0.10 |   8 | 30% | 1000 |   5.73% |  6.85% |  100 |  8.00% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 35 | 00:03:46 (  6) |  0.10 | 128 | 60% | 1000 |   4.63% |  6.53% |   75 |  7.39% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 36 | 00:04:02 ( 17) |  0.01 | 128 | 95% |  250 |   4.41% |  6.13% |  250 |  6.47% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 37 | 00:04:18 ( 16) |  0.30 |  32 | 95% |  250 |   4.15% |  5.14% |   10 |  5.32% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 38 | 00:04:27 (  8) |  0.10 | 128 | 30% |  500 |   5.30% |  6.45% |   50 |  6.96% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 39 | 00:04:44 ( 17) |  0.10 | 128 | 95% |  250 |   4.14% |  5.39% |   10 |  6.37% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 40 | 00:04:57 ( 13) |  0.01 |  32 | 60% |  250 |   4.93% |  6.70% |  250 |  7.18% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 41 | 00:05:06 (  9) |  0.10 |  32 | 30% |  500 |   5.30% |  6.45% |   50 |  6.96% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 42 | 00:05:16 ( 10) |  0.01 |  32 | 95% |  500 |   4.54% |  6.19% |  500 |  6.86% |  250
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 43 | 00:05:21 (  6) |  0.01 |  32 | 30% | 1000 |   5.25% |  6.58% |  500 |  6.79% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 44 | 00:05:27 (  5) |  0.01 |   8 | 30% |  500 |   4.88% |  6.46% |  450 |  6.94% |  350
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 45 | 00:05:36 (  9) |  0.01 | 128 | 60% |  500 |   4.78% |  6.53% |  400 |  6.56% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 46 | 00:05:41 (  6) |  0.30 |   8 | 95% |  500 |   4.86% |  5.73% |   25 |  6.15% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 47 | 00:05:47 (  6) |  0.30 |  32 | 30% | 1000 |   5.15% |  5.84% |   25 |  7.19% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 48 | 00:06:01 ( 15) |  0.10 | 128 | 60% |  250 |   3.94% |  5.38% |   25 |  5.65% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 49 | 00:06:06 (  5) |  0.30 |   8 | 30% |  250 |   4.39% |  5.44% |   25 |  5.43% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 50 | 00:06:11 (  4) |  0.10 |   4 | 95% | 1000 |   3.96% |  6.36% |  250 |  6.62% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 51 | 00:06:21 ( 10) |  0.30 | 128 | 95% |  500 |   4.23% |  5.59% |   25 |  6.31% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 52 | 00:06:27 (  6) |  0.01 | 128 | 30% | 1000 |   5.25% |  6.58% |  500 |  6.79% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 53 | 00:06:32 (  5) |  0.01 |   8 | 30% |  250 |   4.21% |  6.14% |  500 |  5.71% |  200
# Lookahead:  5 | Train: 252 | Test: 63 | Params:  54 | Train configs: 6
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  0 | 00:00:06 (  6) |  0.30 |   8 | 95% |  500 |   4.24% |  6.62% |   50 |  6.50% |  350
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  1 | 00:00:10 (  4) |  0.30 |   4 | 60% | 1000 |   3.26% |  7.39% |   50 |  6.61% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  2 | 00:00:16 (  6) |  0.01 |  32 | 60% | 1000 |   4.54% |  8.66% |  500 |  6.43% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  3 | 00:00:24 (  8) |  0.01 |  32 | 30% |  500 |   4.65% |  8.51% |  500 |  8.61% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  4 | 00:00:34 ( 10) |  0.10 |  32 | 60% |  500 |   4.88% |  7.40% |   75 |  6.79% |   75
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  5 | 00:00:38 (  4) |  0.10 |   4 | 60% | 1000 |   3.53% |  9.03% |   50 |  7.94% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  6 | 00:00:42 (  4) |  0.10 |   4 | 95% |  500 |   3.59% |  7.90% |   50 |  6.44% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  7 | 00:00:46 (  4) |  0.30 |   4 | 30% |  250 |   3.61% |  6.63% |   75 |  5.49% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  8 | 00:00:49 (  4) |  0.01 |   4 | 95% |  250 |   3.02% |  7.71% |  400 |  7.06% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  9 | 00:00:59 ( 10) |  0.10 | 128 | 60% |  500 |   4.88% |  7.40% |   75 |  6.79% |   75
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 10 | 00:01:09 ( 10) |  0.01 | 128 | 95% |  500 |   5.33% |  7.92% |  450 |  6.63% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 11 | 00:01:13 (  4) |  0.30 |   4 | 95% |  500 |   2.84% |  7.68% |   10 |  5.74% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 12 | 00:01:17 (  4) |  0.10 |   4 | 95% | 1000 |   3.94% |  8.96% |   50 |  8.82% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 13 | 00:01:21 (  4) |  0.10 |   4 | 60% |  500 |   3.40% |  8.06% |   50 |  6.98% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 14 | 00:01:25 (  4) |  0.30 |   4 | 95% | 1000 |   4.18% |  8.49% |   10 |  7.65% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 15 | 00:01:31 (  6) |  0.01 | 128 | 60% | 1000 |   4.54% |  8.66% |  500 |  6.43% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 16 | 00:01:37 (  6) |  0.10 |   8 | 60% |  250 |   4.09% |  7.18% |   75 |  6.30% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 17 | 00:01:43 (  6) |  0.30 | 128 | 60% | 1000 |   4.53% |  8.22% |   25 |  6.94% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 18 | 00:01:49 (  6) |  0.30 |  32 | 30% | 1000 |   3.07% |  7.37% |   50 |  7.10% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 19 | 00:02:03 ( 15) |  0.10 |  32 | 60% |  250 |   4.17% |  8.24% |   50 |  8.37% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 20 | 00:02:10 (  6) |  0.01 | 128 | 95% | 1000 |   5.24% |  8.68% |  300 |  7.00% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 21 | 00:02:15 (  6) |  0.01 |   8 | 60% | 1000 |   4.32% |  8.48% |  500 |  7.43% |   75
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 22 | 00:02:22 (  6) |  0.10 | 128 | 95% | 1000 |   6.14% |  8.88% |   50 |  7.15% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 23 | 00:02:27 (  5) |  0.01 |   8 | 60% |  250 |   3.98% |  7.04% |  500 |  5.44% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 24 | 00:02:31 (  4) |  0.10 |   4 | 30% |  250 |   3.07% |  8.27% |   50 |  7.92% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 25 | 00:02:48 ( 17) |  0.10 | 128 | 95% |  250 |   5.79% |  8.12% |   50 |  8.18% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 26 | 00:02:51 (  4) |  0.01 |   4 | 30% |  500 |   2.87% |  8.00% |  450 |  8.18% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 27 | 00:02:60 (  9) |  0.30 | 128 | 30% |  500 |   2.57% |  5.78% |   50 |  5.51% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 28 | 00:03:10 ( 10) |  0.01 |  32 | 95% |  500 |   5.33% |  7.92% |  450 |  6.63% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 29 | 00:03:27 ( 17) |  0.30 | 128 | 95% |  250 |   6.15% |  7.29% |   10 |  7.44% |   75
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 30 | 00:03:31 (  4) |  0.01 |   4 | 95% | 1000 |   3.32% |  9.20% |  450 |  8.29% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 31 | 00:03:34 (  4) |  0.10 |   4 | 30% | 1000 |   3.61% |  8.82% |   50 |  8.25% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 32 | 00:03:38 (  4) |  0.01 |   4 | 30% |  250 |   3.05% |  7.94% |  500 |  7.71% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 33 | 00:03:56 ( 18) |  0.10 | 128 | 60% |  250 |   4.41% |  8.26% |   75 |  8.73% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 34 | 00:04:02 (  6) |  0.30 |   8 | 60% | 1000 |   5.24% |  7.92% |   10 |  7.36% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 35 | 00:04:15 ( 14) |  0.01 |  32 | 60% |  250 |   4.74% |  8.71% |  500 |  7.32% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 36 | 00:04:29 ( 13) |  0.01 | 128 | 30% |  250 |   4.96% |  8.65% |  500 |  8.50% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 37 | 00:19:57 (928) |  0.01 |   8 | 95% | 1000 |   5.27% |  8.79% |  350 |  6.70% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 38 | 00:20:01 (  4) |  0.30 |   4 | 60% |  250 |   4.43% |  6.55% |  100 |  5.87% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 39 | 00:20:06 (  6) |  0.01 |  32 | 30% | 1000 |   4.26% |  8.60% |  450 |  8.37% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 40 | 00:20:18 ( 12) |  0.01 |  32 | 30% |  250 |   5.00% |  8.64% |  500 |  8.28% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 41 | 00:20:23 (  5) |  0.10 |   8 | 30% |  250 |   4.04% |  8.15% |   75 |  7.18% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 42 | 00:20:31 (  8) |  0.30 |  32 | 30% |  500 |   2.57% |  5.78% |   50 |  5.51% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 43 | 00:20:38 (  6) |  0.01 |  32 | 95% | 1000 |   5.24% |  8.68% |  300 |  7.00% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 44 | 00:35:54 (917) |  0.10 |  32 | 95% |  250 |   4.98% |  8.32% |   50 |  8.01% |  250
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 45 | 00:36:03 (  9) |  0.01 | 128 | 60% |  500 |   5.03% |  8.64% |  100 |  7.27% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 46 | 00:36:10 (  6) |  0.30 | 128 | 95% | 1000 |   4.85% |  8.67% |   10 |  7.34% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 47 | 00:36:24 ( 15) |  0.01 |  32 | 95% |  250 |   4.94% |  8.26% |  500 |  7.34% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 48 | 00:51:33 (909) |  0.10 |  32 | 95% |  500 |   6.00% |  8.17% |   50 |  7.65% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 49 | 00:51:37 (  4) |  0.10 |   4 | 60% |  250 |   4.01% |  8.02% |  100 |  7.34% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 50 | 00:51:40 (  3) |  0.30 |   4 | 30% |  500 |   1.66% |  7.29% |   50 |  6.54% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 51 | 00:51:44 (  4) |  0.01 |   4 | 95% |  500 |   2.89% |  7.67% |  500 |  6.84% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 52 | 00:51:50 (  6) |  0.10 |  32 | 60% | 1000 |   4.27% |  8.18% |   75 |  7.97% |  250
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 53 | 00:51:60 (  9) |  0.30 | 128 | 60% |  500 |   5.23% |  7.18% |   25 |  7.30% |   25
# Lookahead:  5 | Train: 1134 | Test: 63 | Params:  54 | Train configs: 6
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  0 | 00:00:19 ( 19) |  0.30 |  32 | 60% | 1000 |  10.75% |  6.78% |   25 |  5.35% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  1 | 00:00:26 (  7) |  0.10 |   8 | 60% |  250 |   7.02% |  7.81% |  150 |  6.75% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  2 | 00:17:51 (1044) |  0.30 |   8 | 30% |  250 |   6.51% |  7.08% |  200 |  7.92% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  3 | 00:17:58 (  8) |  0.01 |   8 | 95% |  250 |  10.55% |  7.23% |  450 |  6.73% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  4 | 00:18:05 (  7) |  0.10 |   8 | 30% | 1000 |   7.24% |  7.28% |  350 |  5.65% |  350
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  5 | 00:18:26 ( 21) |  0.30 | 128 | 95% | 1000 |   7.83% |  6.33% |  150 |  7.12% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  6 | 00:18:33 (  7) |  0.10 |   8 | 95% | 1000 |   5.52% |  7.01% |  250 |  5.59% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  7 | 00:18:40 (  7) |  0.30 |   8 | 30% |  500 |   8.62% |  7.09% |   50 |  5.64% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  8 | 00:19:02 ( 22) |  0.10 | 128 | 30% | 1000 |   7.60% |  7.23% |  150 |  7.14% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  9 | 00:19:24 ( 22) |  0.10 | 128 | 95% | 1000 |   8.11% |  7.13% |  100 |  6.12% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 10 | 00:19:32 (  8) |  0.30 |   8 | 60% | 1000 |  10.00% |  7.12% |  400 |  7.15% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 11 | 00:20:08 ( 36) |  0.01 | 128 | 95% |  500 |   9.41% |  7.58% |  250 |  7.51% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 12 | 00:20:42 ( 34) |  0.01 | 128 | 30% |  500 |   7.22% |  7.77% |  500 |  6.15% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 13 | 00:21:01 ( 19) |  0.30 |  32 | 30% |  500 |   7.20% |  6.70% |  250 |  6.88% |  350
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 14 | 00:21:09 (  8) |  0.01 |   8 | 60% |  500 |  10.38% |  6.50% |  500 |  4.52% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 15 | 00:21:17 (  8) |  0.30 |   8 | 60% |  250 |   9.58% |  6.17% |   50 |  6.68% |   75
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 16 | 00:21:36 ( 19) |  0.01 |  32 | 95% | 1000 |   8.03% |  6.57% |  500 |  5.62% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 17 | 00:21:43 (  8) |  0.10 |   8 | 60% |  500 |   7.33% |  8.00% |  100 |  6.34% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 18 | 00:22:01 ( 18) |  0.30 |  32 | 95% |  250 |   9.65% |  7.70% |   25 |  7.52% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 19 | 00:22:20 ( 19) |  0.30 |  32 | 30% | 1000 |   7.36% |  7.18% |   50 |  6.54% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 20 | 00:23:21 ( 61) |  0.30 | 128 | 95% |  250 |   8.12% |  6.99% |   10 |  6.50% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 21 | 00:23:26 (  5) |  0.01 |   4 | 30% |  250 |   7.61% |  6.30% |  500 |  6.39% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 22 | 00:23:31 (  5) |  0.10 |   4 | 95% | 1000 |   8.65% |  6.79% |  500 |  5.93% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 23 | 00:24:09 ( 38) |  0.01 | 128 | 60% |  500 |   9.35% |  7.87% |  500 |  6.44% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 24 | 00:24:14 (  5) |  0.30 |   4 | 95% |  250 |   7.45% |  6.78% |  100 |  6.73% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 25 | 00:24:21 (  7) |  0.30 |   8 | 95% |  250 |   8.88% |  7.88% |  100 |  8.40% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 26 | 00:24:43 ( 23) |  0.10 | 128 | 60% | 1000 |   8.25% |  7.38% |  100 |  6.27% |  250
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 27 | 00:24:49 (  5) |  0.30 |   4 | 60% |  250 |   9.13% |  7.53% |  100 |  5.74% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 28 | 00:24:54 (  6) |  0.01 |   4 | 60% |  500 |   9.72% |  5.35% |  500 |  4.94% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 29 | 00:25:02 (  8) |  0.01 |   8 | 30% | 1000 |   5.95% |  5.85% |  450 |  4.90% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 30 | 00:26:01 ( 59) |  0.30 | 128 | 30% |  250 |   7.81% |  5.75% |   25 |  5.76% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 31 | 00:26:21 ( 19) |  0.01 |  32 | 30% |  250 |   7.36% |  8.05% |  200 |  7.36% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 32 | 00:26:26 (  5) |  0.30 |   4 | 30% | 1000 |   6.40% |  6.58% |  300 |  5.72% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 33 | 00:26:31 (  5) |  0.30 |   4 | 95% | 1000 |   9.08% |  6.73% |  500 |  5.94% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 34 | 00:26:35 (  5) |  0.10 |   4 | 95% |  250 |   9.97% |  7.51% |  300 |  6.55% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 35 | 00:26:41 (  5) |  0.30 |   4 | 60% | 1000 |   9.59% |  7.73% |  350 |  6.69% |  350
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 36 | 00:26:48 (  7) |  0.10 |   8 | 30% |  250 |   8.57% |  8.02% |  150 |  7.28% |  350
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 37 | 00:27:28 ( 40) |  0.30 | 128 | 60% |  500 |   9.73% |  8.55% |   50 |  8.91% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 38 | 00:27:46 ( 18) |  0.10 |  32 | 95% |  250 |   9.28% |  8.22% |   50 |  7.33% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 39 | 00:27:53 (  7) |  0.10 |   8 | 30% |  500 |   5.71% |  8.33% |  350 |  7.75% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 40 | 00:28:14 ( 21) |  0.30 | 128 | 30% | 1000 |   5.96% |  6.69% |  100 |  7.06% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 41 | 00:28:49 ( 34) |  0.10 | 128 | 30% |  500 |   7.91% |  8.16% |   50 |  8.11% |  350
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 42 | 00:29:09 ( 20) |  0.10 |  32 | 95% | 1000 |   7.80% |  7.65% |  250 |  7.75% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 43 | 00:30:13 ( 64) |  0.30 | 128 | 60% |  250 |   7.73% |  7.11% |   10 |  6.06% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 44 | 00:30:33 ( 20) |  0.01 |  32 | 30% |  500 |   6.77% |  7.65% |  450 |  5.93% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 45 | 00:30:38 (  5) |  0.01 |   4 | 30% |  500 |   7.70% |  5.83% |  500 |  5.56% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 46 | 00:30:43 (  5) |  0.30 |   4 | 60% |  500 |   9.27% |  7.22% |  300 |  6.18% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 47 | 00:31:02 ( 19) |  0.30 |  32 | 60% |  250 |   8.95% |  7.44% |  100 |  7.61% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 48 | 00:31:41 ( 38) |  0.10 | 128 | 95% |  500 |   9.37% |  7.43% |  100 |  8.09% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 49 | 00:32:02 ( 21) |  0.01 | 128 | 95% | 1000 |   8.30% |  6.69% |  500 |  5.69% |   75
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 50 | 00:32:07 (  6) |  0.10 |   4 | 30% |  250 |   9.93% |  7.07% |  200 |  5.68% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 51 | 00:32:13 (  6) |  0.30 |   4 | 95% |  500 |   7.57% |  7.20% |  150 |  6.11% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 52 | 00:32:34 ( 21) |  0.10 |  32 | 60% | 1000 |   8.63% |  6.77% |  350 |  5.30% |  350
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 53 | 00:32:41 (  8) |  0.10 |   8 | 60% | 1000 |   7.70% |  6.97% |  100 |  5.56% |  150
# Lookahead:  1 | Train: 1134 | Test: 63 | Params:  54 | Train configs: 6
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  0 | 00:00:09 (  9) |  0.10 |   8 | 30% |  250 |   8.21% |  6.63% |  150 |  7.16% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  1 | 00:01:13 ( 64) |  0.01 | 128 | 60% |  250 |   8.84% |  7.35% |  300 |  7.94% |  350
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  2 | 00:01:20 (  8) |  0.01 |   8 | 95% |  250 |   8.36% |  6.24% |  500 |  7.33% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  3 | 00:01:38 ( 18) |  0.30 |  32 | 30% |  250 |   8.65% |  6.58% |   25 |  7.41% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  4 | 00:01:43 (  5) |  0.10 |   4 | 95% |  250 |   8.14% |  6.32% |  150 |  7.42% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  5 | 00:01:53 (  9) |  0.30 |   8 | 60% |  250 |   7.20% |  6.11% |   50 |  6.20% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  6 | 00:02:00 (  8) |  0.30 |   8 | 60% |  500 |   8.51% |  5.75% |   50 |  6.97% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  7 | 00:02:22 ( 22) |  0.30 | 128 | 30% | 1000 |   7.90% |  5.84% |   10 |  6.05% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  8 | 00:02:28 (  5) |  0.30 |   4 | 30% |  500 |   8.54% |  6.56% |   75 |  7.78% |   75
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  9 | 00:02:37 (  9) |  0.01 |   8 | 30% | 1000 |   8.65% |  6.58% |  500 |  7.45% |  350
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 10 | 00:03:39 ( 62) |  0.10 | 128 | 95% |  250 |   8.22% |  5.86% |   10 |  6.18% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 11 | 00:03:58 ( 19) |  0.01 |  32 | 30% | 1000 |   9.08% |  6.80% |  500 |  7.07% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 12 | 00:04:38 ( 40) |  0.30 | 128 | 95% |  500 |   8.18% |  5.55% |   10 |  5.94% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 13 | 00:05:19 ( 41) |  0.30 | 128 | 60% |  500 |   7.47% |  5.30% |   10 |  5.88% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 14 | 00:06:25 ( 66) |  0.10 | 128 | 60% |  250 |   7.92% |  6.26% |   25 |  6.91% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 15 | 00:06:33 (  8) |  0.30 |   8 | 60% | 1000 |   7.60% |  6.49% |  300 |  7.82% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 16 | 00:06:54 ( 21) |  0.01 |  32 | 30% |  250 |   8.65% |  7.16% |  500 |  7.30% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 17 | 00:07:01 (  7) |  0.30 |   8 | 95% |  250 |   8.14% |  7.09% |   50 |  7.65% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 18 | 00:07:11 ( 10) |  0.01 |   8 | 30% |  250 |   8.43% |  6.54% |  500 |  6.77% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 19 | 00:07:16 (  5) |  0.10 |   4 | 95% |  500 |   8.50% |  6.82% |  250 |  7.44% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 20 | 00:08:17 ( 61) |  0.01 | 128 | 30% |  250 |   8.70% |  7.12% |  500 |  7.12% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 21 | 00:08:37 ( 21) |  0.30 |  32 | 60% |  500 |   8.43% |  6.29% |   50 |  7.37% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 22 | 00:09:18 ( 41) |  0.10 | 128 | 60% |  500 |   8.47% |  6.52% |   50 |  6.92% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 23 | 00:09:27 (  9) |  0.10 |   8 | 95% | 1000 |   8.27% |  6.46% |  150 |  7.03% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 24 | 00:09:34 (  7) |  0.10 |   8 | 30% |  500 |   9.27% |  6.71% |  150 |  7.70% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 25 | 00:09:43 (  9) |  0.10 |   8 | 95% |  250 |   8.57% |  6.21% |  150 |  7.47% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 26 | 00:10:48 ( 66) |  0.30 | 128 | 60% |  250 |   7.34% |  5.02% |   10 |  5.19% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 27 | 00:11:09 ( 21) |  0.01 |  32 | 95% | 1000 |   9.06% |  7.02% |  500 |  7.85% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 28 | 00:11:33 ( 24) |  0.01 | 128 | 95% | 1000 |   9.01% |  7.10% |  400 |  7.95% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 29 | 00:12:13 ( 40) |  0.10 | 128 | 95% |  500 |   9.14% |  6.31% |   25 |  7.15% |   75
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 30 | 00:12:34 ( 21) |  0.01 |  32 | 30% |  500 |   8.90% |  7.10% |  500 |  7.09% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 31 | 00:12:41 (  6) |  0.30 |   4 | 95% | 1000 |   8.16% |  6.33% |  150 |  7.14% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 32 | 00:13:17 ( 36) |  0.01 | 128 | 30% |  500 |   8.97% |  7.31% |  500 |  7.63% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 33 | 00:13:37 ( 20) |  0.30 |  32 | 30% |  500 |   8.44% |  6.62% |   25 |  7.73% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 34 | 00:13:58 ( 21) |  0.10 |  32 | 60% |  250 |   8.17% |  6.07% |   25 |  6.14% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 35 | 00:14:04 (  6) |  0.01 |   4 | 95% |  250 |   7.94% |  5.41% |  500 |  6.33% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 36 | 00:14:10 (  6) |  0.01 |   4 | 30% | 1000 |   8.10% |  5.36% |  500 |  5.69% |  350
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 37 | 00:14:16 (  6) |  0.10 |   4 | 60% |  500 |   8.07% |  5.97% |  450 |  7.54% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 38 | 00:14:22 (  6) |  0.01 |   4 | 60% | 1000 |   8.02% |  5.13% |  500 |  5.80% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 39 | 00:14:43 ( 21) |  0.10 |  32 | 30% | 1000 |   8.88% |  6.57% |   75 |  7.23% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 40 | 00:15:06 ( 23) |  0.10 | 128 | 30% | 1000 |   8.54% |  6.67% |   50 |  7.10% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 41 | 00:15:27 ( 21) |  0.10 |  32 | 30% |  500 |   8.67% |  6.98% |   50 |  6.95% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 42 | 00:15:46 ( 20) |  0.10 |  32 | 30% |  250 |   9.45% |  7.75% |   25 |  8.03% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 43 | 00:16:10 ( 24) |  0.30 | 128 | 60% | 1000 |   7.15% |  5.87% |   25 |  6.50% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 44 | 00:16:19 (  8) |  0.10 |   8 | 30% | 1000 |   8.50% |  7.04% |   75 |  7.54% |   75
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 45 | 00:16:40 ( 21) |  0.30 |  32 | 95% | 1000 |   7.29% |  5.89% |   50 |  6.65% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 46 | 00:17:01 ( 21) |  0.10 |  32 | 95% |  250 |   9.13% |  6.31% |   25 |  7.65% |   75
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 47 | 00:17:10 (  9) |  0.10 |   8 | 95% |  500 |   8.14% |  6.19% |  350 |  7.15% |  450
# ---------{dates}
# ---------{dates}
# ...
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 38 | 00:05:06 (  6) |  0.10 |   8 | 60% |  500 |  12.88% |  12.13% |   25 |  13.67% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 39 | 00:05:25 ( 19) |  0.01 | 128 | 95% |  250 |   8.84% |  11.37% |  150 |  14.18% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 40 | 00:05:32 (  7) |  0.30 | 128 | 30% | 1000 |  13.23% |  12.48% |   50 |  13.63% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 41 | 00:05:39 (  7) |  0.01 |   8 | 95% | 1000 |   7.55% |  15.11% |  100 |  15.36% |   75
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 42 | 00:05:43 (  4) |  0.01 |   4 | 95% |  250 |   5.25% |  9.94% |  500 |  12.52% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 43 | 00:05:47 (  4) |  0.01 |   4 | 30% |  500 |   3.60% |  9.87% |  500 |  10.68% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 44 | 00:06:05 ( 18) |  0.30 |  32 | 95% |  250 |  11.85% |  9.86% |   10 |  10.27% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 45 | 00:06:09 (  4) |  0.30 |   4 | 30% |  250 |  14.67% |  11.88% |   50 |  11.97% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 46 | 00:06:26 ( 17) |  0.10 |  32 | 95% |  250 |  11.45% |  11.90% |   10 |  13.60% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 47 | 00:06:43 ( 17) |  0.01 |  32 | 95% |  250 |   8.60% |  11.22% |   75 |  13.33% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 48 | 00:06:55 ( 12) |  0.01 | 128 | 95% |  500 |   8.40% |  12.84% |   50 |  13.67% |  250
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 49 | 00:07:06 ( 12) |  0.30 |  32 | 95% |  500 |  13.31% |  11.29% |   10 |  11.31% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 50 | 00:07:18 ( 12) |  0.30 | 128 | 60% |  500 |  12.82% |  13.12% |   10 |  14.18% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 51 | 00:07:24 (  6) |  0.10 |   8 | 95% |  250 |  10.89% |  13.00% |   25 |  14.51% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 52 | 00:07:30 (  6) |  0.01 |   8 | 30% |  250 |   5.95% |  11.54% |  500 |  11.62% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 53 | 00:07:40 (  9) |  0.10 |  32 | 30% |  500 |  12.69% |  11.72% |  200 |  14.75% |  200
# Lookahead: 21 | Train: 1134 | Test: 63 | Params:  54 | Train configs: 6
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  0 | 00:00:06 (  6) |  0.10 |   4 | 60% |  500 |  13.80% |  9.97% |  450 |  10.42% |  350
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  1 | 00:00:12 (  6) |  0.10 |   4 | 95% |  500 |  15.23% |  9.45% |  500 |  8.84% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  2 | 00:00:36 ( 24) |  0.10 | 128 | 60% | 1000 |   8.14% |  10.93% |  150 |  12.08% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  3 | 00:00:45 (  9) |  0.10 |   8 | 60% |  250 |  15.94% |  12.34% |  450 |  12.71% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  4 | 00:01:06 ( 21) |  0.30 |  32 | 60% |  500 |  10.15% |  9.50% |   75 |  10.92% |   75
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  5 | 00:01:17 ( 10) |  0.01 |   8 | 60% | 1000 |  11.41% |  7.79% |  100 |  8.97% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  6 | 00:01:38 ( 21) |  0.30 | 128 | 30% | 1000 |  22.47% |  10.35% |  150 |  10.56% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  7 | 00:01:59 ( 21) |  0.01 |  32 | 95% | 1000 |   6.96% |  9.05% |  500 |  9.64% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  8 | 00:02:07 (  8) |  0.01 |   4 | 60% | 1000 |  10.80% |  5.68% |  200 |  6.44% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	  9 | 00:02:29 ( 22) |  0.01 |  32 | 95% |  250 |  12.77% |  10.53% |  500 |  10.90% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 10 | 00:02:50 ( 22) |  0.10 |  32 | 60% | 1000 |   8.18% |  9.76% |  300 |  10.51% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 11 | 00:03:29 ( 38) |  0.30 | 128 | 30% |  500 |  24.50% |  14.06% |   25 |  16.01% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 12 | 00:03:38 (  9) |  0.01 |   8 | 60% |  250 |  12.75% |  8.95% |  500 |  8.83% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 13 | 00:04:19 ( 41) |  0.10 | 128 | 60% |  500 |  11.00% |  10.53% |   50 |  10.80% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 14 | 00:04:59 ( 40) |  0.10 | 128 | 95% |  500 |  10.78% |  11.86% |   50 |  12.95% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 15 | 00:05:59 ( 60) |  0.10 | 128 | 30% |  250 |  14.02% |  10.14% |   50 |  10.35% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 16 | 00:06:19 ( 20) |  0.10 |  32 | 95% |  250 |  13.99% |  11.28% |  100 |  11.72% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 17 | 00:07:18 ( 59) |  0.01 | 128 | 30% |  250 |  11.18% |  10.48% |  500 |  11.07% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 18 | 00:07:23 (  5) |  0.30 |   4 | 30% |  250 |  15.02% |  9.36% |  100 |  9.36% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 19 | 00:07:44 ( 21) |  0.30 |  32 | 95% |  500 |   8.55% |  11.31% |   25 |  12.80% |   75
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 20 | 00:08:05 ( 21) |  0.10 |  32 | 95% |  500 |  14.58% |  11.89% |  100 |  13.27% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 21 | 00:08:25 ( 21) |  0.10 |  32 | 30% |  500 |  14.81% |  11.44% |  350 |  12.04% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 22 | 00:08:34 (  9) |  0.01 |   8 | 95% |  500 |  10.69% |  9.24% |   75 |  9.19% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 23 | 00:08:56 ( 21) |  0.01 |  32 | 60% | 1000 |   7.74% |  9.95% |  150 |  10.66% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 24 | 00:09:59 ( 63) |  0.10 | 128 | 95% |  250 |  11.92% |  10.64% |   50 |  10.63% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 25 | 00:10:22 ( 23) |  0.01 |  32 | 60% |  250 |  11.97% |  10.04% |  500 |  10.39% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 26 | 00:10:45 ( 22) |  0.01 |  32 | 95% |  500 |  12.68% |  10.53% |  500 |  10.97% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 27 | 00:10:52 (  8) |  0.30 |   8 | 30% |  250 |  17.50% |  11.65% |   75 |  11.57% |  150
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 28 | 00:10:58 (  6) |  0.10 |   4 | 30% | 1000 |  17.78% |  8.92% |  450 |  9.34% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 29 | 00:11:04 (  6) |  0.30 |   4 | 95% |  250 |  13.82% |  8.97% |  250 |  8.62% |  250
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 30 | 00:11:12 (  8) |  0.10 |   8 | 95% |  250 |  16.99% |  10.61% |  300 |  10.99% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 31 | 00:11:52 ( 40) |  0.30 | 128 | 95% |  500 |  11.11% |  7.16% |  150 |  6.70% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 32 | 00:11:58 (  6) |  0.01 |   4 | 95% | 1000 |   8.63% |  6.75% |   10 |  9.30% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 33 | 00:12:19 ( 21) |  0.01 | 128 | 30% | 1000 |   8.87% |  8.57% |  500 |  8.56% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 34 | 00:12:25 (  6) |  0.10 |   4 | 95% |  250 |  16.64% |  9.57% |  500 |  9.85% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 35 | 00:12:31 (  6) |  0.10 |   4 | 60% | 1000 |  15.77% |  8.86% |  500 |  9.39% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 36 | 00:12:40 (  9) |  0.01 |   8 | 30% | 1000 |   8.08% |  6.77% |  150 |  7.95% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 37 | 00:12:48 (  8) |  0.10 |   8 | 95% |  500 |  13.84% |  12.05% |  500 |  13.75% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 38 | 00:12:56 (  8) |  0.30 |   8 | 95% | 1000 |  12.65% |  9.33% |  450 |  8.48% |  250
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 39 | 00:13:02 (  6) |  0.10 |   4 | 95% | 1000 |  14.90% |  9.05% |  450 |  8.53% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 40 | 00:13:10 (  9) |  0.01 |   8 | 30% |  500 |   8.03% |  7.43% |  500 |  7.32% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 41 | 00:13:31 ( 21) |  0.01 |  32 | 30% |  500 |  10.86% |  9.98% |  500 |  9.64% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 42 | 00:13:38 (  7) |  0.01 |   4 | 60% |  500 |  10.50% |  6.43% |   10 |  6.12% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 43 | 00:13:59 ( 21) |  0.30 |  32 | 95% | 1000 |   8.58% |  8.63% |   75 |  8.74% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 44 | 00:14:05 (  6) |  0.01 |   4 | 30% |  500 |   8.33% |  5.28% |  500 |  5.34% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 45 | 00:14:27 ( 22) |  0.10 |  32 | 60% |  250 |  14.06% |  11.38% |   75 |  12.69% |  250
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 46 | 00:15:27 ( 60) |  0.30 | 128 | 30% |  250 |  15.25% |  9.94% |   50 |  10.22% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 47 | 00:15:50 ( 23) |  0.01 | 128 | 95% | 1000 |   4.89% |  9.67% |  500 |  10.54% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 48 | 00:15:56 (  6) |  0.30 |   4 | 30% | 1000 |  18.26% |  10.51% |  300 |  10.29% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 49 | 00:16:03 (  7) |  0.30 |   4 | 60% |  250 |  10.70% |  7.82% |  200 |  8.54% |  450
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 50 | 00:17:06 ( 63) |  0.30 | 128 | 95% |  250 |  11.15% |  7.90% |   25 |  7.16% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 51 | 00:17:28 ( 23) |  0.30 |  32 | 60% | 1000 |  11.86% |  8.55% |   50 |  10.33% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 52 | 00:17:51 ( 22) |  0.01 |  32 | 60% |  500 |  12.06% |  10.49% |  500 |  10.68% |  500
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# 	 53 | 00:18:15 ( 24) |  0.01 | 128 | 60% | 1000 |   6.99% |  10.06% |  150 |  11.38% |  150

# %% [markdown]
# ## CatBoost Model Tuning

# %% [markdown]
# We repeat a similar process for CatBoost - see book and CatBoost [docs](https://catboost.ai/docs/concepts/about.html) for detail.

# %% [markdown]
# ### Hyperparameter Options

# %%
param_names = ['max_depth', 'min_child_samples']

max_depth_opts = [3, 5, 7, 9]
min_child_samples_opts = [20, 250, 500]

# %%
cv_params = list(product(max_depth_opts,
                         min_child_samples_opts))
n_params = len(cv_params)

# %% [markdown]
# ### Train/Test Period Lengths

# %%
lookaheads = [1, 5, 21]
# lookaheads = [21]
label_dict = dict(zip(lookaheads, labels))

# %%
train_lengths = [int(4.5 * 252), 252]
# train_lengths = [int(4.5 * 252)]
test_lengths = [63]

# %%
test_params = list(product(lookaheads,
                           train_lengths,
                           test_lengths))

# %% [markdown]
# ### Custom Loss Function

# %%
class CatBoostIC(object):
    """Custom IC eval metric for CatBoost"""

    def is_max_optimal(self):
        # Returns whether great values of metric are better
        return True

    def evaluate(self, approxes, target, weight):
        target = np.array(target)
        approxes = np.array(approxes).reshape(-1)
        rho = spearmanr(approxes, target)[0]
        return rho, 1

    def get_final_error(self, error, weight):
        # Returns final value of metric based on error and weight
        return error

# %% [markdown]
# ### Run Cross-Validation

# %%
cb_store = Path(results_path / 'tuning_catboost.h5')

# %%
num_iterations = [10, 25, 50, 75] + list(range(100, 1001, 100))
num_boost_round = num_iterations[-1]

# %%
metric_cols = (param_names + ['t', 'daily_ic_mean', 'daily_ic_mean_n',
                              'daily_ic_median', 'daily_ic_median_n'] +
               [str(n) for n in num_iterations])

# %%
for lookahead, train_length, test_length in test_params:
    cvp = np.random.choice(list(range(n_params)),
                           size=int(n_params / 1),
                           replace=False)
    cv_params_ = [cv_params[i] for i in cvp]

    n_splits = int(2 * YEAR / test_length)
    print(f'Lookahead: {lookahead:2.0f} | Train: {train_length:3.0f} | '
          f'Test: {test_length:2.0f} | Params: {len(cv_params_):3.0f} | Train configs: {len(test_params)}')

    cv = MultipleTimeSeriesCV(n_splits=n_splits,
                              lookahead=lookahead,
                              test_period_length=test_length,
                              train_period_length=train_length)

    label = label_dict[lookahead]
    outcome_data = data.loc[:, features + [label]].dropna()
    cat_cols_idx = [outcome_data.columns.get_loc(c) for c in categoricals]
    catboost_data = Pool(label=outcome_data[label],
                         data=outcome_data.drop(label, axis=1),
                         cat_features=cat_cols_idx)
    predictions, metrics, feature_importance, daily_ic = [], [], [], []
    key = f'{lookahead}/{train_length}/{test_length}'
    T = 0
    for p, param_vals in enumerate(cv_params_):
        params = dict(zip(param_names, param_vals))
        # uncomment if running with GPU
#         params['task_type'] = 'GPU'

        start = time()
        cv_preds, nrounds = [], []
        ic_cv = defaultdict(list)
        for i, (train_idx, test_idx) in enumerate(cv.split(X=outcome_data)):
            train_set = catboost_data.slice(train_idx.tolist())

            model = CatBoostRegressor(**params)
            model.fit(X=train_set,
                      verbose_eval=False)

            test_set = outcome_data.iloc[test_idx, :]
            X_test = test_set.loc[:, model.feature_names_]
            y_test = test_set.loc[:, label]
            y_pred = {str(n): model.predict(X_test, ntree_end=n)
                      for n in num_iterations}
            cv_preds.append(y_test.to_frame(
                'y_test').assign(**y_pred).assign(i=i))

        cv_preds = pd.concat(cv_preds).assign(**params)
        predictions.append(cv_preds)
        by_day = cv_preds.groupby(level='date')
        ic_by_day = pd.concat([by_day.apply(lambda x: spearmanr(x.y_test, x[str(n)])[0]).to_frame(n)
                               for n in num_iterations], axis=1)
        daily_ic_mean = ic_by_day.mean()
        daily_ic_mean_n = daily_ic_mean.idxmax()
        daily_ic_median = ic_by_day.median()
        daily_ic_median_n = daily_ic_median.idxmax()

        ic = [spearmanr(cv_preds.y_test, cv_preds[str(n)])[0]
              for n in num_iterations]
        t = time() - start
        T += t
        metrics = pd.Series(list(param_vals) +
                            [t, daily_ic_mean.max(), daily_ic_mean_n,
                             daily_ic_median.max(), daily_ic_median_n] + ic,
                            index=metric_cols)
        msg = f'{p:3.0f} | {format_time(T)} ({t:3.0f}) | {params["max_depth"]:3.0f} | {params["min_child_samples"]:4.0f} | '
        msg += f' {max(ic):6.2%} | {ic_by_day.mean().max(): 6.2%} | {daily_ic_mean_n: 4.0f} | {ic_by_day.median().max(): 6.2%} | {daily_ic_median_n: 4.0f}'
        print(msg)
        metrics.to_hdf(cb_store, 'metrics/' + key)
        ic_by_day.assign(**params).to_hdf(cb_store, 'daily_ic/' + key)
        cv_preds.to_hdf(cb_store, 'predictions/' + key)
# Out:
# Lookahead:  1 | Train: 1134 | Test: 63 | Params:  12 | Train configs: 6
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   0 | 00:49:29 (2969) |   9 |  250 |   7.20% |  6.61% |  100 |  7.32% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   1 | 00:50:04 ( 35) |   3 |  500 |   8.69% |  7.80% |  800 |  9.07% |  700
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   2 | 01:07:27 (1043) |   7 |  500 |   8.61% |  6.48% |   25 |  7.26% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   3 | 01:08:02 ( 35) |   3 |   20 |   8.69% |  7.80% |  800 |  9.07% |  700
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   4 | 01:39:05 (1863) |   5 |   20 |   8.61% |  6.87% |  300 |  7.71% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   5 | 01:57:54 (1129) |   7 |  250 |   8.61% |  6.48% |   25 |  7.26% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   6 | 02:00:22 (148) |   9 |   20 |   7.20% |  6.61% |  100 |  7.32% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   7 | 02:23:18 (1376) |   9 |  500 |   7.20% |  6.61% |  100 |  7.32% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   8 | 02:39:39 (980) |   5 |  500 |   8.61% |  6.87% |  300 |  7.71% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   9 | 02:56:01 (983) |   5 |  250 |   8.61% |  6.87% |  300 |  7.71% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#  10 | 03:28:50 (1968) |   7 |   20 |   8.61% |  6.48% |   25 |  7.26% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#  11 | 03:29:24 ( 35) |   3 |  250 |   8.69% |  7.80% |  800 |  9.07% |  700
# Lookahead:  1 | Train: 252 | Test: 63 | Params:  12 | Train configs: 6
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   0 | 00:00:31 ( 31) |   7 |   20 |   6.68% |  7.55% |  100 |  8.74% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   1 | 00:00:45 ( 13) |   3 |  500 |   7.62% |  6.98% |  300 |  7.68% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   2 | 00:18:34 (1069) |   9 |  500 |   6.86% |  6.39% |   50 |  7.87% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   3 | 00:19:49 ( 76) |   9 |   20 |   6.86% |  6.39% |   50 |  7.87% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   4 | 00:20:21 ( 32) |   7 |  250 |   6.68% |  7.55% |  100 |  8.74% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   5 | 00:52:43 (1942) |   9 |  250 |   6.86% |  6.39% |   50 |  7.87% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   6 | 00:53:03 ( 21) |   5 |   20 |   7.30% |  7.37% |  200 |  8.51% |  600
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   7 | 01:08:38 (934) |   3 |  250 |   7.62% |  6.98% |  300 |  7.68% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   8 | 01:08:58 ( 21) |   5 |  500 |   7.30% |  7.37% |  200 |  8.51% |  600
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   9 | 01:09:30 ( 31) |   7 |  500 |   6.68% |  7.55% |  100 |  8.74% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#  10 | 01:09:50 ( 21) |   5 |  250 |   7.30% |  7.37% |  200 |  8.51% |  600
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#  11 | 01:10:04 ( 14) |   3 |   20 |   7.62% |  6.98% |  300 |  7.68% |  300
# Lookahead:  5 | Train: 1134 | Test: 63 | Params:  12 | Train configs: 6
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   0 | 00:20:51 (1251) |   9 |   20 |   7.63% |  8.74% |  100 |  9.35% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   1 | 00:37:10 (979) |   9 |  250 |   7.63% |  8.74% |  100 |  9.35% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   2 | 00:54:39 (1049) |   9 |  500 |   7.63% |  8.74% |  100 |  9.35% |  100
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   3 | 00:55:15 ( 36) |   3 |  500 |  11.05% |  9.24% |  300 |  7.16% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   4 | 01:21:12 (1557) |   7 |   20 |   9.82% |  8.83% |  200 |  8.38% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   5 | 01:22:50 ( 98) |   3 |   20 |  11.05% |  9.24% |  300 |  7.16% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   6 | 01:40:09 (1039) |   5 |  250 |   9.05% |  8.73% |  400 |  8.77% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   7 | 01:41:04 ( 55) |   5 |   20 |   9.05% |  8.73% |  400 |  8.77% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   8 | 01:41:39 ( 35) |   3 |  250 |  11.05% |  9.24% |  300 |  7.16% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   9 | 02:15:47 (2047) |   7 |  250 |   9.82% |  8.83% |  200 |  8.38% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#  10 | 02:16:43 ( 56) |   5 |  500 |   9.05% |  8.73% |  400 |  8.77% |  400
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#  11 | 02:34:19 (1056) |   7 |  500 |   9.82% |  8.83% |  200 |  8.38% |  200
# Lookahead:  5 | Train: 252 | Test: 63 | Params:  12 | Train configs: 6
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   0 | 00:00:32 ( 32) |   7 |  250 |   4.71% |  9.00% |  100 |  8.82% |  600
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   1 | 00:01:04 ( 32) |   7 |  500 |   4.71% |  9.00% |  100 |  8.82% |  600
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   2 | 00:18:50 (1067) |   9 |  250 |   4.59% |  8.43% |  800 |  7.92% |   75
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   3 | 00:19:22 ( 32) |   7 |   20 |   4.71% |  9.00% |  100 |  8.82% |  600
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   4 | 00:20:41 ( 78) |   9 |  500 |   4.59% |  8.43% |  800 |  7.92% |   75
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   5 | 00:36:32 (952) |   3 |  500 |   5.51% |  9.11% |  200 |  9.06% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   6 | 00:36:54 ( 21) |   5 |  500 |   5.44% |  8.97% |  1000 |  8.90% |  900
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   7 | 00:37:15 ( 21) |   5 |   20 |   5.44% |  8.97% |  1000 |  8.90% |  900
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   8 | 00:37:28 ( 14) |   3 |  250 |   5.51% |  9.11% |  200 |  9.06% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   9 | 00:37:49 ( 21) |   5 |  250 |   5.44% |  8.97% |  1000 |  8.90% |  900
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#  10 | 00:54:56 (1027) |   9 |   20 |   4.59% |  8.43% |  800 |  7.92% |   75
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#  11 | 00:55:10 ( 14) |   3 |   20 |   5.51% |  9.11% |  200 |  9.06% |  300
# Lookahead: 21 | Train: 1134 | Test: 63 | Params:  12 | Train configs: 6
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   0 | 00:00:54 ( 54) |   5 |  500 |  13.27% |  11.38% |  100 |  11.67% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   1 | 00:01:29 ( 35) |   3 |  250 |  16.32% |  10.48% |  300 |  11.09% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   2 | 00:34:49 (2001) |   7 |   20 |  16.78% |  11.99% |   50 |  11.72% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   3 | 00:44:10 (561) |   9 |  250 |  11.79% |  10.16% |   25 |  11.71% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   4 | 01:00:59 (1009) |   7 |  500 |  16.78% |  11.99% |   50 |  11.72% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   5 | 01:01:33 ( 34) |   3 |   20 |  16.32% |  10.48% |  300 |  11.09% |  300
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   6 | 01:02:57 ( 84) |   5 |   20 |  13.27% |  11.38% |  100 |  11.67% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   7 | 01:35:59 (1982) |   9 |  500 |  11.79% |  10.16% |   25 |  11.71% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   8 | 01:37:16 ( 77) |   7 |  250 |  16.78% |  11.99% |   50 |  11.72% |   50
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   9 | 01:43:45 (389) |   5 |  250 |  13.27% |  11.38% |  100 |  11.67% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#  10 | 02:02:27 (1122) |   9 |   20 |  11.79% |  10.16% |   25 |  11.71% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#  11 | 02:03:03 ( 36) |   3 |  500 |  16.32% |  10.48% |  300 |  11.09% |  300
# Lookahead: 21 | Train: 252 | Test: 63 | Params:  12 | Train configs: 6
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   0 | 00:18:31 (1111) |   9 |   20 |   9.80% |  11.92% |   25 |  12.22% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   1 | 00:35:13 (1001) |   9 |  250 |   9.80% |  11.92% |   25 |  12.22% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   2 | 00:35:27 ( 14) |   3 |  500 |  13.43% |  14.04% |  200 |  12.85% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   3 | 00:35:49 ( 22) |   5 |   20 |  11.16% |  13.39% |  100 |  14.26% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   4 | 00:41:51 (362) |   9 |  500 |   9.80% |  11.92% |   25 |  12.22% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   5 | 00:42:05 ( 14) |   3 |   20 |  13.43% |  14.04% |  200 |  12.85% |  200
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   6 | 00:42:27 ( 22) |   5 |  250 |  11.16% |  13.39% |  100 |  14.26% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   7 | 00:58:20 (953) |   7 |  500 |   9.66% |  12.99% |   50 |  13.64% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   8 | 00:58:42 ( 22) |   5 |  500 |  11.16% |  13.39% |  100 |  14.26% |   25
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#   9 | 00:59:15 ( 33) |   7 |  250 |   9.66% |  12.99% |   50 |  13.64% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#  10 | 00:59:48 ( 33) |   7 |   20 |   9.66% |  12.99% |   50 |  13.64% |   10
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
# ---------{dates}
#  11 | 01:00:03 ( 14) |   3 |  250 |  13.43% |  14.04% |  200 |  12.85% |  200
