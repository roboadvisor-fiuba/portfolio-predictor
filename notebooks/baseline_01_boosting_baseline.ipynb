# %% [markdown]
# # Adaptive and Gradient Boosting

# %% [markdown]
# In this notebook, we demonstrate the use of AdaBoost and gradient boosting, incuding several state-of-the-art implementations of this very powerful and flexible algorithm that greatly speed up training.
#
# We use the stock return dataset with a few engineered factors created in [Chapter 4 on Alpha Factor Research](../04_alpha_factor_research) in the notebook [feature_engineering](../04_alpha_factor_research/00_data/feature_engineering.ipynb).

# %% [markdown]
# ## Update

# %% [markdown]
# This notebook now uses `sklearn.ensemble.HistGradientBoostingClassifier`.

# %% [markdown]
# ## Imports and Settings

# %%
# %matplotlib inline

import sys, os
import warnings
from time import time
from itertools import product
import joblib
from pathlib import Path
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import cross_validate
from sklearn.dummy import DummyClassifier
from sklearn.tree import DecisionTreeClassifier
# needed for HistGradientBoostingClassifier
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, HistGradientBoostingClassifier
from sklearn.inspection import partial_dependence, PartialDependenceDisplay
from sklearn.metrics import roc_auc_score

# %%
sys.path.insert(1, os.path.join(sys.path[0], '..'))
from utils import format_time

# %%
results_path = Path('results', 'baseline')
if not results_path.exists():
    results_path.mkdir(exist_ok=True, parents=True)

# %%
warnings.filterwarnings('ignore')
sns.set_style("whitegrid")
idx = pd.IndexSlice
np.random.seed(42)

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# ### Get source

# %% [markdown]
# We use the `engineered_features` dataset created in [Chapter 4, Alpha Factor Research](../04_alpha_factor_research)

# %% [markdown]
# Set data store location:

# %%
DATA_STORE = './data.h5'

# %%
def get_data(start='2010', end='2018', task='classification', holding_period=1, dropna=False):
    
    idx = pd.IndexSlice
    target = f'return_{holding_period}m'
    with pd.HDFStore(DATA_STORE) as store:
        df = store['merval/monthly']

    if start is not None and end is not None:
        df = df.loc[idx[:, start: end], :]
    if dropna:
        df = df.dropna()
        
    y = (df[target]>0).astype(int)
    X = df.drop([c for c in df.columns if c.startswith('target')], axis=1)
    return y, X

# %% [markdown]
# ### Factorize Categories

# %% [markdown]
# Define columns with categorical data:

# %%
cat_cols = ['year', 'month', 'sector']

# %% [markdown]
# Integer-encode categorical columns:

# %%
def factorize_cats(df, cats=['sector']):
    cat_cols = ['year', 'month'] + cats
    for cat in cats:
        df[cat] = pd.factorize(df[cat])[0]
    df.loc[:, cat_cols] = df.loc[:, cat_cols].fillna(-1).astype(int)
    return df

# %% [markdown]
# ### One-Hot Encoding

# %% [markdown]
# Create dummy variables from categorical columns if needed:

# %%
def get_one_hot_data(df, cols=cat_cols[:-1]):
    df = pd.get_dummies(df,
                        columns=cols + ['sector'],
                        prefix=cols + [''],
                        prefix_sep=['_'] * len(cols) + [''])
    return df.rename(columns={c: c.replace('.0', '') for c in df.columns})

# %% [markdown]
# ### Get Holdout Set

# %% [markdown]
# Create holdout test set to estimate generalization error after cross-validation:

# %%
def get_holdout_set(target, features, period=6):
    idx = pd.IndexSlice
    label = target.name
    dates = np.sort(y.index.get_level_values('date').unique())
    cv_start, cv_end = dates[0], dates[-period - 2]
    holdout_start, holdout_end = dates[-period - 1], dates[-1]

    df = features.join(target.to_frame())
    train = df.loc[idx[:, cv_start: cv_end], :]
    y_train, X_train = train[label], train.drop(label, axis=1)

    test = df.loc[idx[:, holdout_start: holdout_end], :]
    y_test, X_test = test[label], test.drop(label, axis=1)
    return y_train, X_train, y_test, X_test

# %% [markdown]
# ## Load Data

# %% [markdown]
# The algorithms in this chapter use a dataset generated in [Chapter 4 on Alpha Factor Research](../04_alpha_factor_research) in the notebook [feature-engineering](../04_alpha_factor_research/00_data/feature_engineering.ipynb) that needs to be executed first.

# %%
y, features = get_data()
X_dummies = get_one_hot_data(features)
X_factors = factorize_cats(features)

# %%
X_factors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1785 entries, ('ALUA.BA', Timestamp('2016-02-29 00:00:00')) to ('YPFD.BA', Timestamp('2018-12-31 00:00:00'))
# Data columns (total 28 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   money_volume   1785 non-null   float64
#  1   atr            1785 non-null   float64
#  2   bb_down        1785 non-null   float64
#  3   bb_high        1785 non-null   float64
#  4   bb_low         1785 non-null   float64
#  5   bb_mid         1785 non-null   float64
#  6   bb_up          1785 non-null   float64
#  7   macd           1785 non-null   float64
#  8   natr           1785 non-null   float64
#  9   ppo            1785 non-null   float64
#  10  rsi            1785 non-null   float64
#  11  sector         1785 non-null   int64
#  12  return_1m      1785 non-null   float64
#  13  return_3m      1785 non-null   float64
#  14  return_6m      1785 non-null   float64
#  15  return_12m     1785 non-null   float64
#  16  beta           1785 non-null   float64
#  17  SMB            1785 non-null   float64
#  18  HML            1785 non-null   float64
#  19  RMW            1785 non-null   float64
#  20  CMA            1785 non-null   float64
#  21  momentum_3     1785 non-null   float64
#  22  momentum_6     1785 non-null   float64
#  23  momentum_3_6   1785 non-null   float64
#  24  momentum_12    1785 non-null   float64
#  25  momentum_3_12  1785 non-null   float64
#  26  year           1785 non-null   int64
#  27  month          1785 non-null   int64
# dtypes: float64(25), int64(3)
# memory usage: 403.6+ KB

# %%
y_clean, features_clean = get_data(dropna=True)
X_dummies_clean = get_one_hot_data(features_clean)
X_factors_clean = factorize_cats(features_clean)

# %% [markdown]
# ## Cross-Validation Setup

# %% [markdown]
# ### Custom Time Series KFold Generator

# %% [markdown]
# Custom Time Series KFold generator.

# %%
class OneStepTimeSeriesSplit:
    """Generates tuples of train_idx, test_idx pairs
    Assumes the index contains a level labeled 'date'"""

    def __init__(self, n_splits=3, test_period_length=1, shuffle=False):
        self.n_splits = n_splits
        self.test_period_length = test_period_length
        self.shuffle = shuffle

    @staticmethod
    def chunks(l, n):
        for i in range(0, len(l), n):
            yield l[i:i + n]

    def split(self, X, y=None, groups=None):
        unique_dates = (X.index
                        .get_level_values('date')
                        .unique()
                        .sort_values(ascending=False)
                        [:self.n_splits*self.test_period_length])

        dates = X.reset_index()[['date']]
        for test_date in self.chunks(unique_dates, self.test_period_length):
            train_idx = dates[dates.date < min(test_date)].index
            test_idx = dates[dates.date.isin(test_date)].index
            if self.shuffle:
                np.random.shuffle(list(train_idx))
            yield train_idx, test_idx

    def get_n_splits(self, X, y, groups=None):
        return self.n_splits

# %%
cv = OneStepTimeSeriesSplit(n_splits=12, 
                            test_period_length=1, 
                            shuffle=False)

# %%
run_time = {}

# %% [markdown]
# ### CV Metrics

# %% [markdown]
# Define some metrics for use with cross-validation:

# %%
metrics = {'balanced_accuracy': 'Accuracy' ,
           'roc_auc': 'AUC',
           'neg_log_loss': 'Log Loss',
           'f1_weighted': 'F1',
           'precision_weighted': 'Precision',
           'recall_weighted': 'Recall'
}

# %% [markdown]
# Helper function that runs cross-validation for the various algorithms.

# %%
def run_cv(clf, X=X_dummies, y=y, metrics=metrics, cv=cv, fit_params=None, n_jobs=-1):
    start = time()
    scores = cross_validate(estimator=clf,
                            X=X, 
                            y=y,
                            scoring=list(metrics.keys()),
                            cv=cv,
                            return_train_score=True,
                            n_jobs=n_jobs,
                            verbose=1,
                            fit_params=fit_params)
    duration = time() - start
    return scores, duration

# %% [markdown]
# ### CV Result Handler Functions

# %% [markdown]
# The following helper functions manipulate and plot the cross-validation results to produce the outputs below.

# %%
def stack_results(scores):
    columns = pd.MultiIndex.from_tuples(
        [tuple(m.split('_', 1)) for m in scores.keys()],
        names=['Dataset', 'Metric'])
    data = np.array(list(scores.values())).T
    df = (pd.DataFrame(data=data,
                       columns=columns)
          .iloc[:, 2:])
    results = pd.melt(df, value_name='Value')
    results.Metric = results.Metric.apply(lambda x: metrics.get(x))
    results.Dataset = results.Dataset.str.capitalize()
    return results

# %%
def plot_result(df, model=None, fname=None):
    m = list(metrics.values())
    g = sns.catplot(x='Dataset', 
                    y='Value', 
                    hue='Dataset', 
                    col='Metric',
                    data=df, 
                    col_order=m,
                    order=['Train', 'Test'],
                    kind="box", 
                    col_wrap=3,
                    sharey=False,
                    height=4, aspect=1.2)
    df = df.groupby(['Metric', 'Dataset']).Value.mean().unstack().loc[m]
    for i, ax in enumerate(g.axes.flat):
        s = f"Train: {df.loc[m[i], 'Train']:>7.4f}\nTest:  {df.loc[m[i], 'Test'] :>7.4f}"
        ax.text(0.05, 0.85, s, fontsize=10, transform=ax.transAxes, 
                bbox=dict(facecolor='white', edgecolor='grey', boxstyle='round,pad=0.5'))
    g.fig.suptitle(model, fontsize=16)
    g.fig.subplots_adjust(top=.9)
    if fname:
        g.savefig(fname, dpi=300);

# %% [markdown]
# ## Baseline Classifier

# %% [markdown]
# `sklearn` provides the [DummyClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html) that makes predictions using simple rule and is useful as a simple baseline to compare with the other (real) classifiers we use below.
#
# The `stratified` rule generates predictions based on the training set’s class distribution, i.e. always predicts the most frequent class.

# %%
dummy_clf = DummyClassifier(strategy='stratified',
                            random_state=42)

# %%
algo = 'dummy_clf'

# %%
fname = results_path / f'{algo}.joblib'
if not Path(fname).exists():
    dummy_cv_result, run_time[algo] = run_cv(dummy_clf)
    joblib.dump(dummy_cv_result, fname)
else:
    dummy_cv_result = joblib.load(fname)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  12 | elapsed:    3.4s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    3.4s finished

# %% [markdown]
# Unsurprisingly, it produces results near the AUC threshold for arbitrary predictions of 0.5:

# %%
dummy_result = stack_results(dummy_cv_result)
dummy_result.groupby(['Metric', 'Dataset']).Value.mean().unstack()
# Out:
# Dataset         Test      Train
# Metric
# AUC         0.436002   0.498678
# Accuracy    0.436002   0.498678
# F1          0.478824   0.502518
# Log Loss  -20.730990 -17.939457
# Precision   0.646554   0.502803
# Recall      0.424837   0.502285

# %%
plot_result(dummy_result, model='Dummy Classifier')

# %% [markdown]
# ## RandomForest

# %% [markdown]
# For comparison, we train a `RandomForestClassifier` as presented in [Chapter 11 on Decision Trees and Random Forests](../11_decision_trees_random_forests/02_random_forest.ipynb).

# %% [markdown]
# ### Configure

# %%
rf_clf = RandomForestClassifier(n_estimators=100,
                                criterion='gini', 
                                max_depth=None, 
                                min_samples_split=2, 
                                min_samples_leaf=1, 
                                min_weight_fraction_leaf=0.0, 
                                max_leaf_nodes=None, 
                                min_impurity_decrease=0.0, 
                                bootstrap=True, 
                                oob_score=True, 
                                n_jobs=-1,
                                random_state=42, 
                                verbose=1)

# %% [markdown]
# ### Cross-validate

# %%
algo = 'random_forest'

# %%
fname = results_path / f'{algo}.joblib'
if not Path(fname).exists():
    rf_cv_result, run_time[algo] = run_cv(rf_clf, y=y_clean, X=X_dummies_clean)
    joblib.dump(rf_cv_result, fname)
else:
    rf_cv_result = joblib.load(fname)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.4s finished
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  12 | elapsed:    1.4s remaining:    0.3s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    1.4s finished

# %% [markdown]
# ### Plot Results

# %%
rf_result = stack_results(rf_cv_result)
rf_result.groupby(['Metric', 'Dataset']).Value.mean().unstack()
# Out:
# Dataset        Test     Train
# Metric
# AUC        1.000000  1.000000
# Accuracy   1.000000  1.000000
# F1         1.000000  1.000000
# Log Loss  -0.056797 -0.019247
# Precision  1.000000  1.000000
# Recall     1.000000  1.000000

# %%
plot_result(rf_result, model='Random Forest')

# %% [markdown]
# ## scikit-learn: AdaBoost

# %% [markdown]
# As part of its [ensemble module](https://scikit-learn.org/stable/modules/ensemble.html#adaboost), sklearn provides an [AdaBoostClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostClassifier.html) implementation that supports two or more classes. The code examples for this section are in the notebook gbm_baseline that compares the performance of various algorithms with a dummy classifier that always predicts the most frequent class.

# %% [markdown]
# ### Base Estimator

# %% [markdown]
# We need to first define a base_estimator as a template for all ensemble members and then configure the ensemble itself. We'll use the default DecisionTreeClassifier with max_depth=1—that is, a stump with a single split. The complexity of the base_estimator is a key tuning parameter because it depends on the nature of the data.
#
# As demonstrated in the [previous chapter](../../10_decision_trees_random_forests), changes to `max_depth` should be combined with appropriate regularization constraints using adjustments to, for example, `min_samples_split`:

# %%
base_estimator = DecisionTreeClassifier(criterion='gini', 
                                        splitter='best',
                                        max_depth=1, 
                                        min_samples_split=2, 
                                        min_samples_leaf=20, 
                                        min_weight_fraction_leaf=0.0,
                                        max_features=None, 
                                        random_state=None, 
                                        max_leaf_nodes=None, 
                                        min_impurity_decrease=0.0, 
                                        class_weight=None)

# %% [markdown]
# ### AdaBoost Configuration

# %% [markdown]
# In the second step, we'll design the ensemble. The n_estimators parameter controls the number of weak learners and the learning_rate determines the contribution of each weak learner, as shown in the following code. By default, weak learners are decision tree stumps:

# %%
ada_clf = AdaBoostClassifier(base_estimator=base_estimator,
                             n_estimators=100,
                             learning_rate=1.0,
                             algorithm='SAMME.R',
                             random_state=42)

# %% [markdown]
# The main tuning parameters that are responsible for good results are `n_estimators` and the base estimator complexity because the depth of the tree controls the extent of the interaction among the features.

# %% [markdown]
# ### Cross-validate

# %% [markdown]
# We will cross-validate the AdaBoost ensemble using a custom 12-fold rolling time-series split to predict 1 month ahead for the last 12 months in the sample, using all available prior data for training, as shown in the following code:

# %%
algo = 'adaboost'

# %%
fname = results_path / f'{algo}.joblib'
if not Path(fname).exists():
    ada_cv_result, run_time[algo] = run_cv(ada_clf, y=y_clean, X=X_dummies_clean)
    joblib.dump(ada_cv_result, fname)
else:
    ada_cv_result = joblib.load(fname)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/ensemble/_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/ensemble/_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/ensemble/_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/ensemble/_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/ensemble/_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/ensemble/_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/ensemble/_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/ensemble/_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/ensemble/_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/ensemble/_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/ensemble/_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/ensemble/_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Done  10 out of  12 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    0.1s finished

# %% [markdown]
# ### Plot Result

# %%
ada_result = stack_results(ada_cv_result)
ada_result.groupby(['Metric', 'Dataset']).Value.mean().unstack()
# Out:
# Dataset            Test         Train
# Metric
# AUC        1.000000e+00  1.000000e+00
# Accuracy   1.000000e+00  1.000000e+00
# F1         1.000000e+00  1.000000e+00
# Log Loss  -2.220446e-16 -2.220446e-16
# Precision  1.000000e+00  1.000000e+00
# Recall     1.000000e+00  1.000000e+00

# %%
plot_result(ada_result, model='AdaBoost')

# %% [markdown]
# ## scikit-learn: HistGradientBoostingClassifier

# %% [markdown]
# The ensemble module of sklearn contains an implementation of gradient boosting trees for regression and classification, both binary and multiclass.

# %% [markdown]
# ### Configure

# %% [markdown]
# The following [HistGradientBoostingClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.HistGradientBoostingClassifier.html) initialization code illustrates the key tuning parameters that we previously introduced, in addition to those that we are familiar with from looking at standalone decision tree models.

# %% [markdown]
# This estimator is much faster than [GradientBoostingClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html#sklearn.ensemble.GradientBoostingClassifier) for big datasets (n_samples >= 10 000).
#
# This estimator has native support for missing values (NaNs). During training, the tree grower learns at each split point whether samples with missing values should go to the left or right child, based on the potential gain. When predicting, samples with missing values are assigned to the left or right child consequently. If no missing values were encountered for a given feature during training, then samples with missing values are mapped to whichever child has the most samples.

# %%
gb_clf = HistGradientBoostingClassifier(loss='log_loss',              
                                        learning_rate=0.1,          # regulates the contribution of each tree
                                        max_iter=100,               # number of boosting stages
                                        min_samples_leaf=20,
                                        max_depth=None,
                                        random_state=None,
                                        max_leaf_nodes=31,           # opt value depends on feature interaction
                                        warm_start=False,
#                                         early_stopping=True,
#                                         scoring='loss',
#                                         validation_fraction=0.1,
#                                         n_iter_no_change=None,
                                        verbose=0,
                                        tol=0.0001)

# %% [markdown]
# ### Cross-validate

# %%
algo = 'sklearn_gbm'

# %%
fname = results_path / f'{algo}.joblib'
if not Path(fname).exists():
    gb_cv_result, run_time[algo] = run_cv(gb_clf, y=y_clean, X=X_dummies_clean)
    joblib.dump(gb_cv_result, fname)
else:
    gb_cv_result = joblib.load(fname)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  12 | elapsed:    0.6s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    0.7s finished

# %% [markdown]
# ### Plot Results

# %%
gb_result = stack_results(gb_cv_result)
gb_result.groupby(['Metric', 'Dataset']).Value.mean().unstack()
# Out:
# Dataset        Test     Train
# Metric
# AUC        1.000000  1.000000
# Accuracy   1.000000  1.000000
# F1         1.000000  1.000000
# Log Loss  -0.000022 -0.000022
# Precision  1.000000  1.000000
# Recall     1.000000  1.000000

# %%
plot_result(gb_result, model='Gradient Boosting Classifier')

# %% [markdown]
# ### Partial Dependence Plots

# %% [markdown]
# Drop time periods to avoid over-reliance for in-sample fit.

# %%
X_ = X_factors_clean.drop(['year', 'month'], axis=1)

# %%
fname = results_path / f'{algo}_model.joblib'
if not Path(fname).exists():
    gb_clf.fit(y=y_clean, X=X_)
    joblib.dump(gb_clf, fname)
else:
    gb_clf = joblib.load(fname)

# %%
# mean accuracy
gb_clf.score(X=X_, y=y_clean)
# Out:
# 1.0

# %%
y_score = gb_clf.predict_proba(X_)[:, 1]
roc_auc_score(y_score=y_score, y_true=y_clean)
# Out:
# 1.0

# %% [markdown]
# #### One-way and two-way partial depende plots

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))

PartialDependenceDisplay.from_estimator(
    estimator=gb_clf,
    X=X_,
    features=['return_12m', 'return_6m', 'CMA', ('return_12m', 'return_6m')],
    percentiles=(0.05, 0.95),
    n_jobs=-1,
    n_cols=2,
    response_method='decision_function',
    grid_resolution=250,
    ax=axes)

for i, j in product([0, 1], repeat=2):
    if i!=1 or j!= 0:
        axes[i][j].xaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0%}'.format(y))) 

axes[1][1].yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0%}'.format(y))) 

axes[0][0].set_ylabel('Partial Dependence')
axes[1][0].set_ylabel('Partial Dependence')
axes[0][0].set_xlabel('12-Months Return')
axes[0][1].set_xlabel('6-Months Return')
axes[1][0].set_xlabel('Conservative Minus Aggressive')

axes[1][1].set_xlabel('12-Month Return')
axes[1][1].set_ylabel('6-Months Return')
fig.suptitle('Partial Dependence Plots', fontsize=16)
fig.tight_layout()
fig.subplots_adjust(top=.95)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[118], line 3
#       1 fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))
# ----> 3 PartialDependenceDisplay.from_estimator(
#       4     estimator=gb_clf,
#       5     X=X_.fillna(method='ffill').fillna(method='bfill'),
#       6     features=['return_12m', 'return_6m', 'CMA', ('return_12m', 'return_6m')],
#       7     percentiles=(0.05, 0.95),
#       8     n_jobs=-1,
#       9     n_cols=2,
#      10     response_method='decision_function',
#      11     grid_resolution=250,
#      12     ax=axes)
#      14 for i, j in product([0, 1], repeat=2):
#      15     if i!=1 or j!= 0:
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/inspection/_plot/partial_dependence.py:758, in PartialDependenceDisplay.from_estimator(cls, estimator, X, features, sample_weight, categorical_features, feature_names, target, response_method, n_cols, grid_resolution, percentiles, method, n_jobs, verbose, line_kw, ice_lines_kw, pd_line_kw, contour_kw, ax, kind, centered, subsample, random_state)
#     745             deciles[fx] = mquantiles(X_col, prob=np.arange(0.1, 1.0, 0.1))
#     747 display = PartialDependenceDisplay(
#     748     pd_results=pd_results,
#     749     features=features,
#    (...)
#     756     is_categorical=is_categorical,
#     757 )
# --> 758 return display.plot(
#     759     ax=ax,
#     760     n_cols=n_cols,
#     761     line_kw=line_kw,
#     762     ice_lines_kw=ice_lines_kw,
#     763     pd_line_kw=pd_line_kw,
#     764     contour_kw=contour_kw,
#     765     centered=centered,
#     766 )
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/inspection/_plot/partial_dependence.py:1461, in PartialDependenceDisplay.plot(self, ax, n_cols, line_kw, ice_lines_kw, pd_line_kw, contour_kw, bar_kw, heatmap_kw, pdp_lim, centered)
#    1443         self._plot_one_way_partial_dependence(
#    1444             kind_plot,
#    1445             preds,
#    (...)
#    1458             pdp_lim,
#    1459         )
#    1460     else:
# -> 1461         self._plot_two_way_partial_dependence(
#    1462             avg_preds,
#    1463             feature_values,
#    1464             feature_idx,
#    1465             axi,
#    1466             pd_plot_idx,
#    1467             Z_level,
#    1468             contour_kw,
#    1469             cat[0] and cat[1],
#    1470             heatmap_kw,
#    1471         )
#    1473 return self
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/inspection/_plot/partial_dependence.py:1072, in PartialDependenceDisplay._plot_two_way_partial_dependence(self, avg_preds, feature_values, feature_idx, ax, pd_plot_idx, Z_level, contour_kw, categorical, heatmap_kw)
#    1070 XX, YY = np.meshgrid(feature_values[0], feature_values[1])
#    1071 Z = avg_preds[self.target_idx].T
# -> 1072 CS = ax.contour(XX, YY, Z, levels=Z_level, linewidths=0.5, colors="k")
#    1073 contour_idx = np.unravel_index(pd_plot_idx, self.contours_.shape)
#    1074 self.contours_[contour_idx] = ax.contourf(
#    1075     XX,
#    1076     YY,
#    (...)
#    1081     **contour_kw,
#    1082 )
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# -> 1446         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448     bound = new_sig.bind(ax, *args, **kwargs)
#    1449     auto_label = (bound.arguments.get(label_namer)
#    1450                   or bound.kwargs.get(label_namer))
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/axes/_axes.py:6449, in Axes.contour(self, *args, **kwargs)
#    6440 """
#    6441 Plot contour lines.
#    6442
#    (...)
#    6446 %(contour_doc)s
#    6447 """
#    6448 kwargs['filled'] = False
# -> 6449 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6450 self._request_autoscale_view()
#    6451 return contours
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/contour.py:769, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, *args, **kwargs)
#     765 if self.negative_linestyles is None:
#     766     self.negative_linestyles = \
#     767         mpl.rcParams['contour.negative_linestyle']
# --> 769 kwargs = self._process_args(*args, **kwargs)
#     770 self._process_levels()
#     772 self._extend_min = self.extend in ['min', 'both']
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/contour.py:1411, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1408         corner_mask = mpl.rcParams['contour.corner_mask']
#    1409 self._corner_mask = corner_mask
# -> 1411 x, y, z = self._contour_args(args, kwargs)
#    1413 contour_generator = contourpy.contour_generator(
#    1414     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1415     line_type=contourpy.LineType.SeparateCode,
#    1416     fill_type=contourpy.FillType.OuterCode,
#    1417     chunk_size=self.nchunk)
#    1419 t = self.get_transform()
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/contour.py:1460, in QuadContourSet._contour_args(self, args, kwargs)
#    1458     _api.warn_external('Log scale: values of z <= 0 have been masked')
#    1459     self.zmin = float(z.min())
# -> 1460 self._process_contour_level_args(args, z.dtype)
#    1461 return (x, y, z)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/contour.py:1143, in ContourSet._process_contour_level_args(self, args, z_dtype)
#    1141     raise ValueError("Filled contours require at least 2 levels.")
#    1142 if len(self.levels) > 1 and np.min(np.diff(self.levels)) <= 0.0:
# -> 1143     raise ValueError("Contour levels must be increasing")
#
# ValueError: Contour levels must be increasing

# %% [markdown]
# #### Two-way partial dependence as 3D plot

# %%
results.keys()
# Out:
# dict_keys(['grid_values', 'values', 'average'])

# %%
targets = ['return_12m', 'return_6m']
results = partial_dependence(estimator=gb_clf,
                               features=targets,
                               X=X_,
                               grid_resolution=100)
XX, YY = np.meshgrid(axes[0], axes[1])
Z = pdp[0].reshape(list(map(np.size, axes))).T

fig = plt.figure(figsize=(14, 8))
ax = Axes3D(fig)
surface = ax.plot_surface(XX, YY, Z,
                          rstride=1,
                          cstride=1,
                          cmap=plt.cm.BuPu,
                          edgecolor='k')
ax.set_xlabel('12-Month Return')
ax.set_ylabel('6-Month Return')
ax.set_zlabel('Partial Dependence')
ax.view_init(elev=22, azim=30)
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0%}'.format(y))) 
ax.xaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0%}'.format(y))) 

# fig.colorbar(surface)
fig.suptitle('Partial Dependence by 6- and 12-month Returns', fontsize=16)
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[133], line 7
#       2 results = partial_dependence(estimator=gb_clf,
#       3                                features=targets,
#       4                                X=X_,
#       5                                grid_resolution=100)
#       6 XX, YY = np.meshgrid(axes[0], axes[1])
# ----> 7 Z = pdp[0].reshape(list(map(np.size, axes))).T
#       9 fig = plt.figure(figsize=(14, 8))
#      10 ax = Axes3D(fig)
#
# ValueError: maximum supported dimension for an ndarray is 32, found 100

# %% [markdown]
# ## XGBoost

# %% [markdown]
# See XGBoost [docs](https://xgboost.readthedocs.io/en/latest/python/python_api.html) for details on parameters and usage.

# %% [markdown]
# ### Configure

# %%
xgb_clf = XGBClassifier(max_depth=3,                  # Maximum tree depth for base learners.
                        learning_rate=0.1,            # Boosting learning rate (xgb's "eta")
                        n_estimators=100,             # Number of boosted trees to fit.
                        silent=True,                  # Whether to print messages while running
                        objective='binary:logistic',  # Task and objective or custom objective function
                        booster='gbtree',             # Select booster: gbtree, gblinear or dart
#                         tree_method='gpu_hist',
                        n_jobs=-1,                    # Number of parallel threads
                        gamma=0,                      # Min loss reduction for further splits
                        min_child_weight=1,           # Min sum of sample weight(hessian) needed
                        max_delta_step=0,             # Max delta step for each tree's weight estimation
                        subsample=1,                  # Subsample ratio of training samples
                        colsample_bytree=1,           # Subsample ratio of cols for each tree
                        colsample_bylevel=1,          # Subsample ratio of cols for each split
                        reg_alpha=0,                  # L1 regularization term on weights
                        reg_lambda=1,                 # L2 regularization term on weights
                        scale_pos_weight=1,           # Balancing class weights
                        base_score=0.5,               # Initial prediction score; global bias
                        random_state=42)              # random seed

# %% [markdown]
# ### Cross-validate

# %%
algo = 'xgboost'

# %%
fname = results_path / f'{algo}.joblib'
if not Path(fname).exists():
    xgb_cv_result, run_time[algo] = run_cv(xgb_clf)
    joblib.dump(xgb_cv_result, fname)
else:
    xgb_cv_result = joblib.load(fname)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [00:30:53] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1713397655897/work/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [00:30:53] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1713397655897/work/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [00:30:53] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1713397655897/work/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [00:30:53] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1713397655897/work/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [00:30:53] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1713397655897/work/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [00:30:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1713397655897/work/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [00:30:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1713397655897/work/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [00:30:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1713397655897/work/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [00:30:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1713397655897/work/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [00:30:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1713397655897/work/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [00:30:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1713397655897/work/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [00:30:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1713397655897/work/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [Parallel(n_jobs=-1)]: Done  10 out of  12 | elapsed:    2.9s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    2.9s finished

# %% [markdown]
# ### Plot Results

# %%
xbg_result = stack_results(xgb_cv_result)
xbg_result.groupby(['Metric', 'Dataset']).Value.mean().unstack()
# Out:
# Dataset        Test     Train
# Metric
# AUC        1.000000  1.000000
# Accuracy   1.000000  1.000000
# F1         1.000000  1.000000
# Log Loss  -0.002326 -0.001763
# Precision  1.000000  1.000000
# Recall     1.000000  1.000000

# %%
plot_result(xbg_result, model='XG Boost', fname=f'figures/{algo}_cv_result')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 plot_result(xbg_result, model='XG Boost', fname=f'figures/{algo}_cv_result')
#
# Cell In[66], line 22, in plot_result(df, model, fname)
#      20 g.fig.subplots_adjust(top=.9)
#      21 if fname:
# ---> 22     g.savefig(fname, dpi=300)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/seaborn/axisgrid.py:100, in _BaseGrid.savefig(self, *args, **kwargs)
#      98 kwargs = kwargs.copy()
#      99 kwargs.setdefault("bbox_inches", "tight")
# --> 100 self.figure.savefig(*args, **kwargs)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/figure.py:3378, in Figure.savefig(self, fname, transparent, **kwargs)
#    3374     for ax in self.axes:
#    3375         stack.enter_context(
#    3376             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3378 self.canvas.print_figure(fname, **kwargs)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/backend_bases.py:2366, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2362 try:
#    2363     # _get_renderer may change the figure dpi (as vector formats
#    2364     # force the figure dpi to 72), so we need to set it again here.
#    2365     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366         result = print_method(
#    2367             filename,
#    2368             facecolor=facecolor,
#    2369             edgecolor=edgecolor,
#    2370             orientation=orientation,
#    2371             bbox_inches_restore=_bbox_inches_restore,
#    2372             **kwargs)
#    2373 finally:
#    2374     if bbox_inches and restore_bbox:
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/backend_bases.py:2232, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2228     optional_kws = {  # Passed by print_figure for other renderers.
#    2229         "dpi", "facecolor", "edgecolor", "orientation",
#    2230         "bbox_inches_restore"}
#    2231     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234 else:  # Let third-parties do as they see fit.
#    2235     print_method = meth
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     462 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     463     """
#     464     Write the figure to a PNG file.
#     465
#    (...)
#     507         *metadata*, including the default 'Software' key.
#     508     """
# --> 509     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:458, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     453 """
#     454 Draw the canvas, then save it using `.image.imsave` (to which
#     455 *pil_kwargs* and *metadata* are forwarded).
#     456 """
#     457 FigureCanvasAgg.draw(self)
# --> 458 mpl.image.imsave(
#     459     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/image.py:1689, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1687 pil_kwargs.setdefault("format", format)
#    1688 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1689 image.save(fname, **pil_kwargs)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/PIL/Image.py:2456, in Image.save(self, fp, format, **params)
#    2454         fp = builtins.open(filename, "r+b")
#    2455     else:
# -> 2456         fp = builtins.open(filename, "w+b")
#    2458 try:
#    2459     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/tomas/roboadvisor/portfolio-predictor/notebooks/figures/xgboost_cv_result.png'

# %% [markdown]
# ### Feature Importance

# %%
xgb_clf.fit(X=X_dummies, y=y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=None, colsample_bytree=1,
#               device=None, early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=0, max_depth=3,
#               max_leaves=None, min_child_weight=1, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=-1, num_parallel_tree=None, random_state=42, ...)

# %%
fi = pd.Series(xgb_clf.feature_importances_, 
               index=X_dummies.columns)

# %%
fi.nlargest(25).sort_values().plot.barh(figsize=(10, 5), 
                                        title='Feature Importance')
sns.despine()
plt.tight_layout();

# %% [markdown]
# ## LightGBM

# %% [markdown]
# See LightGBM [docs](https://lightgbm.readthedocs.io/en/latest/Parameters.html) for details on parameters and usage.

# %% [markdown]
# ### Configure

# %%
lgb_clf = LGBMClassifier(boosting_type='gbdt',
#                          device='gpu',
                         objective='binary',          # learning task
                         metric='auc',
                         num_leaves=31,               # Maximum tree leaves for base learners.
                         max_depth=-1,                # Maximum tree depth for base learners, -1 means no limit.
                         learning_rate=0.1,          # Adaptive lr via callback override in .fit() method  
                         n_estimators=100,            # Number of boosted trees to fit
                         subsample_for_bin=200000,    # Number of samples for constructing bins.
                         class_weight=None,           # dict, 'balanced' or None
                         min_split_gain=0.0,          # Minimum loss reduction for further split
                         min_child_weight=0.001,      # Minimum sum of instance weight(hessian)
                         min_child_samples=20,        # Minimum number of data need in a child(leaf)
                         subsample=1.0,               # Subsample ratio of training samples
                         subsample_freq=0,            # Frequency of subsampling, <=0: disabled
                         colsample_bytree=1.0,        # Subsampling ratio of features
                         reg_alpha=0.0,               # L1 regularization term on weights
                         reg_lambda=0.0,              # L2 regularization term on weights
                         random_state=42,             # Random number seed; default: C++ seed
                         n_jobs=-1,                   # Number of parallel threads.
                         silent=False,
                         importance_type='gain',      # default: 'split' or 'gain'
                        )

# %% [markdown]
# ### Cross-Validate

# %% [markdown]
# #### Using categorical features

# %%
algo = 'lgb_factors'

# %%
fname = results_path / f'{algo}.joblib'
if not Path(fname).exists():
    lgb_factor_cv_result, run_time[algo] = run_cv(lgb_clf, X=X_factors, fit_params={'categorical_feature': cat_cols})
    joblib.dump(lgb_factor_cv_result, fname)
else:
    lgb_factor_cv_result = joblib.load(fname)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Met categorical feature which contains sparse values. Consider renumbering to consecutive integers started from zero
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Number of positive: 857, number of negative: 775
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001251 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6404
# [LightGBM] [Info] Number of data points in the train set: 1632, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.525123 -> initscore=0.100575
# [LightGBM] [Info] Start training from score 0.100575
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Met categorical feature which contains sparse values. Consider renumbering to consecutive integers started from zero
# [LightGBM] [Warning] Met categorical feature which contains sparse values. Consider renumbering to consecutive integers started from zero
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Number of positive: 860, number of negative: 823
# [LightGBM] [Info] Number of positive: 811, number of negative: 770
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Met categorical feature which contains sparse values. Consider renumbering to consecutive integers started from zero
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001814 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001807 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6404
# [LightGBM] [Info] Total Bins 6404
# [LightGBM] [Info] Number of data points in the train set: 1581, number of used features: 28[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Info] Number of data points in the train set: 1683, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.510992 -> initscore=0.043976
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.512966 -> initscore=0.051878
# [LightGBM] [Info] Start training from score 0.043976
# [LightGBM] [Info] Start training from score 0.051878
# [LightGBM] [Info] Number of positive: 754, number of negative: 674
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Met categorical feature which contains sparse values. Consider renumbering to consecutive integers started from zero
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001474 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6404
# [LightGBM] [Info] Number of data points in the train set: 1428, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.528011 -> initscore=0.112162
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Start training from score 0.112162
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 798, number of negative: 732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001429 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6404
# [LightGBM] [Info] Number of data points in the train set: 1530, number of used features: 28
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.521569 -> initscore=0.086328
# [LightGBM] [Info] Start training from score 0.086328
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Met categorical feature which contains sparse values. Consider renumbering to consecutive integers started from zero
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 765, number of negative: 714
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000603 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6404
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of data points in the train set: 1479, number of used features: 28
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.517241 -> initscore=0.068993
# [LightGBM] [Info] Start training from score 0.068993
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Met categorical feature which contains sparse values. Consider renumbering to consecutive integers started from zero
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 886, number of negative: 848
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000712 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6404
# [LightGBM] [Info] Number of data points in the train set: 1734, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.510957 -> initscore=0.043836
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Start training from score 0.043836
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Met categorical feature which contains sparse values. Consider renumbering to consecutive integers started from zero
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Number of positive: 743, number of negative: 634
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000841 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6404
# [LightGBM] [Info] Number of data points in the train set: 1377, number of used features: 28
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.539579 -> initscore=0.158647
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Start training from score 0.158647
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Met categorical feature which contains sparse values. Consider renumbering to consecutive integers started from zero
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Number of positive: 732, number of negative: 594
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001782 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6404
# [LightGBM] [Info] Number of data points in the train set: 1326, number of used features: 28
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [Parallel(n_jobs=-1)]: Done  10 out of  12 | elapsed:    1.3s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    1.3s finished

# %% [markdown]
# ##### Plot Results

# %%
lgb_factor_result = stack_results(lgb_factor_cv_result)
lgb_factor_result.groupby(['Metric', 'Dataset']).Value.mean().unstack()
# Out:
# Dataset        Test     Train
# Metric
# AUC        1.000000  1.000000
# Accuracy   1.000000  1.000000
# F1         1.000000  1.000000
# Log Loss  -0.000022 -0.000022
# Precision  1.000000  1.000000
# Recall     1.000000  1.000000

# %%
plot_result(lgb_factor_result, model='Light GBM | Factors', fname=f'figures/{algo}_cv_result')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 plot_result(lgb_factor_result, model='Light GBM | Factors', fname=f'figures/{algo}_cv_result')
#
# Cell In[66], line 22, in plot_result(df, model, fname)
#      20 g.fig.subplots_adjust(top=.9)
#      21 if fname:
# ---> 22     g.savefig(fname, dpi=300)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/seaborn/axisgrid.py:100, in _BaseGrid.savefig(self, *args, **kwargs)
#      98 kwargs = kwargs.copy()
#      99 kwargs.setdefault("bbox_inches", "tight")
# --> 100 self.figure.savefig(*args, **kwargs)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/figure.py:3378, in Figure.savefig(self, fname, transparent, **kwargs)
#    3374     for ax in self.axes:
#    3375         stack.enter_context(
#    3376             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3378 self.canvas.print_figure(fname, **kwargs)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/backend_bases.py:2366, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2362 try:
#    2363     # _get_renderer may change the figure dpi (as vector formats
#    2364     # force the figure dpi to 72), so we need to set it again here.
#    2365     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366         result = print_method(
#    2367             filename,
#    2368             facecolor=facecolor,
#    2369             edgecolor=edgecolor,
#    2370             orientation=orientation,
#    2371             bbox_inches_restore=_bbox_inches_restore,
#    2372             **kwargs)
#    2373 finally:
#    2374     if bbox_inches and restore_bbox:
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/backend_bases.py:2232, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2228     optional_kws = {  # Passed by print_figure for other renderers.
#    2229         "dpi", "facecolor", "edgecolor", "orientation",
#    2230         "bbox_inches_restore"}
#    2231     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234 else:  # Let third-parties do as they see fit.
#    2235     print_method = meth
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     462 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     463     """
#     464     Write the figure to a PNG file.
#     465
#    (...)
#     507         *metadata*, including the default 'Software' key.
#     508     """
# --> 509     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:458, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     453 """
#     454 Draw the canvas, then save it using `.image.imsave` (to which
#     455 *pil_kwargs* and *metadata* are forwarded).
#     456 """
#     457 FigureCanvasAgg.draw(self)
# --> 458 mpl.image.imsave(
#     459     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/image.py:1689, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1687 pil_kwargs.setdefault("format", format)
#    1688 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1689 image.save(fname, **pil_kwargs)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/PIL/Image.py:2456, in Image.save(self, fp, format, **params)
#    2454         fp = builtins.open(filename, "r+b")
#    2455     else:
# -> 2456         fp = builtins.open(filename, "w+b")
#    2458 try:
#    2459     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/tomas/roboadvisor/portfolio-predictor/notebooks/figures/lgb_factors_cv_result.png'

# %% [markdown]
# #### Using dummy variables

# %%
algo = 'lgb_dummies'

# %%
fname = results_path / f'{algo}.joblib'
if not Path(fname).exists():
    lgb_dummy_cv_result, run_time[algo] = run_cv(lgb_clf)
    joblib.dump(lgb_dummy_cv_result, fname)
else:
    lgb_dummy_cv_result = joblib.load(fname)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Number of positive: 886, number of negative: 848
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000432 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6427
# [LightGBM] [Info] Number of data points in the train set: 1734, number of used features: 51
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.510957 -> initscore=0.043836
# [LightGBM] [Info] Start training from score 0.043836
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Number of positive: 860, number of negative: 823
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000707 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6427
# [LightGBM] [Info] Number of data points in the train set: 1683, number of used features: 51
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.510992 -> initscore=0.043976
# [LightGBM] [Info] Start training from score 0.043976
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Number of positive: 811, number of negative: 770
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Number of positive: 857, number of negative: 775
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000723 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000966 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6427
# [LightGBM] [Info] Number of data points in the train set: 1632, number of used features: 51
# [LightGBM] [Info] Total Bins 6427
# [LightGBM] [Info] Number of data points in the train set: 1581, number of used features: 51
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.525123 -> initscore=0.100575
# [LightGBM] [Info] Start training from score 0.100575
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.512966 -> initscore=0.051878
# [LightGBM] [Info] Start training from score 0.051878
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Info] Number of positive: 798, number of negative: 732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001092 seconds.
# You can set `force_col_wise=true` to remove the overhead.[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Info] Total Bins 6427
# [LightGBM] [Info] Number of data points in the train set: 1530, number of used features: 51
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.521569 -> initscore=0.086328
# [LightGBM] [Info] Start training from score 0.086328
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Info] Number of positive: 754, number of negative: 674
# [LightGBM] [Info] Number of positive: 765, number of negative: 714
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001401 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001529 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6427
# [LightGBM] [Info] Total Bins 6427
# [LightGBM] [Info] Number of data points in the train set: 1428, number of used features: 51
# [LightGBM] [Info] Number of data points in the train set: 1479, number of used features: 51
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.528011 -> initscore=0.112162
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.517241 -> initscore=0.068993
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Start training from score 0.112162[LightGBM] [Info] Start training from score 0.068993
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 743, number of negative: 634
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001292 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6427
# [LightGBM] [Info] Number of data points in the train set: 1377, number of used features: 51
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.539579 -> initscore=0.158647
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Start training from score 0.158647
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf[LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] Unknown parameter: silent
# [Parallel(n_jobs=-1)]: Done  10 out of  12 | elapsed:    0.9s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    0.9s finished

# %% [markdown]
# ##### Plot results

# %%
lgb_dummy_result = stack_results(lgb_dummy_cv_result)
lgb_dummy_result.groupby(['Metric', 'Dataset']).Value.mean().unstack()
# Out:
# Dataset        Test     Train
# Metric
# AUC        1.000000  1.000000
# Accuracy   1.000000  1.000000
# F1         1.000000  1.000000
# Log Loss  -0.000022 -0.000022
# Precision  1.000000  1.000000
# Recall     1.000000  1.000000

# %%
plot_result(lgb_dummy_result, model='Light GBM | Factors', fname=f'figures/{algo}_cv_result')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 plot_result(lgb_dummy_result, model='Light GBM | Factors', fname=f'figures/{algo}_cv_result')
#
# Cell In[66], line 22, in plot_result(df, model, fname)
#      20 g.fig.subplots_adjust(top=.9)
#      21 if fname:
# ---> 22     g.savefig(fname, dpi=300)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/seaborn/axisgrid.py:100, in _BaseGrid.savefig(self, *args, **kwargs)
#      98 kwargs = kwargs.copy()
#      99 kwargs.setdefault("bbox_inches", "tight")
# --> 100 self.figure.savefig(*args, **kwargs)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/figure.py:3378, in Figure.savefig(self, fname, transparent, **kwargs)
#    3374     for ax in self.axes:
#    3375         stack.enter_context(
#    3376             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3378 self.canvas.print_figure(fname, **kwargs)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/backend_bases.py:2366, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2362 try:
#    2363     # _get_renderer may change the figure dpi (as vector formats
#    2364     # force the figure dpi to 72), so we need to set it again here.
#    2365     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366         result = print_method(
#    2367             filename,
#    2368             facecolor=facecolor,
#    2369             edgecolor=edgecolor,
#    2370             orientation=orientation,
#    2371             bbox_inches_restore=_bbox_inches_restore,
#    2372             **kwargs)
#    2373 finally:
#    2374     if bbox_inches and restore_bbox:
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/backend_bases.py:2232, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2228     optional_kws = {  # Passed by print_figure for other renderers.
#    2229         "dpi", "facecolor", "edgecolor", "orientation",
#    2230         "bbox_inches_restore"}
#    2231     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234 else:  # Let third-parties do as they see fit.
#    2235     print_method = meth
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     462 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     463     """
#     464     Write the figure to a PNG file.
#     465
#    (...)
#     507         *metadata*, including the default 'Software' key.
#     508     """
# --> 509     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:458, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     453 """
#     454 Draw the canvas, then save it using `.image.imsave` (to which
#     455 *pil_kwargs* and *metadata* are forwarded).
#     456 """
#     457 FigureCanvasAgg.draw(self)
# --> 458 mpl.image.imsave(
#     459     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/image.py:1689, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1687 pil_kwargs.setdefault("format", format)
#    1688 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1689 image.save(fname, **pil_kwargs)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/PIL/Image.py:2456, in Image.save(self, fp, format, **params)
#    2454         fp = builtins.open(filename, "r+b")
#    2455     else:
# -> 2456         fp = builtins.open(filename, "w+b")
#    2458 try:
#    2459     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/tomas/roboadvisor/portfolio-predictor/notebooks/figures/lgb_dummies_cv_result.png'

# %% [markdown]
# ## Catboost

# %% [markdown]
# See CatBoost [docs](https://catboost.ai/docs/concepts/python-reference_catboostclassifier.html) for details on parameters and usage.

# %% [markdown]
# ### CPU

# %% [markdown]
# #### Configure

# %%
cat_clf = CatBoostClassifier()

# %% [markdown]
# #### Cross-Validate

# %%
s = pd.Series(X_factors.columns.tolist())
cat_cols_idx = s[s.isin(cat_cols)].index.tolist()

# %% [markdown]
# Catboost requires integer values for categorical variables.

# %%
algo = 'catboost'

# %%
fname = results_path / f'{algo}.joblib'
if not Path(fname).exists():
    fit_params = {'cat_features': cat_cols_idx}
    cat_cv_result, run_time[algo] = run_cv(cat_clf,
                                           X=X_factors,
                                           fit_params=fit_params,
                                           n_jobs=-1)
    joblib.dump(cat_cv_result, fname)
else:
    cat_cv_result = joblib.load(fname)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Learning rate set to 0.012528
# Learning rate set to 0.013032
# Learning rate set to 0.012867
# Learning rate set to 0.012699
# Learning rate set to 0.012176
# Learning rate set to 0.011995
# Learning rate set to 0.01181
# Learning rate set to 0.012354
# 0:	learn: 0.6583316	total: 67.8ms	remaining: 1m 7s
# 0:	learn: 0.6620450	total: 70ms	remaining: 1m 9s
# 1:	learn: 0.6294279	total: 80ms	remaining: 39.9s
# 1:	learn: 0.6313743	total: 81.6ms	remaining: 40.7s
# 0:	learn: 0.6632137	total: 81.6ms	remaining: 1m 21s
# 0:	learn: 0.6612288	total: 86.5ms	remaining: 1m 26s
# 0:	learn: 0.6641813	total: 85.1ms	remaining: 1m 25s
# 2:	learn: 0.5998774	total: 91.6ms	remaining: 30.4s
# 0:	learn: 0.6645289	total: 81ms	remaining: 1m 20s
# 2:	learn: 0.6056593	total: 92.4ms	remaining: 30.7s
# 1:	learn: 0.6351360	total: 94.1ms	remaining: 47s
# 0:	learn: 0.6634541	total: 81.8ms	remaining: 1m 21s
# 1:	learn: 0.6266849	total: 104ms	remaining: 51.7s
# 1:	learn: 0.6386826	total: 101ms	remaining: 50.4s
# 3:	learn: 0.5822528	total: 106ms	remaining: 26.5s
# 1:	learn: 0.6380027	total: 95.4ms	remaining: 47.6s
# 3:	learn: 0.5771246	total: 108ms	remaining: 27s
# 2:	learn: 0.6020458	total: 106ms	remaining: 35.2s
# 0:	learn: 0.6633185	total: 87ms	remaining: 1m 26s
# 1:	learn: 0.6380068	total: 96.4ms	remaining: 48.1s
# 2:	learn: 0.6106671	total: 106ms	remaining: 35.4s
# 4:	learn: 0.5562834	total: 119ms	remaining: 23.7s
# 2:	learn: 0.5956191	total: 122ms	remaining: 40.5s
# 4:	learn: 0.5534657	total: 124ms	remaining: 24.6s
# 3:	learn: 0.5766135	total: 120ms	remaining: 29.8s
# 1:	learn: 0.6327528	total: 102ms	remaining: 50.8s
# 2:	learn: 0.6109271	total: 130ms	remaining: 43.3s
# 5:	learn: 0.5282627	total: 136ms	remaining: 22.5s
# 3:	learn: 0.5857976	total: 126ms	remaining: 31.3s
# 5:	learn: 0.5304147	total: 139ms	remaining: 23s
# 3:	learn: 0.5629829	total: 140ms	remaining: 34.9s
# 4:	learn: 0.5500927	total: 142ms	remaining: 28.2s
# 2:	learn: 0.6073351	total: 120ms	remaining: 39.8s
# 4:	learn: 0.5572967	total: 136ms	remaining: 27.1s
# 2:	learn: 0.6104495	total: 128ms	remaining: 42.5s
# 6:	learn: 0.5054231	total: 148ms	remaining: 21s
# 6:	learn: 0.5035723	total: 149ms	remaining: 21.1s
# 7:	learn: 0.4838680	total: 158ms	remaining: 19.6s
# 3:	learn: 0.5806546	total: 131ms	remaining: 32.6s
# 3:	learn: 0.5887799	total: 155ms	remaining: 38.5s
# 7:	learn: 0.4831099	total: 161ms	remaining: 19.9s
# 4:	learn: 0.5365838	total: 160ms	remaining: 31.8s
# 5:	learn: 0.5290422	total: 156ms	remaining: 25.8s
# 4:	learn: 0.5549698	total: 141ms	remaining: 28.1s
# 4:	learn: 0.5634214	total: 165ms	remaining: 32.8s
# 5:	learn: 0.5305830	total: 159ms	remaining: 26.3s
# 8:	learn: 0.4644269	total: 171ms	remaining: 18.8s
# 3:	learn: 0.5839399	total: 151ms	remaining: 37.6s
# 6:	learn: 0.5064401	total: 167ms	remaining: 23.7s
# 8:	learn: 0.4593889	total: 173ms	remaining: 19.1s
# 5:	learn: 0.5065862	total: 174ms	remaining: 28.8s
# 9:	learn: 0.4446484	total: 179ms	remaining: 17.7s
# 5:	learn: 0.5323656	total: 152ms	remaining: 25.2s
# 4:	learn: 0.5592228	total: 161ms	remaining: 32.1s
# 7:	learn: 0.4811769	total: 177ms	remaining: 22s
# 6:	learn: 0.4822323	total: 188ms	remaining: 26.6s
# 5:	learn: 0.5391713	total: 186ms	remaining: 30.8s
# 5:	learn: 0.5354281	total: 171ms	remaining: 28.4s
# 10:	learn: 0.4251972	total: 192ms	remaining: 17.3s
# 9:	learn: 0.4406101	total: 195ms	remaining: 19.3s
# 8:	learn: 0.4613976	total: 190ms	remaining: 20.9s
# 6:	learn: 0.5099603	total: 170ms	remaining: 24.1s
# 7:	learn: 0.4577245	total: 203ms	remaining: 25.2s
# 6:	learn: 0.5092052	total: 197ms	remaining: 27.9s
# 6:	learn: 0.5127421	total: 204ms	remaining: 29s
# 7:	learn: 0.4856087	total: 182ms	remaining: 22.6s
# 6:	learn: 0.5130263	total: 190ms	remaining: 26.9s
# 9:	learn: 0.4402193	total: 205ms	remaining: 20.3s
# 10:	learn: 0.4220693	total: 212ms	remaining: 19.1s
# 11:	learn: 0.4044544	total: 219ms	remaining: 18s
# 7:	learn: 0.4930896	total: 218ms	remaining: 27s
# 8:	learn: 0.4624771	total: 199ms	remaining: 21.9s
# 7:	learn: 0.4925550	total: 204ms	remaining: 25.2s
# 8:	learn: 0.4359480	total: 227ms	remaining: 25s
# 11:	learn: 0.4039689	total: 228ms	remaining: 18.7s
# 10:	learn: 0.4191790	total: 225ms	remaining: 20.3s
# 8:	learn: 0.4751474	total: 218ms	remaining: 24s
# 9:	learn: 0.4156969	total: 242ms	remaining: 23.9s
# 11:	learn: 0.4027762	total: 238ms	remaining: 19.6s
# 12:	learn: 0.3859186	total: 242ms	remaining: 18.4s
# 8:	learn: 0.4722796	total: 239ms	remaining: 26.3s
# 9:	learn: 0.4420090	total: 217ms	remaining: 21.5s
# 12:	learn: 0.3877117	total: 250ms	remaining: 19s
# 9:	learn: 0.4584185	total: 231ms	remaining: 22.9s
# 13:	learn: 0.3675654	total: 251ms	remaining: 17.7s
# 9:	learn: 0.4531252	total: 253ms	remaining: 25s
# 10:	learn: 0.4241471	total: 231ms	remaining: 20.7s
# 10:	learn: 0.3955229	total: 258ms	remaining: 23.2s
# 12:	learn: 0.3834262	total: 253ms	remaining: 19.2s
# 7:	learn: 0.4928792	total: 254ms	remaining: 31.4s
# 13:	learn: 0.3662705	total: 268ms	remaining: 18.8s
# 14:	learn: 0.3523219	total: 266ms	remaining: 17.5s
# 11:	learn: 0.3726363	total: 271ms	remaining: 22.3s
# 15:	learn: 0.3302297	total: 269ms	remaining: 16.6s
# 10:	learn: 0.4351550	total: 250ms	remaining: 22.5s
# 13:	learn: 0.3662188	total: 269ms	remaining: 18.9s
# 10:	learn: 0.4372684	total: 273ms	remaining: 24.5s
# 11:	learn: 0.4074285	total: 250ms	remaining: 20.6s
# 16:	learn: 0.3143224	total: 281ms	remaining: 16.2s
# 12:	learn: 0.3539610	total: 285ms	remaining: 21.6s
# 8:	learn: 0.4744030	total: 276ms	remaining: 30.4s
# 14:	learn: 0.3514598	total: 283ms	remaining: 18.6s
# 14:	learn: 0.3517636	total: 289ms	remaining: 19s
# 11:	learn: 0.4178193	total: 267ms	remaining: 22s
# 11:	learn: 0.4198554	total: 293ms	remaining: 24.1s
# 13:	learn: 0.3404012	total: 300ms	remaining: 21.1s
# 12:	learn: 0.3902425	total: 276ms	remaining: 21s
# 15:	learn: 0.3345170	total: 305ms	remaining: 18.8s
# 17:	learn: 0.2982776	total: 305ms	remaining: 16.6s
# 16:	learn: 0.3167223	total: 309ms	remaining: 17.9s
# 9:	learn: 0.4568829	total: 300ms	remaining: 29.7s
# 13:	learn: 0.3745751	total: 289ms	remaining: 20.3s
# 12:	learn: 0.4003415	total: 294ms	remaining: 22.3s
# 10:	learn: 0.4371318	total: 311ms	remaining: 27.9s
# 17:	learn: 0.3023472	total: 328ms	remaining: 17.9s
# 12:	learn: 0.4028016	total: 330ms	remaining: 25.1s
# 18:	learn: 0.2850903	total: 331ms	remaining: 17.1s
# 14:	learn: 0.3251794	total: 335ms	remaining: 22s
# 15:	learn: 0.3354268	total: 332ms	remaining: 20.4s
# 11:	learn: 0.4181709	total: 329ms	remaining: 27.1s
# 13:	learn: 0.3779476	total: 336ms	remaining: 23.6s
# 13:	learn: 0.3843504	total: 318ms	remaining: 22.4s
# 18:	learn: 0.2888805	total: 344ms	remaining: 17.7s
# 16:	learn: 0.3194348	total: 340ms	remaining: 19.7s
# 14:	learn: 0.3586898	total: 323ms	remaining: 21.2s
# 19:	learn: 0.2735026	total: 341ms	remaining: 16.7s
# 14:	learn: 0.3629117	total: 349ms	remaining: 22.9s
# 17:	learn: 0.3052515	total: 349ms	remaining: 19.1s
# 15:	learn: 0.3101779	total: 356ms	remaining: 21.9s
# 14:	learn: 0.3670323	total: 334ms	remaining: 21.9s
# 16:	learn: 0.2979306	total: 366ms	remaining: 21.1s
# 15:	learn: 0.3503255	total: 361ms	remaining: 22.2s
# 12:	learn: 0.4022576	total: 357ms	remaining: 27.1s
# 15:	learn: 0.3415973	total: 344ms	remaining: 21.2s
# 20:	learn: 0.2609721	total: 362ms	remaining: 16.9s
# 17:	learn: 0.2830816	total: 375ms	remaining: 20.5s
# 18:	learn: 0.2914351	total: 371ms	remaining: 19.2s
# 18:	learn: 0.2641065	total: 379ms	remaining: 19.6s
# 16:	learn: 0.3252886	total: 351ms	remaining: 20.3s
# 16:	learn: 0.3358498	total: 376ms	remaining: 21.7s
# 15:	learn: 0.3499174	total: 359ms	remaining: 22.1s
# 19:	learn: 0.2798823	total: 379ms	remaining: 18.6s
# 13:	learn: 0.3847453	total: 375ms	remaining: 26.4s
# 17:	learn: 0.3106867	total: 361ms	remaining: 19.7s
# 19:	learn: 0.2762462	total: 381ms	remaining: 18.7s
# 14:	learn: 0.3623906	total: 380ms	remaining: 24.9s
# 20:	learn: 0.2699174	total: 391ms	remaining: 18.2s
# 19:	learn: 0.2510911	total: 397ms	remaining: 19.5s
# 21:	learn: 0.2496586	total: 390ms	remaining: 17.3s
# 16:	learn: 0.3346015	total: 382ms	remaining: 22.1s
# 21:	learn: 0.2567719	total: 403ms	remaining: 17.9s
# 20:	learn: 0.2621729	total: 402ms	remaining: 18.7s
# 15:	learn: 0.3489954	total: 401ms	remaining: 24.6s
# 17:	learn: 0.3231166	total: 410ms	remaining: 22.4s
# 18:	learn: 0.2969654	total: 388ms	remaining: 20s
# 17:	learn: 0.3198983	total: 392ms	remaining: 21.4s
# 18:	learn: 0.3093364	total: 420ms	remaining: 21.7s
# 22:	learn: 0.2389412	total: 416ms	remaining: 17.7s
# 22:	learn: 0.2460001	total: 423ms	remaining: 18s
# 19:	learn: 0.2824202	total: 401ms	remaining: 19.7s
# 20:	learn: 0.2405082	total: 429ms	remaining: 20s
# 19:	learn: 0.2970215	total: 427ms	remaining: 20.9s
# 16:	learn: 0.3336145	total: 419ms	remaining: 24.2s
# 18:	learn: 0.3084943	total: 410ms	remaining: 21.2s
# 23:	learn: 0.2261617	total: 426ms	remaining: 17.3s
# 21:	learn: 0.2266448	total: 437ms	remaining: 19.4s
# 20:	learn: 0.2847378	total: 434ms	remaining: 20.2s
# 20:	learn: 0.2693122	total: 412ms	remaining: 19.2s
# 21:	learn: 0.2714284	total: 438ms	remaining: 19.5s
# 21:	learn: 0.2512348	total: 435ms	remaining: 19.3s
# 17:	learn: 0.3196997	total: 429ms	remaining: 23.4s
# 19:	learn: 0.2932607	total: 420ms	remaining: 20.6s
# 23:	learn: 0.2349697	total: 442ms	remaining: 18s
# 24:	learn: 0.2165180	total: 437ms	remaining: 17s
# 21:	learn: 0.2572482	total: 422ms	remaining: 18.8s
# 22:	learn: 0.2582688	total: 449ms	remaining: 19.1s
# 22:	learn: 0.2415408	total: 448ms	remaining: 19s
# 25:	learn: 0.2079394	total: 444ms	remaining: 16.6s
# 23:	learn: 0.2467612	total: 452ms	remaining: 18.4s
# 18:	learn: 0.3080628	total: 444ms	remaining: 22.9s
# 23:	learn: 0.2300918	total: 451ms	remaining: 18.3s
# 22:	learn: 0.2166082	total: 460ms	remaining: 19.5s
# 24:	learn: 0.2381668	total: 460ms	remaining: 17.9s
# 24:	learn: 0.2249260	total: 458ms	remaining: 17.9s
# 22:	learn: 0.2465739	total: 437ms	remaining: 18.5s
# 24:	learn: 0.2209949	total: 459ms	remaining: 17.9s
# 26:	learn: 0.1958484	total: 456ms	remaining: 16.4s
# 19:	learn: 0.2961309	total: 454ms	remaining: 22.3s
# 25:	learn: 0.2140705	total: 466ms	remaining: 17.5s
# 20:	learn: 0.2815231	total: 449ms	remaining: 20.9s
# 27:	learn: 0.1866212	total: 463ms	remaining: 16.1s
# 25:	learn: 0.2285677	total: 472ms	remaining: 17.7s
# 23:	learn: 0.2356414	total: 448ms	remaining: 18.2s
# 23:	learn: 0.2072691	total: 476ms	remaining: 19.4s
# 20:	learn: 0.2851370	total: 466ms	remaining: 21.7s
# 21:	learn: 0.2676674	total: 455ms	remaining: 20.2s
# 25:	learn: 0.2114796	total: 472ms	remaining: 17.7s
# 26:	learn: 0.2048301	total: 476ms	remaining: 17.2s
# 26:	learn: 0.2193399	total: 479ms	remaining: 17.3s
# 24:	learn: 0.2242743	total: 456ms	remaining: 17.8s
# 28:	learn: 0.1762086	total: 474ms	remaining: 15.9s
# 22:	learn: 0.2561412	total: 462ms	remaining: 19.6s
# 27:	learn: 0.2066506	total: 482ms	remaining: 16.7s
# 21:	learn: 0.2722741	total: 474ms	remaining: 21.1s
# 26:	learn: 0.2031087	total: 485ms	remaining: 17.5s
# 23:	learn: 0.2456076	total: 469ms	remaining: 19.1s
# 25:	learn: 0.2136870	total: 466ms	remaining: 17.4s
# 28:	learn: 0.1989567	total: 492ms	remaining: 16.5s
# 29:	learn: 0.1690067	total: 485ms	remaining: 15.7s
# 27:	learn: 0.1983020	total: 490ms	remaining: 17s
# 24:	learn: 0.1967513	total: 496ms	remaining: 19.3s
# 22:	learn: 0.2603293	total: 487ms	remaining: 20.7s
# 24:	learn: 0.2352258	total: 478ms	remaining: 18.6s
# 27:	learn: 0.1941899	total: 494ms	remaining: 17.2s
# 26:	learn: 0.2040176	total: 475ms	remaining: 17.1s
# 29:	learn: 0.1902229	total: 499ms	remaining: 16.1s
# 25:	learn: 0.1873288	total: 503ms	remaining: 18.8s
# 28:	learn: 0.1884618	total: 500ms	remaining: 16.7s
# 30:	learn: 0.1623423	total: 495ms	remaining: 15.5s
# 25:	learn: 0.2221001	total: 483ms	remaining: 18.1s
# 31:	learn: 0.1516787	total: 497ms	remaining: 15s
# 23:	learn: 0.2493515	total: 497ms	remaining: 20.2s
# 28:	learn: 0.1861028	total: 503ms	remaining: 16.9s
# 26:	learn: 0.1793666	total: 509ms	remaining: 18.3s
# 30:	learn: 0.1821108	total: 509ms	remaining: 15.9s
# 27:	learn: 0.1932517	total: 485ms	remaining: 16.8s
# 29:	learn: 0.1800601	total: 511ms	remaining: 16.5s
# 32:	learn: 0.1460377	total: 508ms	remaining: 14.9s
# 28:	learn: 0.1861777	total: 492ms	remaining: 16.5s
# 27:	learn: 0.1708583	total: 518ms	remaining: 18s
# 31:	learn: 0.1743420	total: 517ms	remaining: 15.6s
# 29:	learn: 0.1804244	total: 514ms	remaining: 16.6s
# 24:	learn: 0.2392527	total: 508ms	remaining: 19.8s
# 26:	learn: 0.2145858	total: 499ms	remaining: 18s
# 30:	learn: 0.1729671	total: 517ms	remaining: 16.2s
# 30:	learn: 0.1695469	total: 517ms	remaining: 16.2s
# 32:	learn: 0.1675541	total: 524ms	remaining: 15.4s
# 25:	learn: 0.2313153	total: 516ms	remaining: 19.3s
# 27:	learn: 0.2068303	total: 506ms	remaining: 17.6s
# 33:	learn: 0.1401391	total: 520ms	remaining: 14.8s
# 31:	learn: 0.1663310	total: 526ms	remaining: 15.9s
# 28:	learn: 0.1638830	total: 530ms	remaining: 17.8s
# 28:	learn: 0.1948981	total: 510ms	remaining: 17.1s
# 31:	learn: 0.1620497	total: 526ms	remaining: 15.9s
# 29:	learn: 0.1800334	total: 509ms	remaining: 16.4s
# 26:	learn: 0.2217412	total: 524ms	remaining: 18.9s
# 29:	learn: 0.1560643	total: 535ms	remaining: 17.3s
# 33:	learn: 0.1602059	total: 534ms	remaining: 15.2s
# 34:	learn: 0.1312227	total: 528ms	remaining: 14.6s
# 27:	learn: 0.2130783	total: 531ms	remaining: 18.4s
# 29:	learn: 0.1886885	total: 522ms	remaining: 16.9s
# 30:	learn: 0.1493920	total: 544ms	remaining: 17s
# 30:	learn: 0.1724469	total: 520ms	remaining: 16.3s
# 32:	learn: 0.1589207	total: 542ms	remaining: 15.9s
# 32:	learn: 0.1533400	total: 541ms	remaining: 15.9s
# 30:	learn: 0.1826635	total: 528ms	remaining: 16.5s
# 28:	learn: 0.2052382	total: 539ms	remaining: 18.1s
# 34:	learn: 0.1548744	total: 549ms	remaining: 15.1s
# 31:	learn: 0.1643952	total: 528ms	remaining: 16s
# 35:	learn: 0.1261590	total: 545ms	remaining: 14.6s
# 31:	learn: 0.1425067	total: 555ms	remaining: 16.8s
# 33:	learn: 0.1463140	total: 548ms	remaining: 15.6s
# 31:	learn: 0.1770914	total: 537ms	remaining: 16.2s
# 33:	learn: 0.1527673	total: 555ms	remaining: 15.8s
# 32:	learn: 0.1339725	total: 560ms	remaining: 16.4s
# 35:	learn: 0.1491509	total: 558ms	remaining: 15s
# 32:	learn: 0.1586985	total: 535ms	remaining: 15.7s
# 36:	learn: 0.1209747	total: 554ms	remaining: 14.4s
# 29:	learn: 0.1949162	total: 552ms	remaining: 17.9s
# 36:	learn: 0.1428574	total: 562ms	remaining: 14.6s
# 32:	learn: 0.1697936	total: 545ms	remaining: 16s
# 34:	learn: 0.1461372	total: 562ms	remaining: 15.5s
# 33:	learn: 0.1284978	total: 568ms	remaining: 16.1s
# 30:	learn: 0.1840238	total: 559ms	remaining: 17.5s
# 34:	learn: 0.1409973	total: 562ms	remaining: 15.5s
# 33:	learn: 0.1511284	total: 545ms	remaining: 15.5s
# 37:	learn: 0.1168420	total: 563ms	remaining: 14.2s
# 34:	learn: 0.1435592	total: 550ms	remaining: 15.2s
# 37:	learn: 0.1371433	total: 576ms	remaining: 14.6s
# 33:	learn: 0.1639992	total: 558ms	remaining: 15.8s
# 38:	learn: 0.1128364	total: 586ms	remaining: 14.4s
# 39:	learn: 0.1080258	total: 622ms	remaining: 14.9s
# 34:	learn: 0.1227888	total: 659ms	remaining: 18.2s
# 35:	learn: 0.1401797	total: 656ms	remaining: 17.6s
# 34:	learn: 0.1574958	total: 686ms	remaining: 18.9s
# 38:	learn: 0.1324041	total: 720ms	remaining: 17.7s
# 35:	learn: 0.1179848	total: 740ms	remaining: 19.8s
# 35:	learn: 0.1351954	total: 721ms	remaining: 19.3s
# 36:	learn: 0.1334324	total: 765ms	remaining: 19.9s
# 35:	learn: 0.1378597	total: 757ms	remaining: 20.3s
# 31:	learn: 0.1777582	total: 817ms	remaining: 24.7s
# 40:	learn: 0.1036455	total: 820ms	remaining: 19.2s
# 37:	learn: 0.1272808	total: 827ms	remaining: 20.9s
# 36:	learn: 0.1143942	total: 839ms	remaining: 21.8s
# 38:	learn: 0.1219368	total: 836ms	remaining: 20.6s
# 39:	learn: 0.1266473	total: 839ms	remaining: 20.1s
# 36:	learn: 0.1295743	total: 820ms	remaining: 21.4s
# 35:	learn: 0.1521739	total: 825ms	remaining: 22.1s
# 41:	learn: 0.0997043	total: 836ms	remaining: 19.1s
# 36:	learn: 0.1329262	total: 823ms	remaining: 21.4s
# 32:	learn: 0.1703763	total: 838ms	remaining: 24.6s
# 37:	learn: 0.1244712	total: 835ms	remaining: 21.1s
# 40:	learn: 0.1226401	total: 858ms	remaining: 20.1s
# 36:	learn: 0.1466303	total: 843ms	remaining: 21.9s
# 37:	learn: 0.1277769	total: 841ms	remaining: 21.3s
# 42:	learn: 0.0957140	total: 857ms	remaining: 19.1s
# 39:	learn: 0.1168449	total: 851ms	remaining: 20.4s
# 33:	learn: 0.1637521	total: 857ms	remaining: 24.3s
# 37:	learn: 0.1093391	total: 867ms	remaining: 22s
# 43:	learn: 0.0897775	total: 860ms	remaining: 18.7s
# 38:	learn: 0.1192206	total: 850ms	remaining: 20.9s
# 41:	learn: 0.1179297	total: 875ms	remaining: 19.9s
# 37:	learn: 0.1419665	total: 857ms	remaining: 21.7s
# 34:	learn: 0.1575896	total: 871ms	remaining: 24s
# 44:	learn: 0.0867494	total: 875ms	remaining: 18.6s
# 40:	learn: 0.1123655	total: 870ms	remaining: 20.4s
# 38:	learn: 0.1220888	total: 862ms	remaining: 21.2s
# 35:	learn: 0.1527466	total: 879ms	remaining: 23.5s
# 42:	learn: 0.1135882	total: 888ms	remaining: 19.8s
# 45:	learn: 0.0830614	total: 883ms	remaining: 18.3s
# 39:	learn: 0.1142700	total: 872ms	remaining: 20.9s
# 39:	learn: 0.1167408	total: 876ms	remaining: 21s
# 38:	learn: 0.1374437	total: 900ms	remaining: 22.2s
# 46:	learn: 0.0804302	total: 917ms	remaining: 18.6s
# 43:	learn: 0.1091556	total: 928ms	remaining: 20.2s
# 40:	learn: 0.1103420	total: 907ms	remaining: 21.2s
# 38:	learn: 0.1053284	total: 928ms	remaining: 22.9s
# 36:	learn: 0.1469199	total: 930ms	remaining: 24.2s
# 41:	learn: 0.1044156	total: 917ms	remaining: 20.9s
# 47:	learn: 0.0770189	total: 938ms	remaining: 18.6s
# 37:	learn: 0.1418329	total: 937ms	remaining: 23.7s
# 41:	learn: 0.1070376	total: 935ms	remaining: 21.3s
# 40:	learn: 0.1104658	total: 928ms	remaining: 21.7s
# 42:	learn: 0.1005306	total: 929ms	remaining: 20.7s
# 44:	learn: 0.1044033	total: 952ms	remaining: 20.2s
# 39:	learn: 0.1331597	total: 937ms	remaining: 22.5s
# 48:	learn: 0.0738829	total: 951ms	remaining: 18.5s
# 41:	learn: 0.1057340	total: 942ms	remaining: 21.5s
# 38:	learn: 0.1374467	total: 956ms	remaining: 23.6s
# 43:	learn: 0.0967598	total: 948ms	remaining: 20.6s
# 49:	learn: 0.0713074	total: 968ms	remaining: 18.4s
# 39:	learn: 0.1021360	total: 971ms	remaining: 23.3s
# 40:	learn: 0.1284762	total: 960ms	remaining: 22.5s
# 45:	learn: 0.1005519	total: 984ms	remaining: 20.4s
# 42:	learn: 0.1026868	total: 970ms	remaining: 21.6s
# 42:	learn: 0.1017063	total: 964ms	remaining: 21.4s
# 39:	learn: 0.1332602	total: 982ms	remaining: 23.6s
# 40:	learn: 0.0982705	total: 986ms	remaining: 23.1s
# 44:	learn: 0.0934211	total: 969ms	remaining: 20.6s
# 41:	learn: 0.1231617	total: 974ms	remaining: 22.2s
# 42:	learn: 0.1162566	total: 978ms	remaining: 21.8s
# 43:	learn: 0.0982967	total: 992ms	remaining: 21.6s
# 46:	learn: 0.0968499	total: 1.01s	remaining: 20.5s
# 45:	learn: 0.0898510	total: 991ms	remaining: 20.6s
# 50:	learn: 0.0684750	total: 1.01s	remaining: 18.8s
# 41:	learn: 0.0945917	total: 1.02s	remaining: 23.2s
# 43:	learn: 0.1121983	total: 1.01s	remaining: 21.9s
# 51:	learn: 0.0644187	total: 1.02s	remaining: 18.6s
# 43:	learn: 0.0980152	total: 1.01s	remaining: 21.9s
# 47:	learn: 0.0913632	total: 1.03s	remaining: 20.4s
# 42:	learn: 0.0907476	total: 1.03s	remaining: 22.9s
# 46:	learn: 0.0867339	total: 1.01s	remaining: 20.5s
# 40:	learn: 0.1283575	total: 1.03s	remaining: 24.1s
# 52:	learn: 0.0615294	total: 1.03s	remaining: 18.4s
# 48:	learn: 0.0885660	total: 1.04s	remaining: 20.3s
# 47:	learn: 0.0834700	total: 1.02s	remaining: 20.2s
# 44:	learn: 0.1078638	total: 1.02s	remaining: 21.7s
# 43:	learn: 0.0860675	total: 1.04s	remaining: 22.7s
# 53:	learn: 0.0591956	total: 1.04s	remaining: 18.2s
# 48:	learn: 0.0812521	total: 1.03s	remaining: 20s
# 41:	learn: 0.1244026	total: 1.05s	remaining: 23.9s
# 44:	learn: 0.0947603	total: 1.04s	remaining: 22.1s
# 44:	learn: 0.0943102	total: 1.03s	remaining: 22s
# 45:	learn: 0.1036732	total: 1.04s	remaining: 21.5s
# 49:	learn: 0.0851657	total: 1.06s	remaining: 20.1s
# 45:	learn: 0.0903774	total: 1.04s	remaining: 21.7s
# 42:	learn: 0.1205523	total: 1.06s	remaining: 23.6s
# 44:	learn: 0.0836847	total: 1.06s	remaining: 22.5s
# 49:	learn: 0.0786902	total: 1.04s	remaining: 19.8s
# 46:	learn: 0.0989999	total: 1.05s	remaining: 21.3s
# 54:	learn: 0.0564710	total: 1.06s	remaining: 18.3s
# 45:	learn: 0.0917486	total: 1.06s	remaining: 22s
# 50:	learn: 0.0830138	total: 1.07s	remaining: 20s
# 51:	learn: 0.0784082	total: 1.08s	remaining: 19.6s
# 43:	learn: 0.1169237	total: 1.07s	remaining: 23.3s
# 45:	learn: 0.0814160	total: 1.07s	remaining: 22.3s
# 47:	learn: 0.0949180	total: 1.06s	remaining: 21s
# 46:	learn: 0.0777228	total: 1.07s	remaining: 21.8s
# 46:	learn: 0.0879773	total: 1.07s	remaining: 21.7s
# 48:	learn: 0.0917689	total: 1.07s	remaining: 20.7s
# 46:	learn: 0.0863719	total: 1.07s	remaining: 21.7s
# 52:	learn: 0.0753047	total: 1.09s	remaining: 19.5s
# 47:	learn: 0.0849582	total: 1.08s	remaining: 21.4s
# 47:	learn: 0.0752325	total: 1.09s	remaining: 21.6s
# 50:	learn: 0.0761610	total: 1.07s	remaining: 19.9s
# 44:	learn: 0.1117369	total: 1.09s	remaining: 23.2s
# 49:	learn: 0.0886729	total: 1.08s	remaining: 20.6s
# 53:	learn: 0.0726719	total: 1.1s	remaining: 19.4s
# 55:	learn: 0.0544970	total: 1.1s	remaining: 18.5s
# 51:	learn: 0.0739183	total: 1.08s	remaining: 19.7s
# 50:	learn: 0.0852591	total: 1.09s	remaining: 20.3s
# 54:	learn: 0.0694353	total: 1.11s	remaining: 19.1s
# 52:	learn: 0.0697984	total: 1.09s	remaining: 19.4s
# 48:	learn: 0.0722109	total: 1.11s	remaining: 21.5s
# 48:	learn: 0.0812426	total: 1.1s	remaining: 21.4s
# 47:	learn: 0.0835300	total: 1.1s	remaining: 21.8s
# 45:	learn: 0.1080833	total: 1.11s	remaining: 23s
# 56:	learn: 0.0523082	total: 1.11s	remaining: 18.3s
# 51:	learn: 0.0827740	total: 1.1s	remaining: 20.1s
# 57:	learn: 0.0502561	total: 1.11s	remaining: 18.1s
# 48:	learn: 0.0807359	total: 1.1s	remaining: 21.5s
# 55:	learn: 0.0673981	total: 1.13s	remaining: 19.1s
# 49:	learn: 0.0696628	total: 1.12s	remaining: 21.4s
# 49:	learn: 0.0784779	total: 1.12s	remaining: 21.2s
# 46:	learn: 0.1035318	total: 1.12s	remaining: 22.8s
# 53:	learn: 0.0671979	total: 1.1s	remaining: 19.4s
# 58:	learn: 0.0485366	total: 1.12s	remaining: 17.9s
# 52:	learn: 0.0801233	total: 1.11s	remaining: 19.9s
# 50:	learn: 0.0666174	total: 1.13s	remaining: 21s
# 49:	learn: 0.0760923	total: 1.11s	remaining: 21.2s
# 50:	learn: 0.0745782	total: 1.13s	remaining: 21s
# 56:	learn: 0.0645667	total: 1.14s	remaining: 18.9s
# 54:	learn: 0.0648310	total: 1.11s	remaining: 19.2s
# 51:	learn: 0.0641679	total: 1.14s	remaining: 20.8s
# 51:	learn: 0.0718519	total: 1.14s	remaining: 20.7s
# 59:	learn: 0.0462536	total: 1.14s	remaining: 17.9s
# 47:	learn: 0.1003168	total: 1.14s	remaining: 22.6s
# 50:	learn: 0.0729127	total: 1.13s	remaining: 21s
# 55:	learn: 0.0627122	total: 1.13s	remaining: 19s
# 53:	learn: 0.0779255	total: 1.14s	remaining: 20s
# 60:	learn: 0.0446876	total: 1.15s	remaining: 17.8s
# 56:	learn: 0.0603430	total: 1.14s	remaining: 18.8s
# 48:	learn: 0.0965386	total: 1.16s	remaining: 22.6s
# 54:	learn: 0.0744872	total: 1.15s	remaining: 19.8s
# 52:	learn: 0.0691392	total: 1.16s	remaining: 20.8s
# 57:	learn: 0.0623625	total: 1.18s	remaining: 19.1s
# 57:	learn: 0.0584845	total: 1.15s	remaining: 18.7s
# 61:	learn: 0.0428835	total: 1.17s	remaining: 17.7s
# 52:	learn: 0.0614714	total: 1.18s	remaining: 21s
# 55:	learn: 0.0716655	total: 1.16s	remaining: 19.6s
# 51:	learn: 0.0707495	total: 1.16s	remaining: 21.2s
# 58:	learn: 0.0599708	total: 1.19s	remaining: 19s
# 56:	learn: 0.0690118	total: 1.17s	remaining: 19.4s
# 62:	learn: 0.0413197	total: 1.18s	remaining: 17.6s
# 49:	learn: 0.0933279	total: 1.19s	remaining: 22.6s
# 58:	learn: 0.0566587	total: 1.17s	remaining: 18.7s
# 53:	learn: 0.0668790	total: 1.18s	remaining: 20.7s
# 59:	learn: 0.0576095	total: 1.2s	remaining: 18.8s
# 57:	learn: 0.0670023	total: 1.18s	remaining: 19.2s
# 63:	learn: 0.0400084	total: 1.2s	remaining: 17.5s
# 50:	learn: 0.0901196	total: 1.2s	remaining: 22.3s
# 52:	learn: 0.0683214	total: 1.19s	remaining: 21.2s
# 54:	learn: 0.0643099	total: 1.19s	remaining: 20.5s
# 60:	learn: 0.0559016	total: 1.21s	remaining: 18.7s
# 53:	learn: 0.0590535	total: 1.21s	remaining: 21.1s
# 53:	learn: 0.0658948	total: 1.19s	remaining: 20.9s
# 54:	learn: 0.0556922	total: 1.21s	remaining: 20.8s
# 59:	learn: 0.0547000	total: 1.2s	remaining: 18.9s
# 51:	learn: 0.0873811	total: 1.22s	remaining: 22.3s
# 61:	learn: 0.0539902	total: 1.23s	remaining: 18.7s
# 58:	learn: 0.0650000	total: 1.21s	remaining: 19.4s
# 55:	learn: 0.0622298	total: 1.22s	remaining: 20.6s
# 55:	learn: 0.0534326	total: 1.23s	remaining: 20.7s
# 64:	learn: 0.0388290	total: 1.23s	remaining: 17.6s
# 54:	learn: 0.0638612	total: 1.22s	remaining: 21s
# 59:	learn: 0.0629375	total: 1.22s	remaining: 19.1s
# 56:	learn: 0.0606127	total: 1.23s	remaining: 20.4s
# 56:	learn: 0.0513259	total: 1.24s	remaining: 20.5s
# 65:	learn: 0.0368927	total: 1.24s	remaining: 17.5s
# 60:	learn: 0.0608725	total: 1.23s	remaining: 19s
# 57:	learn: 0.0585318	total: 1.24s	remaining: 20.2s
# 52:	learn: 0.0841494	total: 1.25s	remaining: 22.3s
# 62:	learn: 0.0521498	total: 1.27s	remaining: 18.8s
# 57:	learn: 0.0493977	total: 1.26s	remaining: 20.5s
# 66:	learn: 0.0356009	total: 1.26s	remaining: 17.5s
# 53:	learn: 0.0809045	total: 1.26s	remaining: 22.1s
# 60:	learn: 0.0531988	total: 1.25s	remaining: 19.2s
# 55:	learn: 0.0613559	total: 1.26s	remaining: 21.3s
# 61:	learn: 0.0587988	total: 1.26s	remaining: 19.1s
# 58:	learn: 0.0562035	total: 1.27s	remaining: 20.3s
# 56:	learn: 0.0586896	total: 1.27s	remaining: 21s
# 61:	learn: 0.0514732	total: 1.27s	remaining: 19.2s
# 57:	learn: 0.0565708	total: 1.28s	remaining: 20.8s
# 59:	learn: 0.0540362	total: 1.29s	remaining: 20.2s
# 63:	learn: 0.0504446	total: 1.3s	remaining: 19.1s
# 62:	learn: 0.0496519	total: 1.28s	remaining: 19s
# 60:	learn: 0.0523510	total: 1.3s	remaining: 20s
# 63:	learn: 0.0482208	total: 1.29s	remaining: 18.8s
# 64:	learn: 0.0487690	total: 1.32s	remaining: 19s
# 58:	learn: 0.0473512	total: 1.31s	remaining: 21s
# 54:	learn: 0.0788779	total: 1.32s	remaining: 22.6s
# 64:	learn: 0.0469224	total: 1.3s	remaining: 18.6s
# 62:	learn: 0.0572923	total: 1.31s	remaining: 19.5s
# 65:	learn: 0.0473876	total: 1.33s	remaining: 18.9s
# 59:	learn: 0.0453471	total: 1.33s	remaining: 20.9s
# 66:	learn: 0.0457527	total: 1.34s	remaining: 18.7s
# 58:	learn: 0.0544832	total: 1.32s	remaining: 21.1s
# 55:	learn: 0.0758004	total: 1.34s	remaining: 22.5s
# 61:	learn: 0.0497919	total: 1.33s	remaining: 20.1s
# 63:	learn: 0.0559797	total: 1.33s	remaining: 19.4s
# 67:	learn: 0.0345425	total: 1.34s	remaining: 18.3s
# 60:	learn: 0.0437042	total: 1.35s	remaining: 20.7s
# 59:	learn: 0.0525038	total: 1.33s	remaining: 20.9s
# 62:	learn: 0.0471927	total: 1.34s	remaining: 19.9s
# 56:	learn: 0.0729971	total: 1.35s	remaining: 22.3s
# 68:	learn: 0.0327406	total: 1.34s	remaining: 18.2s
# 64:	learn: 0.0537516	total: 1.34s	remaining: 19.3s
# 65:	learn: 0.0451213	total: 1.34s	remaining: 18.9s
# 57:	learn: 0.0706919	total: 1.36s	remaining: 22.1s
# 65:	learn: 0.0519378	total: 1.35s	remaining: 19.1s
# 61:	learn: 0.0421779	total: 1.37s	remaining: 20.7s
# 66:	learn: 0.0434036	total: 1.35s	remaining: 18.8s
# 69:	learn: 0.0316827	total: 1.36s	remaining: 18.1s
# 63:	learn: 0.0458278	total: 1.36s	remaining: 19.9s
# 67:	learn: 0.0445337	total: 1.38s	remaining: 18.9s
# 60:	learn: 0.0507377	total: 1.36s	remaining: 20.9s
# 64:	learn: 0.0443702	total: 1.38s	remaining: 19.8s
# 70:	learn: 0.0304616	total: 1.38s	remaining: 18.1s
# 61:	learn: 0.0489167	total: 1.37s	remaining: 20.8s
# 68:	learn: 0.0432381	total: 1.4s	remaining: 18.8s
# 58:	learn: 0.0679084	total: 1.39s	remaining: 22.2s
# 67:	learn: 0.0419355	total: 1.37s	remaining: 18.8s
# 69:	learn: 0.0422827	total: 1.41s	remaining: 18.7s
# 66:	learn: 0.0505758	total: 1.39s	remaining: 19.3s
# 65:	learn: 0.0424971	total: 1.39s	remaining: 19.7s
# 71:	learn: 0.0293244	total: 1.4s	remaining: 18s
# 62:	learn: 0.0477517	total: 1.39s	remaining: 20.7s
# 59:	learn: 0.0648737	total: 1.4s	remaining: 22s
# 70:	learn: 0.0408406	total: 1.42s	remaining: 18.6s
# 66:	learn: 0.0411215	total: 1.41s	remaining: 19.6s
# 63:	learn: 0.0462799	total: 1.41s	remaining: 20.6s
# 62:	learn: 0.0407572	total: 1.43s	remaining: 21.2s
# 72:	learn: 0.0284256	total: 1.42s	remaining: 18.1s
# 71:	learn: 0.0391500	total: 1.43s	remaining: 18.4s
# 60:	learn: 0.0615863	total: 1.42s	remaining: 21.9s
# 64:	learn: 0.0446479	total: 1.42s	remaining: 20.4s
# 61:	learn: 0.0583844	total: 1.43s	remaining: 21.6s
# 67:	learn: 0.0395846	total: 1.43s	remaining: 19.6s
# 63:	learn: 0.0392704	total: 1.44s	remaining: 21.1s
# 73:	learn: 0.0274013	total: 1.43s	remaining: 17.9s
# 72:	learn: 0.0375317	total: 1.44s	remaining: 18.3s
# 68:	learn: 0.0408031	total: 1.41s	remaining: 19s
# 68:	learn: 0.0383094	total: 1.44s	remaining: 19.4s
# 65:	learn: 0.0432870	total: 1.44s	remaining: 20.3s
# 69:	learn: 0.0393912	total: 1.42s	remaining: 18.9s
# 64:	learn: 0.0374535	total: 1.46s	remaining: 21s
# 66:	learn: 0.0412905	total: 1.44s	remaining: 20.1s
# 62:	learn: 0.0568220	total: 1.46s	remaining: 21.7s
# 70:	learn: 0.0385162	total: 1.43s	remaining: 18.8s
# 74:	learn: 0.0265944	total: 1.46s	remaining: 18s
# 65:	learn: 0.0362119	total: 1.47s	remaining: 20.8s
# 73:	learn: 0.0361743	total: 1.47s	remaining: 18.4s
# 69:	learn: 0.0370013	total: 1.46s	remaining: 19.4s
# 63:	learn: 0.0547379	total: 1.47s	remaining: 21.5s
# 67:	learn: 0.0487800	total: 1.46s	remaining: 20s
# 67:	learn: 0.0398507	total: 1.46s	remaining: 20s
# 71:	learn: 0.0374619	total: 1.44s	remaining: 18.6s
# 75:	learn: 0.0257265	total: 1.48s	remaining: 18s
# 70:	learn: 0.0357450	total: 1.47s	remaining: 19.3s
# 64:	learn: 0.0533500	total: 1.48s	remaining: 21.3s
# 72:	learn: 0.0362631	total: 1.46s	remaining: 18.5s
# 68:	learn: 0.0385877	total: 1.47s	remaining: 19.9s
# 74:	learn: 0.0350011	total: 1.5s	remaining: 18.5s
# 73:	learn: 0.0350075	total: 1.47s	remaining: 18.3s
# 68:	learn: 0.0473007	total: 1.48s	remaining: 20s
# 76:	learn: 0.0247828	total: 1.49s	remaining: 17.9s
# 66:	learn: 0.0349427	total: 1.5s	remaining: 20.9s
# 69:	learn: 0.0373582	total: 1.49s	remaining: 19.7s
# 67:	learn: 0.0339373	total: 1.5s	remaining: 20.6s
# 65:	learn: 0.0513734	total: 1.5s	remaining: 21.2s
# 77:	learn: 0.0239471	total: 1.5s	remaining: 17.8s
# 70:	learn: 0.0362477	total: 1.5s	remaining: 19.6s
# 69:	learn: 0.0462110	total: 1.5s	remaining: 19.9s
# 68:	learn: 0.0329358	total: 1.51s	remaining: 20.4s
# 75:	learn: 0.0339332	total: 1.52s	remaining: 18.5s
# 71:	learn: 0.0344827	total: 1.5s	remaining: 19.4s
# 66:	learn: 0.0495319	total: 1.51s	remaining: 21.1s
# 74:	learn: 0.0337787	total: 1.49s	remaining: 18.4s
# 78:	learn: 0.0233167	total: 1.51s	remaining: 17.7s
# 71:	learn: 0.0355219	total: 1.51s	remaining: 19.4s
# 69:	learn: 0.0320163	total: 1.52s	remaining: 20.2s
# 72:	learn: 0.0333651	total: 1.51s	remaining: 19.2s
# 70:	learn: 0.0448444	total: 1.51s	remaining: 19.8s
# 75:	learn: 0.0325395	total: 1.5s	remaining: 18.2s
# 67:	learn: 0.0478962	total: 1.52s	remaining: 20.9s
# 71:	learn: 0.0438075	total: 1.52s	remaining: 19.6s
# 76:	learn: 0.0330093	total: 1.54s	remaining: 18.4s
# 73:	learn: 0.0324069	total: 1.52s	remaining: 19.1s
# 72:	learn: 0.0343878	total: 1.52s	remaining: 19.3s
# 79:	learn: 0.0226528	total: 1.53s	remaining: 17.6s
# 76:	learn: 0.0316201	total: 1.51s	remaining: 18.1s
# 70:	learn: 0.0310481	total: 1.54s	remaining: 20.1s
# 68:	learn: 0.0463118	total: 1.53s	remaining: 20.7s
# 71:	learn: 0.0296985	total: 1.54s	remaining: 19.9s
# 77:	learn: 0.0320112	total: 1.55s	remaining: 18.3s
# 74:	learn: 0.0313380	total: 1.54s	remaining: 19s
# 72:	learn: 0.0425225	total: 1.53s	remaining: 19.5s
# 69:	learn: 0.0446646	total: 1.54s	remaining: 20.5s
# 77:	learn: 0.0306930	total: 1.52s	remaining: 18s
# 75:	learn: 0.0303201	total: 1.55s	remaining: 18.8s
# 70:	learn: 0.0434468	total: 1.55s	remaining: 20.3s
# 80:	learn: 0.0219172	total: 1.55s	remaining: 17.6s
# 73:	learn: 0.0330976	total: 1.55s	remaining: 19.4s
# 78:	learn: 0.0311891	total: 1.56s	remaining: 18.2s
# 78:	learn: 0.0297916	total: 1.53s	remaining: 17.9s
# 79:	learn: 0.0287760	total: 1.53s	remaining: 17.7s
# 73:	learn: 0.0415557	total: 1.55s	remaining: 19.5s
# 79:	learn: 0.0300342	total: 1.57s	remaining: 18.1s
# 74:	learn: 0.0320078	total: 1.56s	remaining: 19.2s
# 71:	learn: 0.0419308	total: 1.57s	remaining: 20.2s
# 72:	learn: 0.0285406	total: 1.57s	remaining: 20s
# 80:	learn: 0.0277037	total: 1.54s	remaining: 17.5s
# 76:	learn: 0.0293891	total: 1.56s	remaining: 18.8s
# 81:	learn: 0.0212953	total: 1.57s	remaining: 17.5s
# 80:	learn: 0.0292487	total: 1.58s	remaining: 18s
# 81:	learn: 0.0270472	total: 1.55s	remaining: 17.4s
# 74:	learn: 0.0399936	total: 1.57s	remaining: 19.4s
# 81:	learn: 0.0284942	total: 1.59s	remaining: 17.8s
# 75:	learn: 0.0309207	total: 1.57s	remaining: 19.1s
# 72:	learn: 0.0407286	total: 1.59s	remaining: 20.2s
# 77:	learn: 0.0284986	total: 1.58s	remaining: 18.7s
# 82:	learn: 0.0205294	total: 1.58s	remaining: 17.5s
# 73:	learn: 0.0274743	total: 1.6s	remaining: 20s
# 82:	learn: 0.0276639	total: 1.6s	remaining: 17.7s
# 82:	learn: 0.0264678	total: 1.57s	remaining: 17.3s
# 75:	learn: 0.0386968	total: 1.58s	remaining: 19.3s
# 76:	learn: 0.0301175	total: 1.59s	remaining: 19s
# 78:	learn: 0.0274914	total: 1.59s	remaining: 18.6s
# 83:	learn: 0.0198551	total: 1.59s	remaining: 17.4s
# 77:	learn: 0.0292545	total: 1.59s	remaining: 18.8s
# 73:	learn: 0.0395853	total: 1.61s	remaining: 20.1s
# 83:	learn: 0.0259237	total: 1.58s	remaining: 17.3s
# 83:	learn: 0.0266523	total: 1.62s	remaining: 17.7s
# 78:	learn: 0.0278380	total: 1.6s	remaining: 18.7s
# 76:	learn: 0.0375965	total: 1.6s	remaining: 19.2s
# 74:	learn: 0.0267494	total: 1.62s	remaining: 20s
# 84:	learn: 0.0191114	total: 1.61s	remaining: 17.3s
# 79:	learn: 0.0265630	total: 1.61s	remaining: 18.5s
# 79:	learn: 0.0265033	total: 1.6s	remaining: 18.5s
# 75:	learn: 0.0257338	total: 1.63s	remaining: 19.8s
# 84:	learn: 0.0251176	total: 1.59s	remaining: 17.2s
# 74:	learn: 0.0385847	total: 1.62s	remaining: 20s
# 80:	learn: 0.0258415	total: 1.62s	remaining: 18.3s
# 84:	learn: 0.0259356	total: 1.63s	remaining: 17.6s
# 77:	learn: 0.0365133	total: 1.61s	remaining: 19.1s
# 80:	learn: 0.0256560	total: 1.62s	remaining: 18.4s
# 81:	learn: 0.0248895	total: 1.62s	remaining: 18.2s
# 78:	learn: 0.0355636	total: 1.62s	remaining: 18.9s
# 85:	learn: 0.0183611	total: 1.63s	remaining: 17.3s
# 76:	learn: 0.0248245	total: 1.64s	remaining: 19.7s
# 85:	learn: 0.0245277	total: 1.61s	remaining: 17.1s
# 85:	learn: 0.0254278	total: 1.65s	remaining: 17.5s
# 81:	learn: 0.0250164	total: 1.64s	remaining: 18.3s
# 75:	learn: 0.0375449	total: 1.64s	remaining: 20s
# 82:	learn: 0.0239741	total: 1.64s	remaining: 18.1s
# 77:	learn: 0.0240402	total: 1.66s	remaining: 19.6s
# 79:	learn: 0.0347821	total: 1.64s	remaining: 18.8s
# 86:	learn: 0.0177855	total: 1.64s	remaining: 17.2s
# 86:	learn: 0.0247127	total: 1.66s	remaining: 17.4s
# 82:	learn: 0.0239640	total: 1.65s	remaining: 18.2s
# 76:	learn: 0.0365066	total: 1.65s	remaining: 19.8s
# 86:	learn: 0.0241409	total: 1.63s	remaining: 17.1s
# 77:	learn: 0.0348078	total: 1.66s	remaining: 19.6s
# 83:	learn: 0.0234233	total: 1.65s	remaining: 18s
# 87:	learn: 0.0237595	total: 1.67s	remaining: 17.3s
# 87:	learn: 0.0172386	total: 1.66s	remaining: 17.2s
# 80:	learn: 0.0340318	total: 1.65s	remaining: 18.7s
# 78:	learn: 0.0233931	total: 1.67s	remaining: 19.5s
# 83:	learn: 0.0232633	total: 1.66s	remaining: 18.1s
# 87:	learn: 0.0234307	total: 1.64s	remaining: 17s
# 81:	learn: 0.0331671	total: 1.66s	remaining: 18.6s
# 84:	learn: 0.0229251	total: 1.67s	remaining: 18s
# 84:	learn: 0.0224387	total: 1.68s	remaining: 18s
# 79:	learn: 0.0226837	total: 1.69s	remaining: 19.4s
# 78:	learn: 0.0339881	total: 1.68s	remaining: 19.6s
# 88:	learn: 0.0228314	total: 1.66s	remaining: 17s
# 82:	learn: 0.0324025	total: 1.68s	remaining: 18.6s
# 85:	learn: 0.0222292	total: 1.69s	remaining: 17.9s
# 88:	learn: 0.0231756	total: 1.7s	remaining: 17.4s
# 83:	learn: 0.0311358	total: 1.68s	remaining: 18.4s
# 85:	learn: 0.0217711	total: 1.69s	remaining: 18s
# 88:	learn: 0.0167271	total: 1.69s	remaining: 17.3s
# 89:	learn: 0.0218029	total: 1.67s	remaining: 16.8s
# 79:	learn: 0.0328602	total: 1.7s	remaining: 19.5s
# 80:	learn: 0.0221517	total: 1.71s	remaining: 19.4s
# 86:	learn: 0.0216157	total: 1.69s	remaining: 17.8s
# 84:	learn: 0.0303369	total: 1.7s	remaining: 18.3s
# 90:	learn: 0.0212295	total: 1.68s	remaining: 16.8s
# 81:	learn: 0.0215049	total: 1.72s	remaining: 19.2s
# 87:	learn: 0.0208503	total: 1.7s	remaining: 17.7s
# 80:	learn: 0.0317765	total: 1.71s	remaining: 19.4s
# 89:	learn: 0.0161444	total: 1.71s	remaining: 17.3s
# 89:	learn: 0.0224068	total: 1.72s	remaining: 17.4s
# 91:	learn: 0.0205213	total: 1.68s	remaining: 16.6s
# 88:	learn: 0.0203062	total: 1.71s	remaining: 17.5s
# 86:	learn: 0.0211767	total: 1.72s	remaining: 18s
# 85:	learn: 0.0294362	total: 1.71s	remaining: 18.2s
# 82:	learn: 0.0210091	total: 1.73s	remaining: 19.1s
# 90:	learn: 0.0218676	total: 1.73s	remaining: 17.3s
# 89:	learn: 0.0195145	total: 1.72s	remaining: 17.4s
# 81:	learn: 0.0308455	total: 1.73s	remaining: 19.3s
# 92:	learn: 0.0200148	total: 1.7s	remaining: 16.6s
# 87:	learn: 0.0205942	total: 1.73s	remaining: 18s
# 90:	learn: 0.0189434	total: 1.73s	remaining: 17.3s
# 83:	learn: 0.0202693	total: 1.74s	remaining: 19s
# 82:	learn: 0.0298754	total: 1.74s	remaining: 19.2s
# 91:	learn: 0.0213330	total: 1.75s	remaining: 17.2s
# 86:	learn: 0.0284153	total: 1.73s	remaining: 18.1s
# 90:	learn: 0.0155943	total: 1.74s	remaining: 17.4s
# 92:	learn: 0.0204974	total: 1.75s	remaining: 17.1s
# 93:	learn: 0.0193559	total: 1.71s	remaining: 16.5s
# 87:	learn: 0.0275256	total: 1.74s	remaining: 18s
# 91:	learn: 0.0184689	total: 1.74s	remaining: 17.2s
# 84:	learn: 0.0197273	total: 1.76s	remaining: 18.9s
# 88:	learn: 0.0198991	total: 1.75s	remaining: 17.9s
# 83:	learn: 0.0288916	total: 1.75s	remaining: 19.1s
# 94:	learn: 0.0189362	total: 1.73s	remaining: 16.4s
# 91:	learn: 0.0151275	total: 1.75s	remaining: 17.3s
# 92:	learn: 0.0178835	total: 1.75s	remaining: 17.1s
# 85:	learn: 0.0192387	total: 1.77s	remaining: 18.8s
# 89:	learn: 0.0192313	total: 1.76s	remaining: 17.8s
# 95:	learn: 0.0182605	total: 1.73s	remaining: 16.3s
# 88:	learn: 0.0267881	total: 1.75s	remaining: 17.9s
# 84:	learn: 0.0280943	total: 1.76s	remaining: 19s
# 93:	learn: 0.0199561	total: 1.77s	remaining: 17.1s
# 92:	learn: 0.0145389	total: 1.76s	remaining: 17.2s
# 89:	learn: 0.0259544	total: 1.76s	remaining: 17.8s
# 96:	learn: 0.0177031	total: 1.74s	remaining: 16.2s
# 93:	learn: 0.0141609	total: 1.77s	remaining: 17.1s
# 86:	learn: 0.0187428	total: 1.78s	remaining: 18.7s
# 93:	learn: 0.0173559	total: 1.77s	remaining: 17.1s
# 94:	learn: 0.0194054	total: 1.79s	remaining: 17s
# 85:	learn: 0.0272799	total: 1.78s	remaining: 18.9s
# 97:	learn: 0.0172034	total: 1.75s	remaining: 16.1s
# 87:	learn: 0.0180202	total: 1.79s	remaining: 18.5s
# 94:	learn: 0.0136272	total: 1.78s	remaining: 16.9s
# 90:	learn: 0.0253311	total: 1.77s	remaining: 17.7s
# 90:	learn: 0.0186959	total: 1.78s	remaining: 17.8s
# 98:	learn: 0.0165643	total: 1.75s	remaining: 16s
# 94:	learn: 0.0169942	total: 1.78s	remaining: 17s
# 95:	learn: 0.0187516	total: 1.8s	remaining: 16.9s
# 86:	learn: 0.0267388	total: 1.79s	remaining: 18.8s
# 95:	learn: 0.0132417	total: 1.78s	remaining: 16.8s
# 91:	learn: 0.0181433	total: 1.79s	remaining: 17.7s
# 91:	learn: 0.0245565	total: 1.78s	remaining: 17.6s
# 99:	learn: 0.0161643	total: 1.77s	remaining: 15.9s
# 96:	learn: 0.0128774	total: 1.79s	remaining: 16.7s
# 87:	learn: 0.0257863	total: 1.8s	remaining: 18.6s
# 95:	learn: 0.0164941	total: 1.79s	remaining: 16.9s
# 88:	learn: 0.0174341	total: 1.81s	remaining: 18.5s
# 92:	learn: 0.0238696	total: 1.79s	remaining: 17.5s
# 92:	learn: 0.0176365	total: 1.8s	remaining: 17.6s
# 96:	learn: 0.0181748	total: 1.81s	remaining: 16.9s
# 97:	learn: 0.0125242	total: 1.8s	remaining: 16.6s
# 100:	learn: 0.0156402	total: 1.77s	remaining: 15.8s
# 96:	learn: 0.0160151	total: 1.8s	remaining: 16.8s
# 89:	learn: 0.0169402	total: 1.82s	remaining: 18.4s
# 97:	learn: 0.0176305	total: 1.82s	remaining: 16.7s
# 93:	learn: 0.0171585	total: 1.81s	remaining: 17.5s
# 93:	learn: 0.0231547	total: 1.8s	remaining: 17.4s
# 97:	learn: 0.0155068	total: 1.81s	remaining: 16.6s
# 98:	learn: 0.0170706	total: 1.82s	remaining: 16.6s
# 101:	learn: 0.0153474	total: 1.78s	remaining: 15.7s
# 88:	learn: 0.0250193	total: 1.82s	remaining: 18.6s
# 90:	learn: 0.0164706	total: 1.83s	remaining: 18.3s
# 98:	learn: 0.0152059	total: 1.81s	remaining: 16.5s
# 94:	learn: 0.0165440	total: 1.82s	remaining: 17.3s
# 99:	learn: 0.0166965	total: 1.83s	remaining: 16.5s
# 98:	learn: 0.0121581	total: 1.82s	remaining: 16.6s
# 102:	learn: 0.0150731	total: 1.8s	remaining: 15.7s
# 94:	learn: 0.0226055	total: 1.82s	remaining: 17.3s
# 99:	learn: 0.0116631	total: 1.82s	remaining: 16.4s
# 100:	learn: 0.0162028	total: 1.84s	remaining: 16.4s
# 100:	learn: 0.0111938	total: 1.83s	remaining: 16.3s
# 95:	learn: 0.0161095	total: 1.83s	remaining: 17.3s
# 89:	learn: 0.0242648	total: 1.84s	remaining: 18.6s
# 99:	learn: 0.0147083	total: 1.83s	remaining: 16.5s
# 91:	learn: 0.0159310	total: 1.84s	remaining: 18.2s
# 90:	learn: 0.0235366	total: 1.84s	remaining: 18.4s
# 103:	learn: 0.0147698	total: 1.81s	remaining: 15.6s
# 100:	learn: 0.0142952	total: 1.84s	remaining: 16.4s
# 101:	learn: 0.0108885	total: 1.84s	remaining: 16.2s
# 95:	learn: 0.0220872	total: 1.84s	remaining: 17.3s
# 101:	learn: 0.0159250	total: 1.86s	remaining: 16.4s
# 96:	learn: 0.0156115	total: 1.85s	remaining: 17.2s
# 101:	learn: 0.0138424	total: 1.85s	remaining: 16.3s
# 104:	learn: 0.0145063	total: 1.83s	remaining: 15.6s
# 92:	learn: 0.0154980	total: 1.87s	remaining: 18.2s
# 102:	learn: 0.0153019	total: 1.87s	remaining: 16.3s
# 97:	learn: 0.0149662	total: 1.86s	remaining: 17.1s
# 91:	learn: 0.0229665	total: 1.86s	remaining: 18.4s
# 102:	learn: 0.0105141	total: 1.86s	remaining: 16.2s
# 105:	learn: 0.0140280	total: 1.83s	remaining: 15.5s
# 102:	learn: 0.0134445	total: 1.86s	remaining: 16.2s
# 93:	learn: 0.0149795	total: 1.88s	remaining: 18.1s
# 98:	learn: 0.0145582	total: 1.87s	remaining: 17s
# 96:	learn: 0.0216117	total: 1.86s	remaining: 17.3s
# 92:	learn: 0.0222468	total: 1.87s	remaining: 18.3s
# 94:	learn: 0.0145862	total: 1.89s	remaining: 18s
# 93:	learn: 0.0214210	total: 1.88s	remaining: 18.1s
# 99:	learn: 0.0140860	total: 1.88s	remaining: 16.9s
# 103:	learn: 0.0148989	total: 1.9s	remaining: 16.4s
# 106:	learn: 0.0135968	total: 1.86s	remaining: 15.5s
# 97:	learn: 0.0210985	total: 1.88s	remaining: 17.3s
# 103:	learn: 0.0101360	total: 1.88s	remaining: 16.2s
# 98:	learn: 0.0202258	total: 1.88s	remaining: 17.1s
# 100:	learn: 0.0136525	total: 1.89s	remaining: 16.8s
# 94:	learn: 0.0210277	total: 1.89s	remaining: 18s
# 103:	learn: 0.0131566	total: 1.88s	remaining: 16.2s
# 101:	learn: 0.0131114	total: 1.9s	remaining: 16.7s
# 99:	learn: 0.0193972	total: 1.89s	remaining: 17s
# 95:	learn: 0.0205169	total: 1.9s	remaining: 17.9s
# 95:	learn: 0.0142545	total: 1.91s	remaining: 18s
# 104:	learn: 0.0127300	total: 1.89s	remaining: 16.1s
# 107:	learn: 0.0132985	total: 1.87s	remaining: 15.5s
# 96:	learn: 0.0199367	total: 1.91s	remaining: 17.8s
# 104:	learn: 0.0098555	total: 1.9s	remaining: 16.2s
# 96:	learn: 0.0137809	total: 1.92s	remaining: 17.9s
# 105:	learn: 0.0122962	total: 1.9s	remaining: 16s
# 108:	learn: 0.0128012	total: 1.88s	remaining: 15.4s
# 102:	learn: 0.0127951	total: 1.91s	remaining: 16.6s
# 104:	learn: 0.0143986	total: 1.93s	remaining: 16.4s
# 100:	learn: 0.0190017	total: 1.91s	remaining: 17s
# 97:	learn: 0.0194355	total: 1.92s	remaining: 17.7s
# 97:	learn: 0.0133919	total: 1.93s	remaining: 17.8s
# 105:	learn: 0.0095906	total: 1.92s	remaining: 16.2s
# 106:	learn: 0.0118646	total: 1.92s	remaining: 16s
# 103:	learn: 0.0124606	total: 1.93s	remaining: 16.6s
# 101:	learn: 0.0182583	total: 1.92s	remaining: 16.9s
# 109:	learn: 0.0125123	total: 1.9s	remaining: 15.4s
# 110:	learn: 0.0120381	total: 1.91s	remaining: 15.3s
# 98:	learn: 0.0130021	total: 1.95s	remaining: 17.7s
# 98:	learn: 0.0188589	total: 1.94s	remaining: 17.6s
# 107:	learn: 0.0115948	total: 1.93s	remaining: 15.9s
# 102:	learn: 0.0178010	total: 1.93s	remaining: 16.8s
# 105:	learn: 0.0139628	total: 1.95s	remaining: 16.4s
# 106:	learn: 0.0134437	total: 1.96s	remaining: 16.4s
# 104:	learn: 0.0121902	total: 1.95s	remaining: 16.6s
# 99:	learn: 0.0182601	total: 1.95s	remaining: 17.6s
# 106:	learn: 0.0092604	total: 1.94s	remaining: 16.2s
# 103:	learn: 0.0173553	total: 1.94s	remaining: 16.7s
# 111:	learn: 0.0116794	total: 1.92s	remaining: 15.3s
# 99:	learn: 0.0127693	total: 1.97s	remaining: 17.7s
# 108:	learn: 0.0111955	total: 1.95s	remaining: 15.9s
# 100:	learn: 0.0177270	total: 1.96s	remaining: 17.5s
# 105:	learn: 0.0118681	total: 1.96s	remaining: 16.5s
# 104:	learn: 0.0169341	total: 1.96s	remaining: 16.7s
# 112:	learn: 0.0114050	total: 1.94s	remaining: 15.2s
# 107:	learn: 0.0131694	total: 1.98s	remaining: 16.3s
# 101:	learn: 0.0170750	total: 1.97s	remaining: 17.3s
# 107:	learn: 0.0090311	total: 1.96s	remaining: 16.2s
# 105:	learn: 0.0165626	total: 1.96s	remaining: 16.5s
# 100:	learn: 0.0124587	total: 1.99s	remaining: 17.7s
# 113:	learn: 0.0110694	total: 1.95s	remaining: 15.1s
# 102:	learn: 0.0167108	total: 1.98s	remaining: 17.2s
# 106:	learn: 0.0115568	total: 1.97s	remaining: 16.5s
# 109:	learn: 0.0108645	total: 1.97s	remaining: 15.9s
# 108:	learn: 0.0128572	total: 1.99s	remaining: 16.3s
# 108:	learn: 0.0087715	total: 1.98s	remaining: 16.2s
# 109:	learn: 0.0123824	total: 2s	remaining: 16.2s
# 101:	learn: 0.0120440	total: 2s	remaining: 17.6s
# 114:	learn: 0.0108059	total: 1.96s	remaining: 15.1s
# 106:	learn: 0.0161726	total: 1.98s	remaining: 16.5s
# 103:	learn: 0.0162522	total: 1.99s	remaining: 17.2s
# 107:	learn: 0.0112599	total: 1.99s	remaining: 16.4s
# 102:	learn: 0.0117748	total: 2s	remaining: 17.4s
# 110:	learn: 0.0106086	total: 1.99s	remaining: 15.9s
# 107:	learn: 0.0158632	total: 1.99s	remaining: 16.4s
# 104:	learn: 0.0158893	total: 2s	remaining: 17.1s
# 103:	learn: 0.0114964	total: 2.01s	remaining: 17.3s
# 109:	learn: 0.0085742	total: 1.99s	remaining: 16.1s
# 111:	learn: 0.0103271	total: 2s	remaining: 15.8s
# 110:	learn: 0.0120864	total: 2.02s	remaining: 16.2s
# 115:	learn: 0.0105416	total: 1.98s	remaining: 15.1s
# 110:	learn: 0.0082584	total: 2s	remaining: 16s
# 108:	learn: 0.0109454	total: 2s	remaining: 16.4s
# 108:	learn: 0.0154991	total: 2s	remaining: 16.4s
# 104:	learn: 0.0111274	total: 2.02s	remaining: 17.2s
# 105:	learn: 0.0154313	total: 2.01s	remaining: 17s
# 112:	learn: 0.0100225	total: 2s	remaining: 15.7s
# 109:	learn: 0.0151859	total: 2.01s	remaining: 16.2s
# 111:	learn: 0.0118438	total: 2.03s	remaining: 16.1s
# 109:	learn: 0.0107249	total: 2.02s	remaining: 16.3s
# 111:	learn: 0.0079942	total: 2.01s	remaining: 16s
# 116:	learn: 0.0103149	total: 2s	remaining: 15.1s
# 113:	learn: 0.0097214	total: 2.02s	remaining: 15.7s
# 110:	learn: 0.0147024	total: 2.02s	remaining: 16.2s
# 105:	learn: 0.0108173	total: 2.04s	remaining: 17.2s
# 112:	learn: 0.0115416	total: 2.04s	remaining: 16s
# 112:	learn: 0.0077415	total: 2.02s	remaining: 15.9s
# 106:	learn: 0.0149585	total: 2.03s	remaining: 17s
# 110:	learn: 0.0105056	total: 2.03s	remaining: 16.3s
# 107:	learn: 0.0144048	total: 2.04s	remaining: 16.9s
# 111:	learn: 0.0143663	total: 2.03s	remaining: 16.1s
# 111:	learn: 0.0102519	total: 2.04s	remaining: 16.2s
# 113:	learn: 0.0075953	total: 2.03s	remaining: 15.8s
# 113:	learn: 0.0112234	total: 2.06s	remaining: 16s
# 106:	learn: 0.0105231	total: 2.06s	remaining: 17.2s
# 112:	learn: 0.0099184	total: 2.04s	remaining: 16.1s
# 117:	learn: 0.0100956	total: 2.02s	remaining: 15.1s
# 112:	learn: 0.0140383	total: 2.04s	remaining: 16.1s
# 108:	learn: 0.0140771	total: 2.06s	remaining: 16.8s
# 107:	learn: 0.0102140	total: 2.06s	remaining: 17.1s
# 114:	learn: 0.0094744	total: 2.05s	remaining: 15.8s
# 114:	learn: 0.0109674	total: 2.07s	remaining: 15.9s
# 118:	learn: 0.0098523	total: 2.03s	remaining: 15s
# 109:	learn: 0.0136174	total: 2.06s	remaining: 16.7s
# 113:	learn: 0.0137291	total: 2.06s	remaining: 16s
# 119:	learn: 0.0095281	total: 2.04s	remaining: 14.9s
# 114:	learn: 0.0132328	total: 2.06s	remaining: 15.9s
# 115:	learn: 0.0107078	total: 2.08s	remaining: 15.9s
# 114:	learn: 0.0073855	total: 2.06s	remaining: 15.9s
# 108:	learn: 0.0100356	total: 2.08s	remaining: 17s
# 113:	learn: 0.0096305	total: 2.07s	remaining: 16.1s
# 110:	learn: 0.0132016	total: 2.08s	remaining: 16.6s
# 120:	learn: 0.0092852	total: 2.05s	remaining: 14.9s
# 115:	learn: 0.0071493	total: 2.07s	remaining: 15.8s
# 116:	learn: 0.0104481	total: 2.09s	remaining: 15.8s
# 115:	learn: 0.0092867	total: 2.07s	remaining: 15.8s
# 109:	learn: 0.0097736	total: 2.09s	remaining: 16.9s
# 115:	learn: 0.0128890	total: 2.08s	remaining: 15.8s
# 121:	learn: 0.0090576	total: 2.06s	remaining: 14.8s
# 116:	learn: 0.0090101	total: 2.08s	remaining: 15.7s
# 117:	learn: 0.0100847	total: 2.1s	remaining: 15.7s
# 117:	learn: 0.0086913	total: 2.08s	remaining: 15.6s
# 114:	learn: 0.0094252	total: 2.09s	remaining: 16.1s
# 116:	learn: 0.0069978	total: 2.08s	remaining: 15.7s
# 111:	learn: 0.0128832	total: 2.1s	remaining: 16.6s
# 110:	learn: 0.0095546	total: 2.11s	remaining: 16.9s
# 118:	learn: 0.0083901	total: 2.09s	remaining: 15.5s
# 116:	learn: 0.0126022	total: 2.09s	remaining: 15.8s
# 117:	learn: 0.0068522	total: 2.09s	remaining: 15.6s
# 122:	learn: 0.0088336	total: 2.07s	remaining: 14.8s
# 112:	learn: 0.0124817	total: 2.1s	remaining: 16.5s
# 115:	learn: 0.0091435	total: 2.1s	remaining: 16s
# 118:	learn: 0.0098579	total: 2.12s	remaining: 15.7s
# 111:	learn: 0.0091972	total: 2.12s	remaining: 16.8s
# 113:	learn: 0.0121931	total: 2.11s	remaining: 16.4s
# 117:	learn: 0.0122307	total: 2.11s	remaining: 15.7s
# ...
# 922:	learn: 0.0006103	total: 6.45s	remaining: 538ms
# 929:	learn: 0.0005959	total: 6.63s	remaining: 499ms
# 894:	learn: 0.0006692	total: 5.25s	remaining: 616ms
# 951:	learn: 0.0006374	total: 6.21s	remaining: 313ms
# 923:	learn: 0.0006103	total: 6.45s	remaining: 531ms
# 895:	learn: 0.0006692	total: 5.26s	remaining: 610ms
# 930:	learn: 0.0005959	total: 6.64s	remaining: 492ms
# 952:	learn: 0.0006374	total: 6.22s	remaining: 307ms
# 924:	learn: 0.0006103	total: 6.46s	remaining: 523ms
# 931:	learn: 0.0005959	total: 6.64s	remaining: 485ms
# 896:	learn: 0.0006692	total: 5.26s	remaining: 604ms
# 953:	learn: 0.0006374	total: 6.22s	remaining: 300ms
# 925:	learn: 0.0006103	total: 6.46s	remaining: 516ms
# 897:	learn: 0.0006692	total: 5.27s	remaining: 598ms
# 932:	learn: 0.0005959	total: 6.65s	remaining: 477ms
# 954:	learn: 0.0006374	total: 6.23s	remaining: 293ms
# 926:	learn: 0.0006103	total: 6.46s	remaining: 509ms
# 898:	learn: 0.0006692	total: 5.27s	remaining: 592ms
# 933:	learn: 0.0005959	total: 6.65s	remaining: 470ms
# 955:	learn: 0.0006374	total: 6.23s	remaining: 287ms
# 927:	learn: 0.0006103	total: 6.47s	remaining: 502ms
# 934:	learn: 0.0005959	total: 6.66s	remaining: 463ms
# 899:	learn: 0.0006692	total: 5.28s	remaining: 586ms
# 956:	learn: 0.0006374	total: 6.24s	remaining: 280ms
# 928:	learn: 0.0006103	total: 6.47s	remaining: 495ms
# 900:	learn: 0.0006692	total: 5.28s	remaining: 580ms
# 935:	learn: 0.0005959	total: 6.66s	remaining: 456ms
# 957:	learn: 0.0006374	total: 6.24s	remaining: 274ms
# 929:	learn: 0.0006103	total: 6.48s	remaining: 488ms
# 936:	learn: 0.0005959	total: 6.67s	remaining: 448ms
# 901:	learn: 0.0006692	total: 5.29s	remaining: 575ms
# 958:	learn: 0.0006374	total: 6.25s	remaining: 267ms
# 937:	learn: 0.0005959	total: 6.67s	remaining: 441ms
# 930:	learn: 0.0006103	total: 6.49s	remaining: 481ms
# 902:	learn: 0.0006692	total: 5.29s	remaining: 569ms
# 959:	learn: 0.0006374	total: 6.25s	remaining: 261ms
# 938:	learn: 0.0005959	total: 6.68s	remaining: 434ms
# 931:	learn: 0.0006103	total: 6.49s	remaining: 474ms
# 903:	learn: 0.0006692	total: 5.3s	remaining: 563ms
# 939:	learn: 0.0005959	total: 6.68s	remaining: 427ms
# 960:	learn: 0.0006374	total: 6.27s	remaining: 254ms
# 904:	learn: 0.0006692	total: 5.31s	remaining: 557ms
# 932:	learn: 0.0006103	total: 6.5s	remaining: 467ms
# 940:	learn: 0.0005959	total: 6.69s	remaining: 420ms
# 961:	learn: 0.0006374	total: 6.27s	remaining: 248ms
# 933:	learn: 0.0006103	total: 6.5s	remaining: 460ms
# 905:	learn: 0.0006692	total: 5.31s	remaining: 551ms
# 934:	learn: 0.0006103	total: 6.51s	remaining: 453ms
# 941:	learn: 0.0005959	total: 6.7s	remaining: 412ms
# 962:	learn: 0.0006374	total: 6.28s	remaining: 241ms
# 906:	learn: 0.0006692	total: 5.32s	remaining: 545ms
# 935:	learn: 0.0006103	total: 6.52s	remaining: 446ms
# 963:	learn: 0.0006374	total: 6.28s	remaining: 235ms
# 907:	learn: 0.0006692	total: 5.32s	remaining: 540ms
# 942:	learn: 0.0005959	total: 6.7s	remaining: 405ms
# 936:	learn: 0.0006103	total: 6.52s	remaining: 438ms
# 943:	learn: 0.0005959	total: 6.71s	remaining: 398ms
# 908:	learn: 0.0006692	total: 5.33s	remaining: 534ms
# 964:	learn: 0.0006374	total: 6.29s	remaining: 228ms
# 937:	learn: 0.0006103	total: 6.53s	remaining: 431ms
# 909:	learn: 0.0006692	total: 5.33s	remaining: 528ms
# 965:	learn: 0.0006374	total: 6.29s	remaining: 222ms
# 944:	learn: 0.0005959	total: 6.71s	remaining: 391ms
# 938:	learn: 0.0006103	total: 6.53s	remaining: 424ms
# 910:	learn: 0.0006692	total: 5.34s	remaining: 522ms
# 939:	learn: 0.0006103	total: 6.53s	remaining: 417ms
# 966:	learn: 0.0006374	total: 6.3s	remaining: 215ms
# 945:	learn: 0.0005959	total: 6.72s	remaining: 384ms
# 940:	learn: 0.0006103	total: 6.54s	remaining: 410ms
# 911:	learn: 0.0006691	total: 5.34s	remaining: 516ms
# 967:	learn: 0.0006374	total: 6.3s	remaining: 208ms
# 946:	learn: 0.0005959	total: 6.73s	remaining: 376ms
# 912:	learn: 0.0006691	total: 5.35s	remaining: 510ms
# 941:	learn: 0.0006103	total: 6.54s	remaining: 403ms
# 968:	learn: 0.0006374	total: 6.31s	remaining: 202ms
# 947:	learn: 0.0005959	total: 6.73s	remaining: 369ms
# 913:	learn: 0.0006691	total: 5.35s	remaining: 504ms
# 942:	learn: 0.0006103	total: 6.55s	remaining: 396ms
# 969:	learn: 0.0006374	total: 6.32s	remaining: 195ms
# 948:	learn: 0.0005959	total: 6.74s	remaining: 362ms
# 914:	learn: 0.0006691	total: 5.36s	remaining: 498ms
# 943:	learn: 0.0006103	total: 6.55s	remaining: 389ms
# 970:	learn: 0.0006374	total: 6.32s	remaining: 189ms
# 949:	learn: 0.0005959	total: 6.74s	remaining: 355ms
# 915:	learn: 0.0006691	total: 5.36s	remaining: 492ms
# 944:	learn: 0.0006103	total: 6.56s	remaining: 382ms
# 971:	learn: 0.0006374	total: 6.33s	remaining: 182ms
# 916:	learn: 0.0006691	total: 5.37s	remaining: 486ms
# 950:	learn: 0.0005959	total: 6.75s	remaining: 348ms
# 945:	learn: 0.0006103	total: 6.56s	remaining: 375ms
# 972:	learn: 0.0006374	total: 6.33s	remaining: 176ms
# 917:	learn: 0.0006691	total: 5.37s	remaining: 480ms
# 951:	learn: 0.0005959	total: 6.75s	remaining: 341ms
# 946:	learn: 0.0006103	total: 6.57s	remaining: 368ms
# 918:	learn: 0.0006691	total: 5.38s	remaining: 474ms
# 952:	learn: 0.0005959	total: 6.76s	remaining: 333ms
# 973:	learn: 0.0006374	total: 6.34s	remaining: 169ms
# 947:	learn: 0.0006103	total: 6.57s	remaining: 361ms
# 919:	learn: 0.0006691	total: 5.38s	remaining: 468ms
# 974:	learn: 0.0006374	total: 6.34s	remaining: 163ms
# 953:	learn: 0.0005958	total: 6.76s	remaining: 326ms
# 920:	learn: 0.0006691	total: 5.38s	remaining: 462ms
# 948:	learn: 0.0006103	total: 6.58s	remaining: 354ms
# 975:	learn: 0.0006374	total: 6.35s	remaining: 156ms
# 954:	learn: 0.0005958	total: 6.77s	remaining: 319ms
# 921:	learn: 0.0006691	total: 5.39s	remaining: 456ms
# 949:	learn: 0.0006103	total: 6.58s	remaining: 347ms
# 955:	learn: 0.0005958	total: 6.77s	remaining: 312ms
# 976:	learn: 0.0006374	total: 6.35s	remaining: 150ms
# 950:	learn: 0.0006103	total: 6.59s	remaining: 339ms
# 922:	learn: 0.0006691	total: 5.4s	remaining: 450ms
# 956:	learn: 0.0005958	total: 6.78s	remaining: 305ms
# 977:	learn: 0.0006374	total: 6.36s	remaining: 143ms
# 951:	learn: 0.0006103	total: 6.59s	remaining: 332ms
# 923:	learn: 0.0006691	total: 5.4s	remaining: 444ms
# 957:	learn: 0.0005958	total: 6.78s	remaining: 297ms
# 978:	learn: 0.0006374	total: 6.36s	remaining: 136ms
# 924:	learn: 0.0006691	total: 5.41s	remaining: 438ms
# 952:	learn: 0.0006102	total: 6.6s	remaining: 325ms
# 958:	learn: 0.0005958	total: 6.79s	remaining: 290ms
# 979:	learn: 0.0006374	total: 6.37s	remaining: 130ms
# 953:	learn: 0.0006102	total: 6.6s	remaining: 318ms
# 925:	learn: 0.0006691	total: 5.41s	remaining: 432ms
# 959:	learn: 0.0005958	total: 6.79s	remaining: 283ms
# 980:	learn: 0.0006374	total: 6.37s	remaining: 123ms
# 954:	learn: 0.0006102	total: 6.61s	remaining: 311ms
# 926:	learn: 0.0006691	total: 5.42s	remaining: 427ms
# 960:	learn: 0.0005958	total: 6.8s	remaining: 276ms
# 955:	learn: 0.0006102	total: 6.61s	remaining: 304ms
# 927:	learn: 0.0006691	total: 5.42s	remaining: 421ms
# 981:	learn: 0.0006374	total: 6.38s	remaining: 117ms
# 961:	learn: 0.0005958	total: 6.8s	remaining: 269ms
# 956:	learn: 0.0006102	total: 6.62s	remaining: 297ms
# 928:	learn: 0.0006691	total: 5.42s	remaining: 415ms
# 982:	learn: 0.0006374	total: 6.39s	remaining: 110ms
# 957:	learn: 0.0006102	total: 6.62s	remaining: 290ms
# 929:	learn: 0.0006691	total: 5.43s	remaining: 409ms
# 962:	learn: 0.0005958	total: 6.81s	remaining: 262ms
# 930:	learn: 0.0006691	total: 5.43s	remaining: 403ms
# 963:	learn: 0.0005958	total: 6.81s	remaining: 254ms
# 983:	learn: 0.0006374	total: 6.39s	remaining: 104ms
# 958:	learn: 0.0006102	total: 6.63s	remaining: 283ms
# 931:	learn: 0.0006691	total: 5.44s	remaining: 397ms
# 984:	learn: 0.0006374	total: 6.4s	remaining: 97.4ms
# 964:	learn: 0.0005958	total: 6.82s	remaining: 247ms
# 959:	learn: 0.0006102	total: 6.63s	remaining: 276ms
# 932:	learn: 0.0006691	total: 5.44s	remaining: 391ms
# 985:	learn: 0.0006374	total: 6.4s	remaining: 90.9ms
# 965:	learn: 0.0005958	total: 6.82s	remaining: 240ms
# 960:	learn: 0.0006102	total: 6.64s	remaining: 269ms
# 933:	learn: 0.0006691	total: 5.45s	remaining: 385ms
# 986:	learn: 0.0006374	total: 6.41s	remaining: 84.4ms
# 966:	learn: 0.0005958	total: 6.83s	remaining: 233ms
# 934:	learn: 0.0006691	total: 5.45s	remaining: 379ms
# 961:	learn: 0.0006102	total: 6.64s	remaining: 262ms
# 987:	learn: 0.0006374	total: 6.41s	remaining: 77.9ms
# 967:	learn: 0.0005958	total: 6.83s	remaining: 226ms
# 962:	learn: 0.0006102	total: 6.65s	remaining: 255ms
# 935:	learn: 0.0006691	total: 5.46s	remaining: 373ms
# 968:	learn: 0.0005958	total: 6.84s	remaining: 219ms
# 988:	learn: 0.0006374	total: 6.42s	remaining: 71.4ms
# 936:	learn: 0.0006691	total: 5.46s	remaining: 367ms
# 963:	learn: 0.0006102	total: 6.65s	remaining: 248ms
# 989:	learn: 0.0006374	total: 6.42s	remaining: 64.9ms
# 969:	learn: 0.0005958	total: 6.84s	remaining: 212ms
# 964:	learn: 0.0006102	total: 6.66s	remaining: 241ms
# 937:	learn: 0.0006691	total: 5.46s	remaining: 361ms
# 990:	learn: 0.0006374	total: 6.43s	remaining: 58.4ms
# 938:	learn: 0.0006691	total: 5.47s	remaining: 355ms
# 970:	learn: 0.0005958	total: 6.85s	remaining: 205ms
# 965:	learn: 0.0006102	total: 6.66s	remaining: 235ms
# 991:	learn: 0.0006374	total: 6.43s	remaining: 51.9ms
# 939:	learn: 0.0006691	total: 5.47s	remaining: 349ms
# 971:	learn: 0.0005958	total: 6.85s	remaining: 197ms
# 966:	learn: 0.0006102	total: 6.67s	remaining: 228ms
# 992:	learn: 0.0006374	total: 6.44s	remaining: 45.4ms
# 940:	learn: 0.0006691	total: 5.48s	remaining: 344ms
# 972:	learn: 0.0005958	total: 6.86s	remaining: 190ms
# 967:	learn: 0.0006102	total: 6.67s	remaining: 221ms
# 993:	learn: 0.0006374	total: 6.44s	remaining: 38.9ms
# 941:	learn: 0.0006691	total: 5.48s	remaining: 338ms
# 973:	learn: 0.0005958	total: 6.87s	remaining: 183ms
# 968:	learn: 0.0006102	total: 6.68s	remaining: 214ms
# 942:	learn: 0.0006691	total: 5.49s	remaining: 332ms
# 994:	learn: 0.0006374	total: 6.45s	remaining: 32.4ms
# 974:	learn: 0.0005958	total: 6.87s	remaining: 176ms
# 943:	learn: 0.0006691	total: 5.49s	remaining: 326ms
# 969:	learn: 0.0006102	total: 6.68s	remaining: 207ms
# 995:	learn: 0.0006374	total: 6.45s	remaining: 25.9ms
# 944:	learn: 0.0006691	total: 5.5s	remaining: 320ms
# 975:	learn: 0.0005958	total: 6.88s	remaining: 169ms
# 970:	learn: 0.0006102	total: 6.69s	remaining: 200ms
# 945:	learn: 0.0006691	total: 5.5s	remaining: 314ms
# 976:	learn: 0.0005958	total: 6.88s	remaining: 162ms
# 996:	learn: 0.0006374	total: 6.46s	remaining: 19.4ms
# 971:	learn: 0.0006102	total: 6.7s	remaining: 193ms
# 946:	learn: 0.0006691	total: 5.51s	remaining: 308ms
# 997:	learn: 0.0006374	total: 6.46s	remaining: 13ms
# 977:	learn: 0.0005958	total: 6.89s	remaining: 155ms
# 972:	learn: 0.0006102	total: 6.7s	remaining: 186ms
# 947:	learn: 0.0006691	total: 5.51s	remaining: 302ms
# 998:	learn: 0.0006374	total: 6.47s	remaining: 6.48ms
# 973:	learn: 0.0006102	total: 6.71s	remaining: 179ms
# 978:	learn: 0.0005958	total: 6.89s	remaining: 148ms
# 948:	learn: 0.0006690	total: 5.52s	remaining: 296ms
# 999:	learn: 0.0006374	total: 6.48s	remaining: 0us
# 979:	learn: 0.0005958	total: 6.9s	remaining: 141ms
# 974:	learn: 0.0006102	total: 6.71s	remaining: 172ms
# 949:	learn: 0.0006690	total: 5.52s	remaining: 291ms
# 980:	learn: 0.0005958	total: 6.9s	remaining: 134ms
# 975:	learn: 0.0006102	total: 6.72s	remaining: 165ms
# 950:	learn: 0.0006690	total: 5.53s	remaining: 285ms
# 981:	learn: 0.0005958	total: 6.91s	remaining: 127ms
# 976:	learn: 0.0006102	total: 6.72s	remaining: 158ms
# 951:	learn: 0.0006690	total: 5.53s	remaining: 279ms
# 982:	learn: 0.0005958	total: 6.91s	remaining: 120ms
# 977:	learn: 0.0006102	total: 6.73s	remaining: 151ms
# 952:	learn: 0.0006690	total: 5.54s	remaining: 273ms
# 983:	learn: 0.0005958	total: 6.92s	remaining: 112ms
# 978:	learn: 0.0006102	total: 6.73s	remaining: 144ms
# 953:	learn: 0.0006690	total: 5.54s	remaining: 267ms
# 984:	learn: 0.0005958	total: 6.92s	remaining: 105ms
# 979:	learn: 0.0006102	total: 6.74s	remaining: 137ms
# 954:	learn: 0.0006690	total: 5.54s	remaining: 261ms
# 985:	learn: 0.0005958	total: 6.92s	remaining: 98.3ms
# 980:	learn: 0.0006102	total: 6.74s	remaining: 131ms
# 955:	learn: 0.0006690	total: 5.55s	remaining: 255ms
# 986:	learn: 0.0005958	total: 6.93s	remaining: 91.3ms
# 981:	learn: 0.0006102	total: 6.74s	remaining: 124ms
# 956:	learn: 0.0006690	total: 5.55s	remaining: 250ms
# 987:	learn: 0.0005958	total: 6.93s	remaining: 84.2ms
# 982:	learn: 0.0006102	total: 6.75s	remaining: 117ms
# 957:	learn: 0.0006690	total: 5.56s	remaining: 244ms
# 988:	learn: 0.0005957	total: 6.94s	remaining: 77.2ms
# 983:	learn: 0.0006102	total: 6.75s	remaining: 110ms
# 958:	learn: 0.0006690	total: 5.56s	remaining: 238ms
# 989:	learn: 0.0005957	total: 6.94s	remaining: 70.1ms
# 984:	learn: 0.0006102	total: 6.76s	remaining: 103ms
# 959:	learn: 0.0006690	total: 5.56s	remaining: 232ms
# 990:	learn: 0.0005957	total: 6.94s	remaining: 63.1ms
# 985:	learn: 0.0006102	total: 6.76s	remaining: 96ms
# 960:	learn: 0.0006690	total: 5.57s	remaining: 226ms
# 991:	learn: 0.0005957	total: 6.95s	remaining: 56ms
# 986:	learn: 0.0006102	total: 6.76s	remaining: 89.1ms
# 961:	learn: 0.0006690	total: 5.57s	remaining: 220ms
# 987:	learn: 0.0006102	total: 6.77s	remaining: 82.2ms
# 992:	learn: 0.0005957	total: 6.95s	remaining: 49ms
# 962:	learn: 0.0006690	total: 5.58s	remaining: 214ms
# 988:	learn: 0.0006102	total: 6.77s	remaining: 75.3ms
# 993:	learn: 0.0005957	total: 6.96s	remaining: 42ms
# 963:	learn: 0.0006690	total: 5.58s	remaining: 208ms
# 989:	learn: 0.0006102	total: 6.77s	remaining: 68.4ms
# 994:	learn: 0.0005957	total: 6.96s	remaining: 35ms
# 964:	learn: 0.0006690	total: 5.58s	remaining: 203ms
# 990:	learn: 0.0006102	total: 6.78s	remaining: 61.6ms
# 995:	learn: 0.0005957	total: 6.96s	remaining: 28ms
# 965:	learn: 0.0006690	total: 5.59s	remaining: 197ms
# 991:	learn: 0.0006102	total: 6.78s	remaining: 54.7ms
# 996:	learn: 0.0005957	total: 6.97s	remaining: 21ms
# 966:	learn: 0.0006690	total: 5.59s	remaining: 191ms
# 992:	learn: 0.0006102	total: 6.79s	remaining: 47.8ms
# 997:	learn: 0.0005957	total: 6.97s	remaining: 14ms
# 967:	learn: 0.0006690	total: 5.6s	remaining: 185ms
# 993:	learn: 0.0006102	total: 6.79s	remaining: 41ms
# 998:	learn: 0.0005957	total: 6.98s	remaining: 6.98ms
# 968:	learn: 0.0006690	total: 5.6s	remaining: 179ms
# 994:	learn: 0.0006102	total: 6.79s	remaining: 34.1ms
# 999:	learn: 0.0005957	total: 6.98s	remaining: 0us
# 969:	learn: 0.0006690	total: 5.6s	remaining: 173ms
# 995:	learn: 0.0006102	total: 6.8s	remaining: 27.3ms
# 970:	learn: 0.0006690	total: 5.61s	remaining: 167ms
# 996:	learn: 0.0006102	total: 6.8s	remaining: 20.5ms
# 971:	learn: 0.0006690	total: 5.61s	remaining: 162ms
# 997:	learn: 0.0006102	total: 6.8s	remaining: 13.6ms
# 972:	learn: 0.0006690	total: 5.61s	remaining: 156ms
# 998:	learn: 0.0006102	total: 6.81s	remaining: 6.82ms
# 973:	learn: 0.0006690	total: 5.62s	remaining: 150ms
# 999:	learn: 0.0006102	total: 6.81s	remaining: 0us
# 974:	learn: 0.0006690	total: 5.62s	remaining: 144ms
# 975:	learn: 0.0006690	total: 5.62s	remaining: 138ms
# 976:	learn: 0.0006690	total: 5.62s	remaining: 132ms
# 977:	learn: 0.0006690	total: 5.63s	remaining: 127ms
# 978:	learn: 0.0006690	total: 5.63s	remaining: 121ms
# 979:	learn: 0.0006690	total: 5.63s	remaining: 115ms
# 980:	learn: 0.0006690	total: 5.63s	remaining: 109ms
# 981:	learn: 0.0006690	total: 5.63s	remaining: 103ms
# 982:	learn: 0.0006690	total: 5.64s	remaining: 97.5ms
# 983:	learn: 0.0006690	total: 5.64s	remaining: 91.7ms
# 984:	learn: 0.0006690	total: 5.64s	remaining: 85.9ms
# 985:	learn: 0.0006689	total: 5.64s	remaining: 80.1ms
# 986:	learn: 0.0006689	total: 5.64s	remaining: 74.4ms
# 987:	learn: 0.0006689	total: 5.65s	remaining: 68.6ms
# 988:	learn: 0.0006689	total: 5.65s	remaining: 62.8ms
# 989:	learn: 0.0006689	total: 5.65s	remaining: 57.1ms
# 990:	learn: 0.0006689	total: 5.65s	remaining: 51.3ms
# 991:	learn: 0.0006689	total: 5.65s	remaining: 45.6ms
# 992:	learn: 0.0006689	total: 5.66s	remaining: 39.9ms
# 993:	learn: 0.0006689	total: 5.66s	remaining: 34.2ms
# 994:	learn: 0.0006689	total: 5.66s	remaining: 28.4ms
# 995:	learn: 0.0006689	total: 5.66s	remaining: 22.7ms
# 996:	learn: 0.0006689	total: 5.66s	remaining: 17ms
# 997:	learn: 0.0006689	total: 5.67s	remaining: 11.4ms
# 998:	learn: 0.0006689	total: 5.67s	remaining: 5.67ms
# 999:	learn: 0.0006689	total: 5.67s	remaining: 0us
# [Parallel(n_jobs=-1)]: Done  10 out of  12 | elapsed:   18.9s remaining:    3.8s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:   19.0s finished

# %% [markdown]
# #### Plot Results

# %%
cat_result = stack_results(cat_cv_result)
cat_result.groupby(['Metric', 'Dataset']).Value.mean().unstack()
# Out:
# Dataset        Test     Train
# Metric
# AUC        1.000000  1.000000
# Accuracy   1.000000  1.000000
# F1         1.000000  1.000000
# Log Loss  -0.001057 -0.000565
# Precision  1.000000  1.000000
# Recall     1.000000  1.000000

# %%
plot_result(cat_result, model='CatBoost', fname=f'figures/{algo}_cv_result')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 plot_result(cat_result, model='CatBoost', fname=f'figures/{algo}_cv_result')
#
# Cell In[66], line 22, in plot_result(df, model, fname)
#      20 g.fig.subplots_adjust(top=.9)
#      21 if fname:
# ---> 22     g.savefig(fname, dpi=300)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/seaborn/axisgrid.py:100, in _BaseGrid.savefig(self, *args, **kwargs)
#      98 kwargs = kwargs.copy()
#      99 kwargs.setdefault("bbox_inches", "tight")
# --> 100 self.figure.savefig(*args, **kwargs)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/figure.py:3378, in Figure.savefig(self, fname, transparent, **kwargs)
#    3374     for ax in self.axes:
#    3375         stack.enter_context(
#    3376             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3378 self.canvas.print_figure(fname, **kwargs)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/backend_bases.py:2366, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2362 try:
#    2363     # _get_renderer may change the figure dpi (as vector formats
#    2364     # force the figure dpi to 72), so we need to set it again here.
#    2365     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366         result = print_method(
#    2367             filename,
#    2368             facecolor=facecolor,
#    2369             edgecolor=edgecolor,
#    2370             orientation=orientation,
#    2371             bbox_inches_restore=_bbox_inches_restore,
#    2372             **kwargs)
#    2373 finally:
#    2374     if bbox_inches and restore_bbox:
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/backend_bases.py:2232, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2228     optional_kws = {  # Passed by print_figure for other renderers.
#    2229         "dpi", "facecolor", "edgecolor", "orientation",
#    2230         "bbox_inches_restore"}
#    2231     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234 else:  # Let third-parties do as they see fit.
#    2235     print_method = meth
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     462 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     463     """
#     464     Write the figure to a PNG file.
#     465
#    (...)
#     507         *metadata*, including the default 'Software' key.
#     508     """
# --> 509     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:458, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     453 """
#     454 Draw the canvas, then save it using `.image.imsave` (to which
#     455 *pil_kwargs* and *metadata* are forwarded).
#     456 """
#     457 FigureCanvasAgg.draw(self)
# --> 458 mpl.image.imsave(
#     459     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/matplotlib/image.py:1689, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1687 pil_kwargs.setdefault("format", format)
#    1688 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1689 image.save(fname, **pil_kwargs)
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/PIL/Image.py:2456, in Image.save(self, fp, format, **params)
#    2454         fp = builtins.open(filename, "r+b")
#    2455     else:
# -> 2456         fp = builtins.open(filename, "w+b")
#    2458 try:
#    2459     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/tomas/roboadvisor/portfolio-predictor/notebooks/figures/catboost_cv_result.png'

# %% [markdown]
# ### GPU

# %% [markdown]
# > Naturally, the following requires that you have a GPU.

# %% [markdown]
# #### Configure

# %%
cat_clf_gpu = CatBoostClassifier(task_type='GPU')

# %% [markdown]
# #### Cross-Validate

# %%
s = pd.Series(X_factors.columns.tolist())
cat_cols_idx = s[s.isin(cat_cols)].index.tolist()

# %%
algo = 'catboost_gpu'

# %%
fname = results_path / f'{algo}.joblib'
if not Path(fname).exists():
    fit_params = {'cat_features': cat_cols_idx}
    cat_gpu_cv_result, run_time[algo] = run_cv(cat_clf_gpu,
                                               y=y,
                                               X=X_factors,
                                               fit_params=fit_params, 
                                               n_jobs=1)
    joblib.dump(cat_gpu_cv_result, fname)
else:
    cat_gpu_cv_result = joblib.load(fname)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[161], line 4
#       2 if not Path(fname).exists():
#       3     fit_params = {'cat_features': cat_cols_idx}
# ----> 4     cat_gpu_cv_result, run_time[algo] = run_cv(cat_clf_gpu,
#       5                                                y=y,
#       6                                                X=X_factors,
#       7                                                fit_params=fit_params,
#       8                                                n_jobs=1)
#       9     joblib.dump(cat_gpu_cv_result, fname)
#      10 else:
#
# Cell In[64], line 3, in run_cv(clf, X, y, metrics, cv, fit_params, n_jobs)
#       1 def run_cv(clf, X=X_dummies, y=y, metrics=metrics, cv=cv, fit_params=None, n_jobs=-1):
#       2     start = time()
# ----> 3     scores = cross_validate(estimator=clf,
#       4                             X=X,
#       5                             y=y,
#       6                             scoring=list(metrics.keys()),
#       7                             cv=cv,
#       8                             return_train_score=True,
#       9                             n_jobs=n_jobs,
#      10                             verbose=1,
#      11                             fit_params=fit_params)
#      12     duration = time() - start
#      13     return scores, duration
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:328, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     308 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
#     309 results = parallel(
#     310     delayed(_fit_and_score)(
#     311         clone(estimator),
#    (...)
#     325     for train, test in indices
#     326 )
# --> 328 _warn_or_raise_about_fit_failures(results, error_score)
#     330 # For callable scoring, the return type is only know after calling. If the
#     331 # return type is a dictionary, the error scores can now be inserted with
#     332 # the correct key.
#     333 if callable(scoring):
#
# File ~/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:414, in _warn_or_raise_about_fit_failures(results, error_score)
#     407 if num_failed_fits == num_fits:
#     408     all_fits_failed_message = (
#     409         f"\nAll the {num_fits} fits failed.\n"
#     410         "It is very likely that your model is misconfigured.\n"
#     411         "You can try to debug the error by setting error_score='raise'.\n\n"
#     412         f"Below are more details about the failures:\n{fit_errors_summary}"
#     413     )
# --> 414     raise ValueError(all_fits_failed_message)
#     416 else:
#     417     some_fits_failed_message = (
#     418         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     419         "The score on these train-test partitions for these parameters"
#    (...)
#     423         f"Below are more details about the failures:\n{fit_errors_summary}"
#     424     )
#
# ValueError:
# All the 12 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/catboost/core.py", line 5220, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "/Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/catboost/core.py", line 2400, in _fit
#     self._train(
#   File "/Users/tomas/miniforge3/envs/ml4t/lib/python3.8/site-packages/catboost/core.py", line 1780, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 4833, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 4882, in _catboost._CatBoost._train
# _catboost.CatBoostError: /Users/zomb-ml-platform-msk/go-agent-21.2.0/pipelines/BuildMaster/catboost.git/catboost/libs/train_lib/trainer_env.cpp:9: Environment for task type [GPU] not found

# %% [markdown]
# #### Plot Results

# %%
cat_gpu_result = stack_results(cat_gpu_cv_result)
cat_gpu_result.groupby(['Metric', 'Dataset']).Value.mean().unstack()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[164], line 1
# ----> 1 cat_gpu_result = stack_results(cat_gpu_cv_result)
#       2 cat_gpu_result.groupby(['Metric', 'Dataset']).Value.mean().unstack()
#
# NameError: name 'cat_gpu_cv_result' is not defined

# %%
plot_result(cat_gpu_result, model='CatBoost', fname=f'figures/{algo}_cv_result')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[162], line 1
# ----> 1 plot_result(cat_gpu_result, model='CatBoost', fname=f'figures/{algo}_cv_result')
#
# NameError: name 'cat_gpu_result' is not defined

# %% [markdown]
# ## Compare Results

# %%
results = {'Baseline': dummy_result,
           'Random Forest': rf_result,
           'AdaBoost': ada_result,
           'Gradient Booster': gb_result,
           'XGBoost': xbg_result,
           'LightGBM Dummies': lgb_dummy_result,
           'LightGBM Factors': lgb_factor_result,
           'CatBoost': cat_result,
           'CatBoost GPU': cat_gpu_result}
df = pd.DataFrame()
for model, result in results.items():
    df = pd.concat([df, result.groupby(['Metric', 'Dataset']
                                       ).Value.mean().unstack()['Test'].to_frame(model)], axis=1)

df.T.sort_values('AUC', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[163], line 9
#       1 results = {'Baseline': dummy_result,
#       2            'Random Forest': rf_result,
#       3            'AdaBoost': ada_result,
#       4            'Gradient Booster': gb_result,
#       5            'XGBoost': xbg_result,
#       6            'LightGBM Dummies': lgb_dummy_result,
#       7            'LightGBM Factors': lgb_factor_result,
#       8            'CatBoost': cat_result,
# ----> 9            'CatBoost GPU': cat_gpu_result}
#      10 df = pd.DataFrame()
#      11 for model, result in results.items():
#
# NameError: name 'cat_gpu_result' is not defined

# %%
algo_dict = dict(zip(['dummy_clf', 'random_forest', 'adaboost', 'sklearn_gbm', 
                      'xgboost', 'lgb_factors', 'lgb_dummies', 'catboost', 'catboost_gpu'],
                     ['Baseline', 'Random Forest', 'AdaBoost', 'Gradient Booster', 
                      'XGBoost', 'LightGBM Dummies', 'LightGBM Factors', 'CatBoost', 'CatBoost GPU']))

# %%
print(run_time)
# Out:
# {'dummy_clf': 3.446434736251831, 'random_forest': 486.9282796382904, 'adaboost': 385.62260723114014, 'sklearn_gbm': 53.61000990867615, 'xgboost': 477.78596901893616, 'lgb_factors': 1847.2539386749268, 'lgb_dummies': 613.5608298778534, 'catboost': 1819.1900961399078}

# %%
r = pd.Series(run_time).to_frame('t')
r.index = r.index.to_series().map(algo_dict)
r.to_csv(results_path / 'runtime.csv')

# %%
# r = pd.read_csv(results_path / 'runtime.csv', index_col=0)

# %%
auc = pd.concat([v.loc[(v.Dataset=='Test') & (v.Metric=='AUC'), 'Value'].to_frame('AUC').assign(Model=k) 
                 for k, v in results.items()])
# auc = auc[auc.Model != 'Baseline']

# %%
fig, axes = plt.subplots(figsize=(15, 5), ncols=2)
idx = df.T.drop('Baseline')['AUC'].sort_values(ascending=False).index
sns.barplot(x='Model', y='AUC',
            data=auc,
            order=idx, ax=axes[0])
axes[0].set_xticklabels([c.replace(' ', '\n') for c in idx])
axes[0].set_ylim(.49, .58)
axes[0].set_title('Predictive Accuracy')

(r.drop('Baseline').sort_values('t').rename(index=lambda x: x.replace(' ', '\n'))
 .plot.barh(title='Runtime', ax=axes[1], logx=True, legend=False))
axes[1].set_xlabel('Seconds (log scale)')
sns.despine()
fig.tight_layout()
